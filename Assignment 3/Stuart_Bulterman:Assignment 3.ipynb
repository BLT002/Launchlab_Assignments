# %% [markdown]
# # Assignment \#3: Importing Data (Part 2)
# In this Assignment you will be practising alternative ways of sourcing data.
#
# ## Web scraping
# For this Assignment you are tasked with scraping the following website: 'premierleague.com'
#
# On this website you are looking for the results of football matches that took place in August 2019.
#
# The results of these matches can be found by going to the url 'premierleague.com/match/\[match_ID\]' where match_ID will start at 46605 up to 46644.
#
# ## Examing the code below.
# The cell below contains limited capability of scraping the website for the results of a match and requires further functionality.
#
# The code retrieves the html page containing the match results.
# Finish the code to retrieve the following <div\> in which both team names as well as the score line for a match can be found:
#
# Find and print the contents of <div class="teamsContainer"\></div\>

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

url = 'https://premierleague.com/match/46605'

page = requests.get(url)

soup = BeautifulSoup(page.content, 'html.parser')

# insert code here
<body><div id="galleryWrapModal" class="pl-modal"><div id="galleryContentModal" class="pl-modal__content"><a class="close" role="button" tabindex="0">close</a><div data-script="pl_gallery" data-widget="gallery-modal" id="galleryModal" class="galleryModal" style=""><div class="galleryWrapper"><ul class="galleryList"><li class="prev"><img class="galleryImageContainer"><figcaption class="galleryFigCaptionContainer"><span class="galleryCaptionTitle"></span><span class="galleryCaptionBody"></span></figcaption></li><li class="current"><img class="galleryImageContainer"><figcaption class="galleryFigCaptionContainer"><span class="galleryCaptionTitle"></span><span class="galleryCaptionBody"></span></figcaption></li><li class="next"><img class="galleryImageContainer"><figcaption class="galleryFigCaptionContainer"><span class="galleryCaptionTitle"></span><span class="galleryCaptionBody"></span></figcaption></li></ul><a tabindex="0" alt="Previous slide" class="galleryNavButton prev"></a><a tabindex="0" alt="Next slide" class="galleryNavButton next"></a></div></div></div></div><div id="videoPlayerWrapModal" class="pl-modal"><div id="videoPlayerContentModal" class="pl-modal__content"><a class="close" role="button" tabindex="0">close</a><div data-script="pl_video-player" data-widget="video-player" id="videoPlayer" style="display:none;" data-old-modal="">
	<div class="modalWrapper">
		<div class="modalContentWrapper">
		    <div class="modalNowPlaying">Now Playing</div>
		    <div class="videoTitle"></div>
		    <div class="video-js vjs-paused vjs-controls-enabled vjs-workinghover vjs-v7 vjs-user-active vjs-layout-tiny bc-player-BvTUJZhBm_default bc-player-BvTUJZhBm_default-index-0 vjs-mouse vjs-dock vjs-plugins-ready vjs-player-info vjs-contextmenu vjs-contextmenu-ui vjs-errors vjs-quality-menu" data-embed="default" data-player="BvTUJZhBm" crossorigin="anonymous" data-account="2508689025001" id="plVideoModal" tabindex="-1" lang="en" translate="no" role="region" aria-label="Video Player"><video id="plVideoModal_html5_api" data-account="2508689025001" crossorigin="anonymous" data-player="BvTUJZhBm" data-embed="default" class="vjs-tech" tabindex="-1" preload="metadata" aria-labelledby="vjs-dock-title-1" aria-describedby="vjs-dock-description-2"></video><script src="https://vjs.zencdn.net/vttjs/0.15.3/vtt.global.min.js"></script><div class="vjs-poster vjs-hidden" tabindex="-1" aria-disabled="false"></div><div class="vjs-text-track-display" translate="yes" aria-live="off" aria-atomic="true"></div><div class="vjs-dock-text"><div class="vjs-dock-title" id="vjs-dock-title-1"></div><div class="vjs-dock-description" id="vjs-dock-description-2"></div></div><div class="vjs-dock-shelf"></div><div class="vjs-loading-spinner" dir="ltr"><span class="vjs-control-text">Video Player is loading.</span></div><button class="vjs-big-play-button" type="button" title="Play Video" aria-disabled="false"><span class="vjs-icon-placeholder" aria-hidden="true"></span><span class="vjs-control-text" aria-live="polite">Play Video</span></button><div class="vjs-control-bar" dir="ltr"><button class="vjs-play-control vjs-control vjs-button" type="button" title="Play" aria-disabled="false"><span class="vjs-icon-placeholder" aria-hidden="true"></span><span class="vjs-control-text" aria-live="polite">Play</span></button><div class="vjs-volume-panel vjs-control vjs-volume-panel-horizontal"><button class="vjs-mute-control vjs-control vjs-button" type="button" title="Mute" aria-disabled="false"><span class="vjs-icon-placeholder" aria-hidden="true"></span><span class="vjs-control-text" aria-live="polite">Mute</span></button><div class="vjs-volume-control vjs-control vjs-volume-horizontal"><div tabindex="0" class="vjs-volume-bar vjs-slider-bar vjs-slider vjs-slider-horizontal" role="slider" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100" aria-label="Volume Level" aria-live="polite" aria-valuetext="100%"><div class="vjs-mouse-display"><div class="vjs-volume-tooltip" aria-hidden="true"></div></div><div class="vjs-volume-level"><span class="vjs-control-text"></span></div></div></div></div><div class="vjs-current-time vjs-time-control vjs-control"><span class="vjs-control-text" role="presentation">Current Time&nbsp;</span><span class="vjs-current-time-display" aria-live="off" role="presentation">0:00</span></div><div class="vjs-time-control vjs-time-divider" aria-hidden="true"><div><span>/</span></div></div><div class="vjs-duration vjs-time-control vjs-control"><span class="vjs-control-text" role="presentation">Duration&nbsp;</span><span class="vjs-duration-display" aria-live="off" role="presentation">0:00</span></div><div class="vjs-progress-control vjs-control"><div tabindex="0" class="vjs-progress-holder vjs-slider vjs-slider-horizontal" role="slider" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100" aria-label="Progress Bar"><div class="vjs-load-progress"><span class="vjs-control-text"><span>Loaded</span>: <span class="vjs-control-text-loaded-percentage">0%</span></span></div><div class="vjs-mouse-display"><div class="vjs-time-tooltip" aria-hidden="true"></div></div><div class="vjs-play-progress vjs-slider-bar" aria-hidden="true"><div class="vjs-time-tooltip" aria-hidden="true"></div></div></div></div><div class="vjs-live-control vjs-control vjs-hidden"><div class="vjs-live-display" aria-live="off"><span class="vjs-control-text">Stream Type&nbsp;</span>LIVE</div></div><button class="vjs-seek-to-live-control vjs-control" type="button" title="Seek to live, currently behind live" aria-disabled="false"><span class="vjs-icon-placeholder" aria-hidden="true"></span><span class="vjs-control-text" aria-live="polite">Seek to live, currently behind live</span><span class="vjs-seek-to-live-text" aria-hidden="true">LIVE</span></button><div class="vjs-remaining-time vjs-time-control vjs-control"><span class="vjs-control-text" role="presentation">Remaining Time&nbsp;</span><span aria-hidden="true">-</span><span class="vjs-remaining-time-display" aria-live="off" role="presentation">0:00</span></div><div class="vjs-custom-control-spacer vjs-spacer ">&nbsp;</div><div class="vjs-playback-rate vjs-menu-button vjs-menu-button-popup vjs-control vjs-button vjs-hidden"><div class="vjs-playback-rate-value" id="vjs-playback-rate-value-label-plVideoModal_component_323">1x</div><button class="vjs-playback-rate vjs-menu-button vjs-menu-button-popup vjs-button" type="button" aria-disabled="false" title="Playback Rate" aria-haspopup="true" aria-expanded="false" aria-describedby="vjs-playback-rate-value-label-plVideoModal_component_323"><span class="vjs-icon-placeholder" aria-hidden="true"></span><span class="vjs-control-text" aria-live="polite">Playback Rate</span></button><div class="vjs-menu"><ul class="vjs-menu-content"></ul></div></div><div class="vjs-chapters-button vjs-menu-button vjs-menu-button-popup vjs-control vjs-button vjs-hidden"><button class="vjs-chapters-button vjs-menu-button vjs-menu-button-popup vjs-button" type="button" aria-disabled="false" title="Chapters" aria-haspopup="true" aria-expanded="false"><span class="vjs-icon-placeholder" aria-hidden="true"></span><span class="vjs-control-text" aria-live="polite">Chapters</span></button><div class="vjs-menu"><ul class="vjs-menu-content"><li class="vjs-menu-title" tabindex="-1">Chapters</li></ul></div></div><div class="vjs-descriptions-button vjs-menu-button vjs-menu-button-popup vjs-control vjs-button vjs-hidden"><button class="vjs-descriptions-button vjs-menu-button vjs-menu-button-popup vjs-button" type="button" aria-disabled="false" title="Descriptions" aria-haspopup="true" aria-expanded="false"><span class="vjs-icon-placeholder" aria-hidden="true"></span><span class="vjs-control-text" aria-live="polite">Descriptions</span></button><div class="vjs-menu"><ul class="vjs-menu-content"><li class="vjs-menu-item vjs-selected" tabindex="-1" role="menuitemradio" aria-disabled="false" aria-checked="true"><span class="vjs-menu-item-text">descriptions off</span><span class="vjs-control-text" aria-live="polite">, selected</span></li></ul></div></div><div class="vjs-subs-caps-button vjs-menu-button vjs-menu-button-popup vjs-control vjs-button vjs-hidden"><button class="vjs-subs-caps-button vjs-menu-button vjs-menu-button-popup vjs-button" type="button" aria-disabled="false" title="Captions" aria-haspopup="true" aria-expanded="false"><span class="vjs-icon-placeholder" aria-hidden="true"></span><span class="vjs-control-text" aria-live="polite">Captions</span></button><div class="vjs-menu"><ul class="vjs-menu-content"><li class="vjs-menu-item vjs-texttrack-settings" tabindex="-1" role="menuitem" aria-disabled="false"><span class="vjs-menu-item-text">captions settings</span><span class="vjs-control-text" aria-live="polite">, opens captions settings dialog</span></li><li class="vjs-menu-item vjs-selected" tabindex="-1" role="menuitemradio" aria-disabled="false" aria-checked="true"><span class="vjs-menu-item-text">captions off</span><span class="vjs-control-text" aria-live="polite">, selected</span></li></ul></div></div><div class="vjs-audio-button vjs-menu-button vjs-menu-button-popup vjs-control vjs-button vjs-hidden"><button class="vjs-audio-button vjs-menu-button vjs-menu-button-popup vjs-button" type="button" aria-disabled="false" title="Audio Track" aria-haspopup="true" aria-expanded="false"><span class="vjs-icon-placeholder" aria-hidden="true"></span><span class="vjs-control-text" aria-live="polite">Audio Track</span></button><div class="vjs-menu"><ul class="vjs-menu-content"></ul></div></div><div class="vjs-quality-menu-wrapper vjs-menu-button vjs-menu-button-popup vjs-control vjs-button vjs-hidden" aria-label="Quality Levels"><button class="vjs-quality-menu-button vjs-menu-button vjs-menu-button-popup vjs-button" type="button" aria-disabled="false" aria-haspopup="true" aria-expanded="false" title="Quality Levels"><span class="vjs-icon-placeholder" aria-hidden="true"></span><span class="vjs-control-text" aria-live="polite">Quality Levels</span></button><div class="vjs-menu"><ul class="vjs-menu-content"></ul></div></div><button class="vjs-picture-in-picture-control vjs-control vjs-button vjs-disabled" type="button" title="Picture-in-Picture" aria-disabled="true" disabled="disabled"><span class="vjs-icon-placeholder" aria-hidden="true"></span><span class="vjs-control-text" aria-live="polite">Picture-in-Picture</span></button><button class="vjs-fullscreen-control vjs-control vjs-button" type="button" title="Fullscreen" aria-disabled="false"><span class="vjs-icon-placeholder" aria-hidden="true"></span><span class="vjs-control-text" aria-live="polite">Fullscreen</span></button></div><div class="vjs-error-display vjs-modal-dialog vjs-hidden " tabindex="-1" aria-describedby="plVideoModal_component_541_description" aria-hidden="true" aria-label="Modal Window" role="dialog"><p class="vjs-modal-dialog-description vjs-control-text" id="plVideoModal_component_541_description">This is a modal window.</p><div class="vjs-modal-dialog-content" role="document"></div></div><div class="vjs-modal-dialog vjs-hidden  vjs-text-track-settings" tabindex="-1" aria-describedby="plVideoModal_component_547_description" aria-hidden="true" aria-label="Caption Settings Dialog" role="dialog"><p class="vjs-modal-dialog-description vjs-control-text" id="plVideoModal_component_547_description">Beginning of dialog window. Escape will cancel and close the window.</p><div class="vjs-modal-dialog-content" role="document"><div class="vjs-track-settings-colors"><fieldset class="vjs-fg-color vjs-track-setting"><legend id="captions-text-legend-plVideoModal_component_547">Text</legend><label id="captions-foreground-color-plVideoModal_component_547" class="vjs-label">Color</label><select aria-labelledby="captions-text-legend-plVideoModal_component_547 captions-foreground-color-plVideoModal_component_547"><option id="captions-foreground-color-plVideoModal_component_547-White" value="#FFF" aria-labelledby="captions-text-legend-plVideoModal_component_547 captions-foreground-color-plVideoModal_component_547 captions-foreground-color-plVideoModal_component_547-White">White</option><option id="captions-foreground-color-plVideoModal_component_547-Black" value="#000" aria-labelledby="captions-text-legend-plVideoModal_component_547 captions-foreground-color-plVideoModal_component_547 captions-foreground-color-plVideoModal_component_547-Black">Black</option><option id="captions-foreground-color-plVideoModal_component_547-Red" value="#F00" aria-labelledby="captions-text-legend-plVideoModal_component_547 captions-foreground-color-plVideoModal_component_547 captions-foreground-color-plVideoModal_component_547-Red">Red</option><option id="captions-foreground-color-plVideoModal_component_547-Green" value="#0F0" aria-labelledby="captions-text-legend-plVideoModal_component_547 captions-foreground-color-plVideoModal_component_547 captions-foreground-color-plVideoModal_component_547-Green">Green</option><option id="captions-foreground-color-plVideoModal_component_547-Blue" value="#00F" aria-labelledby="captions-text-legend-plVideoModal_component_547 captions-foreground-color-plVideoModal_component_547 captions-foreground-color-plVideoModal_component_547-Blue">Blue</option><option id="captions-foreground-color-plVideoModal_component_547-Yellow" value="#FF0" aria-labelledby="captions-text-legend-plVideoModal_component_547 captions-foreground-color-plVideoModal_component_547 captions-foreground-color-plVideoModal_component_547-Yellow">Yellow</option><option id="captions-foreground-color-plVideoModal_component_547-Magenta" value="#F0F" aria-labelledby="captions-text-legend-plVideoModal_component_547 captions-foreground-color-plVideoModal_component_547 captions-foreground-color-plVideoModal_component_547-Magenta">Magenta</option><option id="captions-foreground-color-plVideoModal_component_547-Cyan" value="#0FF" aria-labelledby="captions-text-legend-plVideoModal_component_547 captions-foreground-color-plVideoModal_component_547 captions-foreground-color-plVideoModal_component_547-Cyan">Cyan</option></select><span class="vjs-text-opacity vjs-opacity"><label id="captions-foreground-opacity-plVideoModal_component_547" class="vjs-label">Transparency</label><select aria-labelledby="captions-text-legend-plVideoModal_component_547 captions-foreground-opacity-plVideoModal_component_547"><option id="captions-foreground-opacity-plVideoModal_component_547-Opaque" value="1" aria-labelledby="captions-text-legend-plVideoModal_component_547 captions-foreground-opacity-plVideoModal_component_547 captions-foreground-opacity-plVideoModal_component_547-Opaque">Opaque</option><option id="captions-foreground-opacity-plVideoModal_component_547-SemiTransparent" value="0.5" aria-labelledby="captions-text-legend-plVideoModal_component_547 captions-foreground-opacity-plVideoModal_component_547 captions-foreground-opacity-plVideoModal_component_547-SemiTransparent">Semi-Transparent</option></select></span></fieldset><fieldset class="vjs-bg-color vjs-track-setting"><legend id="captions-background-plVideoModal_component_547">Background</legend><label id="captions-background-color-plVideoModal_component_547" class="vjs-label">Color</label><select aria-labelledby="captions-background-plVideoModal_component_547 captions-background-color-plVideoModal_component_547"><option id="captions-background-color-plVideoModal_component_547-Black" value="#000" aria-labelledby="captions-background-plVideoModal_component_547 captions-background-color-plVideoModal_component_547 captions-background-color-plVideoModal_component_547-Black">Black</option><option id="captions-background-color-plVideoModal_component_547-White" value="#FFF" aria-labelledby="captions-background-plVideoModal_component_547 captions-background-color-plVideoModal_component_547 captions-background-color-plVideoModal_component_547-White">White</option><option id="captions-background-color-plVideoModal_component_547-Red" value="#F00" aria-labelledby="captions-background-plVideoModal_component_547 captions-background-color-plVideoModal_component_547 captions-background-color-plVideoModal_component_547-Red">Red</option><option id="captions-background-color-plVideoModal_component_547-Green" value="#0F0" aria-labelledby="captions-background-plVideoModal_component_547 captions-background-color-plVideoModal_component_547 captions-background-color-plVideoModal_component_547-Green">Green</option><option id="captions-background-color-plVideoModal_component_547-Blue" value="#00F" aria-labelledby="captions-background-plVideoModal_component_547 captions-background-color-plVideoModal_component_547 captions-background-color-plVideoModal_component_547-Blue">Blue</option><option id="captions-background-color-plVideoModal_component_547-Yellow" value="#FF0" aria-labelledby="captions-background-plVideoModal_component_547 captions-background-color-plVideoModal_component_547 captions-background-color-plVideoModal_component_547-Yellow">Yellow</option><option id="captions-background-color-plVideoModal_component_547-Magenta" value="#F0F" aria-labelledby="captions-background-plVideoModal_component_547 captions-background-color-plVideoModal_component_547 captions-background-color-plVideoModal_component_547-Magenta">Magenta</option><option id="captions-background-color-plVideoModal_component_547-Cyan" value="#0FF" aria-labelledby="captions-background-plVideoModal_component_547 captions-background-color-plVideoModal_component_547 captions-background-color-plVideoModal_component_547-Cyan">Cyan</option></select><span class="vjs-bg-opacity vjs-opacity"><label id="captions-background-opacity-plVideoModal_component_547" class="vjs-label">Transparency</label><select aria-labelledby="captions-background-plVideoModal_component_547 captions-background-opacity-plVideoModal_component_547"><option id="captions-background-opacity-plVideoModal_component_547-Opaque" value="1" aria-labelledby="captions-background-plVideoModal_component_547 captions-background-opacity-plVideoModal_component_547 captions-background-opacity-plVideoModal_component_547-Opaque">Opaque</option><option id="captions-background-opacity-plVideoModal_component_547-SemiTransparent" value="0.5" aria-labelledby="captions-background-plVideoModal_component_547 captions-background-opacity-plVideoModal_component_547 captions-background-opacity-plVideoModal_component_547-SemiTransparent">Semi-Transparent</option><option id="captions-background-opacity-plVideoModal_component_547-Transparent" value="0" aria-labelledby="captions-background-plVideoModal_component_547 captions-background-opacity-plVideoModal_component_547 captions-background-opacity-plVideoModal_component_547-Transparent">Transparent</option></select></span></fieldset><fieldset class="vjs-window-color vjs-track-setting"><legend id="captions-window-plVideoModal_component_547">Window</legend><label id="captions-window-color-plVideoModal_component_547" class="vjs-label">Color</label><select aria-labelledby="captions-window-plVideoModal_component_547 captions-window-color-plVideoModal_component_547"><option id="captions-window-color-plVideoModal_component_547-Black" value="#000" aria-labelledby="captions-window-plVideoModal_component_547 captions-window-color-plVideoModal_component_547 captions-window-color-plVideoModal_component_547-Black">Black</option><option id="captions-window-color-plVideoModal_component_547-White" value="#FFF" aria-labelledby="captions-window-plVideoModal_component_547 captions-window-color-plVideoModal_component_547 captions-window-color-plVideoModal_component_547-White">White</option><option id="captions-window-color-plVideoModal_component_547-Red" value="#F00" aria-labelledby="captions-window-plVideoModal_component_547 captions-window-color-plVideoModal_component_547 captions-window-color-plVideoModal_component_547-Red">Red</option><option id="captions-window-color-plVideoModal_component_547-Green" value="#0F0" aria-labelledby="captions-window-plVideoModal_component_547 captions-window-color-plVideoModal_component_547 captions-window-color-plVideoModal_component_547-Green">Green</option><option id="captions-window-color-plVideoModal_component_547-Blue" value="#00F" aria-labelledby="captions-window-plVideoModal_component_547 captions-window-color-plVideoModal_component_547 captions-window-color-plVideoModal_component_547-Blue">Blue</option><option id="captions-window-color-plVideoModal_component_547-Yellow" value="#FF0" aria-labelledby="captions-window-plVideoModal_component_547 captions-window-color-plVideoModal_component_547 captions-window-color-plVideoModal_component_547-Yellow">Yellow</option><option id="captions-window-color-plVideoModal_component_547-Magenta" value="#F0F" aria-labelledby="captions-window-plVideoModal_component_547 captions-window-color-plVideoModal_component_547 captions-window-color-plVideoModal_component_547-Magenta">Magenta</option><option id="captions-window-color-plVideoModal_component_547-Cyan" value="#0FF" aria-labelledby="captions-window-plVideoModal_component_547 captions-window-color-plVideoModal_component_547 captions-window-color-plVideoModal_component_547-Cyan">Cyan</option></select><span class="vjs-window-opacity vjs-opacity"><label id="captions-window-opacity-plVideoModal_component_547" class="vjs-label">Transparency</label><select aria-labelledby="captions-window-plVideoModal_component_547 captions-window-opacity-plVideoModal_component_547"><option id="captions-window-opacity-plVideoModal_component_547-Transparent" value="0" aria-labelledby="captions-window-plVideoModal_component_547 captions-window-opacity-plVideoModal_component_547 captions-window-opacity-plVideoModal_component_547-Transparent">Transparent</option><option id="captions-window-opacity-plVideoModal_component_547-SemiTransparent" value="0.5" aria-labelledby="captions-window-plVideoModal_component_547 captions-window-opacity-plVideoModal_component_547 captions-window-opacity-plVideoModal_component_547-SemiTransparent">Semi-Transparent</option><option id="captions-window-opacity-plVideoModal_component_547-Opaque" value="1" aria-labelledby="captions-window-plVideoModal_component_547 captions-window-opacity-plVideoModal_component_547 captions-window-opacity-plVideoModal_component_547-Opaque">Opaque</option></select></span></fieldset></div><div class="vjs-track-settings-font"><fieldset class="vjs-font-percent vjs-track-setting"><legend id="captions-font-size-plVideoModal_component_547" class="">Font Size</legend><select aria-labelledby="captions-font-size-plVideoModal_component_547"><option id="captions-font-size-plVideoModal_component_547-50" value="0.50" aria-labelledby="captions-font-size-plVideoModal_component_547 captions-font-size-plVideoModal_component_547-50">50%</option><option id="captions-font-size-plVideoModal_component_547-75" value="0.75" aria-labelledby="captions-font-size-plVideoModal_component_547 captions-font-size-plVideoModal_component_547-75">75%</option><option id="captions-font-size-plVideoModal_component_547-100" value="1.00" aria-labelledby="captions-font-size-plVideoModal_component_547 captions-font-size-plVideoModal_component_547-100">100%</option><option id="captions-font-size-plVideoModal_component_547-125" value="1.25" aria-labelledby="captions-font-size-plVideoModal_component_547 captions-font-size-plVideoModal_component_547-125">125%</option><option id="captions-font-size-plVideoModal_component_547-150" value="1.50" aria-labelledby="captions-font-size-plVideoModal_component_547 captions-font-size-plVideoModal_component_547-150">150%</option><option id="captions-font-size-plVideoModal_component_547-175" value="1.75" aria-labelledby="captions-font-size-plVideoModal_component_547 captions-font-size-plVideoModal_component_547-175">175%</option><option id="captions-font-size-plVideoModal_component_547-200" value="2.00" aria-labelledby="captions-font-size-plVideoModal_component_547 captions-font-size-plVideoModal_component_547-200">200%</option><option id="captions-font-size-plVideoModal_component_547-300" value="3.00" aria-labelledby="captions-font-size-plVideoModal_component_547 captions-font-size-plVideoModal_component_547-300">300%</option><option id="captions-font-size-plVideoModal_component_547-400" value="4.00" aria-labelledby="captions-font-size-plVideoModal_component_547 captions-font-size-plVideoModal_component_547-400">400%</option></select></fieldset><fieldset class="vjs-edge-style vjs-track-setting"><legend id="plVideoModal_component_547" class="">Text Edge Style</legend><select aria-labelledby="plVideoModal_component_547"><option id="plVideoModal_component_547-None" value="none" aria-labelledby="plVideoModal_component_547 plVideoModal_component_547-None">None</option><option id="plVideoModal_component_547-Raised" value="raised" aria-labelledby="plVideoModal_component_547 plVideoModal_component_547-Raised">Raised</option><option id="plVideoModal_component_547-Depressed" value="depressed" aria-labelledby="plVideoModal_component_547 plVideoModal_component_547-Depressed">Depressed</option><option id="plVideoModal_component_547-Uniform" value="uniform" aria-labelledby="plVideoModal_component_547 plVideoModal_component_547-Uniform">Uniform</option><option id="plVideoModal_component_547-Dropshadow" value="dropshadow" aria-labelledby="plVideoModal_component_547 plVideoModal_component_547-Dropshadow">Dropshadow</option></select></fieldset><fieldset class="vjs-font-family vjs-track-setting"><legend id="captions-font-family-plVideoModal_component_547" class="">Font Family</legend><select aria-labelledby="captions-font-family-plVideoModal_component_547"><option id="captions-font-family-plVideoModal_component_547-ProportionalSansSerif" value="proportionalSansSerif" aria-labelledby="captions-font-family-plVideoModal_component_547 captions-font-family-plVideoModal_component_547-ProportionalSansSerif">Proportional Sans-Serif</option><option id="captions-font-family-plVideoModal_component_547-MonospaceSansSerif" value="monospaceSansSerif" aria-labelledby="captions-font-family-plVideoModal_component_547 captions-font-family-plVideoModal_component_547-MonospaceSansSerif">Monospace Sans-Serif</option><option id="captions-font-family-plVideoModal_component_547-ProportionalSerif" value="proportionalSerif" aria-labelledby="captions-font-family-plVideoModal_component_547 captions-font-family-plVideoModal_component_547-ProportionalSerif">Proportional Serif</option><option id="captions-font-family-plVideoModal_component_547-MonospaceSerif" value="monospaceSerif" aria-labelledby="captions-font-family-plVideoModal_component_547 captions-font-family-plVideoModal_component_547-MonospaceSerif">Monospace Serif</option><option id="captions-font-family-plVideoModal_component_547-Casual" value="casual" aria-labelledby="captions-font-family-plVideoModal_component_547 captions-font-family-plVideoModal_component_547-Casual">Casual</option><option id="captions-font-family-plVideoModal_component_547-Script" value="script" aria-labelledby="captions-font-family-plVideoModal_component_547 captions-font-family-plVideoModal_component_547-Script">Script</option><option id="captions-font-family-plVideoModal_component_547-SmallCaps" value="small-caps" aria-labelledby="captions-font-family-plVideoModal_component_547 captions-font-family-plVideoModal_component_547-SmallCaps">Small Caps</option></select></fieldset></div><div class="vjs-track-settings-controls"><button type="button" class="vjs-default-button" title="restore all settings to the default values">Reset<span class="vjs-control-text"> restore all settings to the default values</span></button><button type="button" class="vjs-done-button">Done</button></div></div><button class="vjs-close-button vjs-control vjs-button" type="button" title="Close Modal Dialog" aria-disabled="false"><span class="vjs-icon-placeholder" aria-hidden="true"></span><span class="vjs-control-text" aria-live="polite">Close Modal Dialog</span></button><p class="vjs-control-text">End of dialog window.</p></div><div class="vjs-player-info-modal vjs-modal-dialog vjs-hidden " tabindex="-1" aria-describedby="plVideoModal_component_823_description" aria-hidden="true" aria-label="Player Information Dialog" role="dialog"><button class="vjs-close-button vjs-control vjs-button" type="button" title="Close Modal Dialog" aria-disabled="false"><span class="vjs-icon-placeholder" aria-hidden="true"></span><span class="vjs-control-text" aria-live="polite">Close Modal Dialog</span></button><p class="vjs-modal-dialog-description vjs-control-text" id="plVideoModal_component_823_description">This is a modal window. This modal can be closed by pressing the Escape key or activating the close button.</p><div class="vjs-modal-dialog-content" role="document"></div></div></div>

			<div class="modalCaption">
			    <div class="videoDescription"></div>
			    <div class="videoDate"></div>
					<div class="audioDesc"></div>
                    <div class="closedCaption"></div>
			</div>
			<div class="videoSocialShare" data-render="pagehover" data-open="true"></div>
		</div>
	</div>
</div></div></div>
    <header class="masthead">
	
<a class="skipTo" href="#mainNav">Skip to main navigation</a>
<a class="skipTo" href="#mainContent">Skip to main content</a>

<nav class="clubNavigation" data-script="pl_global-header" role="menubar">

    <div class="clubSitesHeading">
        <!-- TO-TRANSLATE -->
        <h4>Club Sites<div class="icon"></div></h4>
    </div>
    <ul class="clubList" role="menu">
                <li>
                    <a target="_blank" href="        https://www.afcb.co.uk/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
" role="menuitem">
                        <div class="badge badge--small badge-image-container" data-widget="club-badge-image" data-size="25">
                            <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t91.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t91@x2.png 2x">
                        </div>
                        <div class="badge badge--large badge-image-container" data-widget="club-badge-image" data-size="50">
                            <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t91.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t91@x2.png 2x">
                            <span class="visuallyHidden">AFC Bournemouth</span>
                        </div>
                        <span class="name">AFC Bournemouth</span>
                    </a>
                </li>
                <li>
                    <a target="_blank" href="        http://www.arsenal.com?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
" role="menuitem">
                        <div class="badge badge--small badge-image-container" data-widget="club-badge-image" data-size="25">
                            <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t3.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t3@x2.png 2x">
                        </div>
                        <div class="badge badge--large badge-image-container" data-widget="club-badge-image" data-size="50">
                            <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t3.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t3@x2.png 2x">
                            <span class="visuallyHidden">Arsenal</span>
                        </div>
                        <span class="name">Arsenal</span>
                    </a>
                </li>
                <li>
                    <a target="_blank" href="        https://www.avfc.co.uk/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
" role="menuitem">
                        <div class="badge badge--small badge-image-container" data-widget="club-badge-image" data-size="25">
                            <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t7.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t7@x2.png 2x">
                        </div>
                        <div class="badge badge--large badge-image-container" data-widget="club-badge-image" data-size="50">
                            <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t7.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t7@x2.png 2x">
                            <span class="visuallyHidden">Aston Villa</span>
                        </div>
                        <span class="name">Aston Villa</span>
                    </a>
                </li>
                <li>
                    <a target="_blank" href="        https://www.brentfordfc.com/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
" role="menuitem">
                        <div class="badge badge--small badge-image-container" data-widget="club-badge-image" data-size="25">
                            <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t94.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t94@x2.png 2x">
                        </div>
                        <div class="badge badge--large badge-image-container" data-widget="club-badge-image" data-size="50">
                            <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t94.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t94@x2.png 2x">
                            <span class="visuallyHidden">Brentford</span>
                        </div>
                        <span class="name">Brentford</span>
                    </a>
                </li>
                <li>
                    <a target="_blank" href="        https://www.brightonandhovealbion.com?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
" role="menuitem">
                        <div class="badge badge--small badge-image-container" data-widget="club-badge-image" data-size="25">
                            <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t36.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t36@x2.png 2x">
                        </div>
                        <div class="badge badge--large badge-image-container" data-widget="club-badge-image" data-size="50">
                            <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t36.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t36@x2.png 2x">
                            <span class="visuallyHidden">Brighton &amp; Hove Albion</span>
                        </div>
                        <span class="name">Brighton &amp; Hove Albion</span>
                    </a>
                </li>
                <li>
                    <a target="_blank" href="        https://www.chelseafc.com/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
" role="menuitem">
                        <div class="badge badge--small badge-image-container" data-widget="club-badge-image" data-size="25">
                            <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t8.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t8@x2.png 2x">
                        </div>
                        <div class="badge badge--large badge-image-container" data-widget="club-badge-image" data-size="50">
                            <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t8.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t8@x2.png 2x">
                            <span class="visuallyHidden">Chelsea</span>
                        </div>
                        <span class="name">Chelsea</span>
                    </a>
                </li>
                <li>
                    <a target="_blank" href="        http://www.cpfc.co.uk/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
" role="menuitem">
                        <div class="badge badge--small badge-image-container" data-widget="club-badge-image" data-size="25">
                            <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t31.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t31@x2.png 2x">
                        </div>
                        <div class="badge badge--large badge-image-container" data-widget="club-badge-image" data-size="50">
                            <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t31.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t31@x2.png 2x">
                            <span class="visuallyHidden">Crystal Palace</span>
                        </div>
                        <span class="name">Crystal Palace</span>
                    </a>
                </li>
                <li>
                    <a target="_blank" href="        http://www.evertonfc.com/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
" role="menuitem">
                        <div class="badge badge--small badge-image-container" data-widget="club-badge-image" data-size="25">
                            <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t11.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t11@x2.png 2x">
                        </div>
                        <div class="badge badge--large badge-image-container" data-widget="club-badge-image" data-size="50">
                            <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t11.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t11@x2.png 2x">
                            <span class="visuallyHidden">Everton </span>
                        </div>
                        <span class="name">Everton </span>
                    </a>
                </li>
                <li>
                    <a target="_blank" href="        https://www.fulhamfc.com/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
" role="menuitem">
                        <div class="badge badge--small badge-image-container" data-widget="club-badge-image" data-size="25">
                            <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t54.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t54@x2.png 2x">
                        </div>
                        <div class="badge badge--large badge-image-container" data-widget="club-badge-image" data-size="50">
                            <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t54.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t54@x2.png 2x">
                            <span class="visuallyHidden">Fulham</span>
                        </div>
                        <span class="name">Fulham</span>
                    </a>
                </li>
                <li>
                    <a target="_blank" href="        https://www.leedsunited.com/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
" role="menuitem">
                        <div class="badge badge--small badge-image-container" data-widget="club-badge-image" data-size="25">
                            <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t2.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t2@x2.png 2x">
                        </div>
                        <div class="badge badge--large badge-image-container" data-widget="club-badge-image" data-size="50">
                            <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t2.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t2@x2.png 2x">
                            <span class="visuallyHidden">Leeds United</span>
                        </div>
                        <span class="name">Leeds United</span>
                    </a>
                </li>
                <li>
                    <a target="_blank" href="        http://www.lcfc.com/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
" role="menuitem">
                        <div class="badge badge--small badge-image-container" data-widget="club-badge-image" data-size="25">
                            <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t13.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t13@x2.png 2x">
                        </div>
                        <div class="badge badge--large badge-image-container" data-widget="club-badge-image" data-size="50">
                            <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t13.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t13@x2.png 2x">
                            <span class="visuallyHidden">Leicester City</span>
                        </div>
                        <span class="name">Leicester City</span>
                    </a>
                </li>
                <li>
                    <a target="_blank" href="        http://www.liverpoolfc.com/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
" role="menuitem">
                        <div class="badge badge--small badge-image-container" data-widget="club-badge-image" data-size="25">
                            <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t14@x2.png 2x">
                        </div>
                        <div class="badge badge--large badge-image-container" data-widget="club-badge-image" data-size="50">
                            <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t14@x2.png 2x">
                            <span class="visuallyHidden">Liverpool</span>
                        </div>
                        <span class="name">Liverpool</span>
                    </a>
                </li>
                <li>
                    <a target="_blank" href="        https://www.mancity.com?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
" role="menuitem">
                        <div class="badge badge--small badge-image-container" data-widget="club-badge-image" data-size="25">
                            <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t43.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t43@x2.png 2x">
                        </div>
                        <div class="badge badge--large badge-image-container" data-widget="club-badge-image" data-size="50">
                            <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t43.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t43@x2.png 2x">
                            <span class="visuallyHidden">Manchester City</span>
                        </div>
                        <span class="name">Manchester City</span>
                    </a>
                </li>
                <li>
                    <a target="_blank" href="        http://www.manutd.com/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
" role="menuitem">
                        <div class="badge badge--small badge-image-container" data-widget="club-badge-image" data-size="25">
                            <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t1.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t1@x2.png 2x">
                        </div>
                        <div class="badge badge--large badge-image-container" data-widget="club-badge-image" data-size="50">
                            <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t1.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t1@x2.png 2x">
                            <span class="visuallyHidden">Manchester United</span>
                        </div>
                        <span class="name">Manchester United</span>
                    </a>
                </li>
                <li>
                    <a target="_blank" href="        https://www.nufc.co.uk/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
" role="menuitem">
                        <div class="badge badge--small badge-image-container" data-widget="club-badge-image" data-size="25">
                            <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t4.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t4@x2.png 2x">
                        </div>
                        <div class="badge badge--large badge-image-container" data-widget="club-badge-image" data-size="50">
                            <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t4.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t4@x2.png 2x">
                            <span class="visuallyHidden">Newcastle United</span>
                        </div>
                        <span class="name">Newcastle United</span>
                    </a>
                </li>
                <li>
                    <a target="_blank" href="        https://www.nottinghamforest.co.uk/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
" role="menuitem">
                        <div class="badge badge--small badge-image-container" data-widget="club-badge-image" data-size="25">
                            <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t17.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t17@x2.png 2x">
                        </div>
                        <div class="badge badge--large badge-image-container" data-widget="club-badge-image" data-size="50">
                            <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t17.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t17@x2.png 2x">
                            <span class="visuallyHidden">Nottingham Forest</span>
                        </div>
                        <span class="name">Nottingham Forest</span>
                    </a>
                </li>
                <li>
                    <a target="_blank" href="        https://www.southamptonfc.com/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
" role="menuitem">
                        <div class="badge badge--small badge-image-container" data-widget="club-badge-image" data-size="25">
                            <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t20.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t20@x2.png 2x">
                        </div>
                        <div class="badge badge--large badge-image-container" data-widget="club-badge-image" data-size="50">
                            <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t20.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t20@x2.png 2x">
                            <span class="visuallyHidden">Southampton</span>
                        </div>
                        <span class="name">Southampton</span>
                    </a>
                </li>
                <li>
                    <a target="_blank" href="        http://www.tottenhamhotspur.com/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
" role="menuitem">
                        <div class="badge badge--small badge-image-container" data-widget="club-badge-image" data-size="25">
                            <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t6.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t6@x2.png 2x">
                        </div>
                        <div class="badge badge--large badge-image-container" data-widget="club-badge-image" data-size="50">
                            <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t6.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t6@x2.png 2x">
                            <span class="visuallyHidden">Tottenham Hotspur</span>
                        </div>
                        <span class="name">Tottenham Hotspur</span>
                    </a>
                </li>
                <li>
                    <a target="_blank" href="        http://www.whufc.com/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
" role="menuitem">
                        <div class="badge badge--small badge-image-container" data-widget="club-badge-image" data-size="25">
                            <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t21.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t21@x2.png 2x">
                        </div>
                        <div class="badge badge--large badge-image-container" data-widget="club-badge-image" data-size="50">
                            <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t21.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t21@x2.png 2x">
                            <span class="visuallyHidden">West Ham United</span>
                        </div>
                        <span class="name">West Ham United</span>
                    </a>
                </li>
                <li>
                    <a target="_blank" href="        https://www.wolves.co.uk/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
" role="menuitem">
                        <div class="badge badge--small badge-image-container" data-widget="club-badge-image" data-size="25">
                            <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t39.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t39@x2.png 2x">
                        </div>
                        <div class="badge badge--large badge-image-container" data-widget="club-badge-image" data-size="50">
                            <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t39.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t39@x2.png 2x">
                            <span class="visuallyHidden">Wolverhampton Wanderers</span>
                        </div>
                        <span class="name">Wolverhampton Wanderers</span>
                    </a>
                </li>
    </ul>
</nav>


    <div class="fixedContainer fixed">
        <a href="https://www.premierleague.com/home" class="u-hide-tab logoContainer" aria-label="Premier League Home Page on logo link" style="height: 60px;">
            <svg class="logo" version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px" viewBox="0 0
                c0,0-0.6-3.6-3.6-6.9l-6.5,0.2c0,0-8.9,7.5-14.2,7.7c0,0,3,5.6,4.5,8.4c3-0.6,8.1-3,10.3-5.4c0,0,1.4,4.5,1.1,9.8
                C103.2,117.4,107.3,112.8,108.6,105.5z M111.3,76.7c-3.3,2.7-6,4.4-6,4.4v8.7c2.4,2.6,4.7,4.8,6.5,8.7
                C115.1,92.7,114.3,84,111.3,76.7z"></path>
            </svg>
            <div class="logoBackground"></div>
            <span class="mobile"><img src="/resources/prod/v6.98.1-4068/i/elements/premier-league-logo-header-mob.svg" alt="Premier League Logo"></span>
        </a>
        <div class="navContainer" data-script="pl_global-header">
            <section id="mainNav" class="navBar" role="menubar">
                <div class="menuBtn" role="button" id="hamburgerToggle" aria-expanded="false">
                    <div class="menuBtnContainer">
                        <div></div>
                        <div></div>
                        <div></div>
                    </div>
                </div>

                <nav class="mainNav">
                    <ul class="pageLinks" role="menu">
    <li class=" premierleague 
    " tabindex="0" aria-haspopup="true" role="menuitem">

        <div role="button" class="navLink active  " tabindex="index">
            <span class="navText">Premier League</span>
                <span class="icn chevron-dropdown"></span>
        </div>

            <div class="dropdown " aria-hidden="true">
                <ul role="menu">
                        <li tabindex="-1">
                            <a tabindex="0" href="/" role="menuitem">
                            Home
                            </a>
                        </li>
                        <li tabindex="-1">
                            <a tabindex="0" href="/fixtures" role="menuitem">
                            Fixtures
                            </a>
                        </li>
                        <li tabindex="-1">
                            <a tabindex="0" href="/results" role="menuitem">
                            Results
                            </a>
                        </li>
                        <li tabindex="-1">
                            <a tabindex="0" href="/tables" role="menuitem">
                            Tables
                            </a>
                        </li>
                        <li tabindex="-1">
                            <a tabindex="0" href="/awards" role="menuitem">
                            Awards
                            </a>
                        </li>
                        <li tabindex="-1">
                            <a tabindex="0" href="/hall-of-fame" role="menuitem">
                            Hall of Fame
                            </a>
                        </li>
                        <li tabindex="-1">
                            <a tabindex="0" href="/transfers" role="menuitem">
                            Transfers
                            </a>
                        </li>
                        <li tabindex="-1">
                            <a tabindex="0" href="/broadcast-schedules" role="menuitem">
                            Broadcast
                            </a>
                        </li>
                        <li tabindex="-1">
                            <a tabindex="0" href="/tickets" role="menuitem">
                            Tickets
                            </a>
                        </li>
                        <li tabindex="-1">
                            <a tabindex="0" href="/clubs" role="menuitem">
                            Clubs
                            </a>
                        </li>
                        <li tabindex="-1">
                            <a tabindex="0" href="/players" role="menuitem">
                            Players
                            </a>
                        </li>
                        <li tabindex="-1">
                            <a tabindex="0" href="/managers" role="menuitem">
                            Managers
                            </a>
                        </li>
                        <li tabindex="-1">
                            <a tabindex="0" href="/news" role="menuitem">
                            News
                            </a>
                        </li>
                        <li tabindex="-1">
                            <a tabindex="0" href="/social" role="menuitem">
                            Social
                            </a>
                        </li>
                        <li tabindex="-1">
                            <a tabindex="0" href="/youth" role="menuitem">
                            Youth
                            </a>
                        </li>
                        <li tabindex="-1">
                            <a tabindex="0" href="/safeguarding" role="menuitem">
                            Safeguarding
                            </a>
                        </li>
                        <li tabindex="-1">
                            <a tabindex="0" href="/history" role="menuitem">
                            History
                            </a>
                        </li>
                        <li tabindex="-1">
                            <a tabindex="0" href="/referees/overview" role="menuitem">
                            Referees
                            </a>
                        </li>
                </ul>
            </div>
    </li>
    <li class=" fantasy 
    " role="menuitem">

        <div role="button" class="navLink   " tabindex="index">
            <span class="navText">Fantasy</span>
                <span class="icn chevron-dropdown"></span>
        </div>

            <div class="dropdown " aria-hidden="true">
                <ul role="menu">
                        <li tabindex="-1">
                            <a tabindex="0" href="/fantasy" role="menuitem">
                            Fantasy
                            </a>
                        </li>
                        <li tabindex="-1">
                            <a tabindex="0" href="/draft" role="menuitem">
                            Fantasy Draft
                            </a>
                        </li>
                </ul>
            </div>
    </li>
    <li class=" video 
    " role="menuitem">
            <a href="/video" data-link-index="2" class="navLink " role="menuitem">
                Video
            </a>

        <div role="button" class="navLink  mobile " tabindex="index">
            <span class="navText">Video</span>
                <span class="icn chevron-dropdown"></span>
        </div>

            <div class="dropdown  dropdownMobile" aria-hidden="true">
                <ul role="menu">
                        <li tabindex="-1">
                            <a tabindex="0" href="/video" role="menuitem">
                            Dashboard
                            </a>
                        </li>
                        <li tabindex="-1">
                            <a tabindex="0" href="/video/fantasy" role="menuitem">
                            Fantasy
                            </a>
                        </li>
                        <li tabindex="-1">
                            <a tabindex="0" href="/video/playlists" role="menuitem">
                            Playlists
                            </a>
                        </li>
                        <li tabindex="-1">
                            <a tabindex="0" href="/video/all" role="menuitem">
                            All Videos
                            </a>
                        </li>
                </ul>
            </div>
    </li>
    <li class=" communities 
    " tabindex="0" role="menuitem">

        <div role="button" class="navLink   " tabindex="index">
            <span class="navText">Communities</span>
                <span class="icn chevron-dropdown"></span>
        </div>

            <div class="dropdown " aria-hidden="true">
                <ul role="menu">
                        <li tabindex="-1">
                            <a tabindex="0" href="/communities" role="menuitem">
                            Latest
                            </a>
                        </li>
                        <li tabindex="-1">
                            <a tabindex="0" href="/communities/strategy" role="menuitem">
                            Strategy
                            </a>
                        </li>
                        <li tabindex="-1">
                            <a tabindex="0" href="/communities/programmes" role="menuitem">
                            Programmes
                            </a>
                        </li>
                        <li tabindex="-1">
                            <a tabindex="0" href="/communities/facilities" role="menuitem">
                            Facilities
                            </a>
                        </li>
                        <li tabindex="-1">
                            <a tabindex="0" href="/communities/plcf" role="menuitem">
                            PL Charitable Fund
                            </a>
                        </li>
                        <li tabindex="-1">
                            <a tabindex="0" href="/communities/supporting-the-game" role="menuitem">
                            Supporting the Game
                            </a>
                        </li>
                </ul>
            </div>
    </li>
    <li class="show-ms noroomforracism 
    noDrop" role="menuitem">
            <a href="/NoRoomForRacism" data-link-index="23" class="navLink " role="menuitem">
                No Room For Racism
            </a>

        <div role="button" data-nochildrenlink="/NoRoomForRacism" class="navLink   " tabindex="index">
            <span class="navText">No Room For Racism</span>
        </div>

            <div class="dropdown" aria-hidden="true">
            </div>
    </li>




    <li class="more " tabindex="0" aria-haspopup="true" role="menuitem">
        <div role="button" class="navLink ">More<span class="icn chevron-dropdown"></span></div>
        <div class="dropdown" aria-hidden="true">
            <ul role="menu">
                        <li>
                            <a href="/stats" role="menuitem">Stats</a>
                        </li>
                        <li>
                            <a href="/stay-well" role="menuitem">Stay Well</a>
                        </li>
                        <li>
                            <a href="/RainbowLaces" role="menuitem">Rainbow Laces</a>
                        </li>
                        <li>
                            <a href="/king-of-the-match" role="menuitem">King of the Match</a>
                        </li>
                        <li>
                            <a href="/transfers" role="menuitem">Transfers</a>
                        </li>
                        <li>
                            <a href="/VAR" role="menuitem">VAR</a>
                        </li>
                        <li>
                            <a href="/photos" role="menuitem">Photos</a>
                        </li>
                        <li>
                            <a href="/partners" role="menuitem">Partners</a>
                        </li>
                        <li>
                            <a href="/epl" role="menuitem">ePremier League</a>
                        </li>
                        <li>
                            <a href="/about" role="menuitem">About</a>
                        </li>
                        <li>
                            <a href="/season-review" role="menuitem">Season Review</a>
                        </li>
                        <li>
                            <a href="/nike-ball-hub" role="menuitem">Nike Ball Hub</a>
                        </li>
                        <li>
                            <a href="/contact" role="menuitem">Contact Us</a>
                        </li>
                        <li>
                            <a href="/poppy" role="menuitem">Poppy</a>
                        </li>
                        <li>
                            <a href="/asia-trophy" role="menuitem">Asia Trophy</a>
                        </li>
                        <li>
                            <a href="/pl-live" role="menuitem">PL Live</a>
                        </li>
                        <li>
                            <a href="/publications" role="menuitem">Publications</a>
                        </li>
                        <li>
                            <a href="/legal" role="menuitem">Legal</a>
                        </li>
                        <li>
                            <a href="/hall-of-fame" role="menuitem">Hall of Fame</a>
                        </li>
            </ul>
        </div>
    </li>























    <!--TO-TRANSLATE -->
    <li class="clubs" aria-haspopup="true">
        <div role="button" class="navLink clubListMobileButton">Clubs<span class="icn external-w"><span class="visuallyHidden">External Link</span></span></div>
        <div class="dropdown" aria-hidden="true" role="menu">
        </div>
    </li>


                    </ul>
                </nav>
    <div class="navOption search">
        <div class="searchBtn headerSearchButton" role="button" tabindex="0"><span class="visuallyHidden">Search</span><div alt="" class="icn search-w"></div></div>
    </div>

    <a href="https://users.premierleague.com/?redirect_uri=https://www.premierleague.com/&amp;app=pl-web" class="navLink navOption navOption--no-border fantasySignIn" role="button" tabindex="0">
        <span class="fantasySignInLabel">Sign in</span>
    </a>
    <a href="https://users.premierleague.com" class="navLink navOption navOption--no-border fantasySignOut hide" role="button" tabindex="0">
        <span class="fantasyUsername"></span>
    </a>

            <a href="/NoRoomForRacism" class=" noroomforracism hide-ms navLink navOption  " role="button" tabindex="0">
                <div class="icn user-w show-m"></div>
                <span class="featuredLinkTitle">No Room For Racism</span>
            </a>

                <span class="mobile-logo">
                    <a href="https://www.premierleague.com/home" class="u-show-tab" aria-label="Premier League Home Page on logo link">
                        <i class="icn pl-logo-mobile-menu"></i>
                    </a>
                </span>
            </section>
            <div class="searchBar searchBarContainer" data-widget="search-header-redirect" role="search">
                <div class="searchBox">
                    <div class="plSearch">
                        <input id="searchPremierLeagueInput" class="searchInput searchInputContainer" type="text" placeholder="Search Premier League">
                        <label for="searchPremierLeagueInput" class="visuallyHidden">Search Premier League</label>
                        <span class="focusBorder"></span>
                        <span class="searchBtnContainer searchButtonContainer">
                            <input type="submit" class="searchInputBtn" tabindex="0" id="searchPremierLeagueInput" aria-label="Submit search">
                            <span class="btnBg"></span>
                            <span class="icn search-sm"><span class="visuallyHidden">Submit search</span></span>
                        </span>
                    </div>
                </div>
            </div>
            <div class="searchOverlay"></div>
        </div>
    </div>


</header><iframe name="__tcfapiLocator" style="display: none;"></iframe>

<main id="mainContent" tabindex="0">
	
<div class="matchCentre">
        
        
<header class="mcHeader">
    <div class="title">
        <h2>Matchday <strong>Live</strong></h2>
        <div class="sponsor u-hide">BROUGHT TO YOU BY</div>
    </div>

    <div data-script="pl_match-week" data-widget="match-week-poll" data-gameweek="4,291" class="pollContainer">
        <div class="pollsBtn matchWeekPollButton">
            <span class="txt">Fan Polls</span>
            <span class="icn poll-w fanPollQuestionNumberContainer"><span class="questions"><strong class="">1</strong></span></span>
        </div>
        <div class="matchWeekQuestionContainer">
            <div class="matchWeekHeader">
                <div class="pulsepollIcon"></div>
                <h4>Pulse Poll</h4>
                <a class="matchweekOptionsCloseButton">
                    <span class="icn close-w"></span>
                </a>
            </div>
            <div class="allQuestionsContainer"><h3 class="subHeader">Open Questions</h3><ul><li data-id="2933"><div class="question"><span>Will Haaland be in your first FPL team?</span> <span class="icn arrow-right"></span></div></li></ul><h3 class="subHeader">Answered Questions</h3><ul></ul></div>
            <div class="matchweekOptionsContainer" style="display:none;">
                    <div class="matchweekOptionsBackButton"><div class="icn chevron-left-w"></div>Back</div>
                <div class="matchWeekOptionRenderContainer"></div>
            </div>
        </div>
        <div class="underlay"></div>
    </div>

        <div class="dropDown" data-widget="dropdown" tabindex="0" data-listener="true">
            <div class="label">Change Matchweek</div>
            <div class="current">


                            <time>09 Aug - 11 Aug</time>

                    <div class="long">Matchweek 1</div>
                    <div class="short">MW 1</div>
            </div>
            <ul class="dropdownList">

                        <li>
                            <a href="/matchweek/4291/blog?match=true">
                                <div class="weekBtn active" role="button" tabindex="0">
                                        <time>09 Aug - 11 Aug</time>
                                    <div class="week">Matchweek 1</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4292/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>17 Aug - 19 Aug</time>
                                    <div class="week">Matchweek 2</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4293/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>23 Aug - 25 Aug</time>
                                    <div class="week">Matchweek 3</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4294/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>31 Aug - 01 Sep</time>
                                    <div class="week">Matchweek 4</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4295/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>14 Sep - 16 Sep</time>
                                    <div class="week">Matchweek 5</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4296/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>20 Sep - 22 Sep</time>
                                    <div class="week">Matchweek 6</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4297/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>28 Sep - 30 Sep</time>
                                    <div class="week">Matchweek 7</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4298/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>05 Oct - 06 Oct</time>
                                    <div class="week">Matchweek 8</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4299/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>19 Oct - 21 Oct</time>
                                    <div class="week">Matchweek 9</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4300/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>25 Oct - 27 Oct</time>
                                    <div class="week">Matchweek 10</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4301/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>02 Nov - 03 Nov</time>
                                    <div class="week">Matchweek 11</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4302/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>08 Nov - 10 Nov</time>
                                    <div class="week">Matchweek 12</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4303/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>23 Nov - 25 Nov</time>
                                    <div class="week">Matchweek 13</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4304/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>30 Nov - 01 Dec</time>
                                    <div class="week">Matchweek 14</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4305/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>03 Dec - 05 Dec</time>
                                    <div class="week">Matchweek 15</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4306/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>07 Dec - 09 Dec</time>
                                    <div class="week">Matchweek 16</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4307/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>14 Dec - 16 Dec</time>
                                    <div class="week">Matchweek 17</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4308/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>21 Dec - 22 Dec</time>
                                    <div class="week">Matchweek 18</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4309/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>26 Dec - 27 Dec</time>
                                    <div class="week">Matchweek 19</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4310/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>28 Dec - 29 Dec</time>
                                    <div class="week">Matchweek 20</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4311/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>01 Jan - 02 Jan</time>
                                    <div class="week">Matchweek 21</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4312/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>10 Jan - 12 Jan</time>
                                    <div class="week">Matchweek 22</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4313/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>18 Jan - 19 Jan</time>
                                    <div class="week">Matchweek 23</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4314/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>21 Jan - 29 Jan</time>
                                    <div class="week">Matchweek 24</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4315/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>01 Feb - 02 Feb</time>
                                    <div class="week">Matchweek 25</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4316/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>08 Feb - 19 Feb</time>
                                    <div class="week">Matchweek 26</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4317/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>22 Feb - 24 Feb</time>
                                    <div class="week">Matchweek 27</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4318/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>28 Feb - 01 Mar</time>
                                    <div class="week">Matchweek 28</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4319/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>07 Mar - 09 Mar</time>
                                    <div class="week">Matchweek 29</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4320/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>17 Jun - 22 Jun</time>
                                    <div class="week">Matchweek 30</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4321/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>23 Jun - 25 Jun</time>
                                    <div class="week">Matchweek 31</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4322/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>27 Jun - 02 Jul</time>
                                    <div class="week">Matchweek 32</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4323/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>04 Jul - 06 Jul</time>
                                    <div class="week">Matchweek 33</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4324/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>07 Jul - 09 Jul</time>
                                    <div class="week">Matchweek 34</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4325/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>11 Jul - 13 Jul</time>
                                    <div class="week">Matchweek 35</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4326/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>14 Jul - 17 Jul</time>
                                    <div class="week">Matchweek 36</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4327/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>18 Jul - 22 Jul</time>
                                    <div class="week">Matchweek 37</div>
                                </div>
                            </a>
                        </li>


                        <li>
                            <a href="/matchweek/4328/blog?match=true">
                                <div class="weekBtn complete" role="button" tabindex="0">
                                        <time>26 Jul - 26 Jul</time>
                                    <div class="week">Matchweek 38</div>
                                </div>
                            </a>
                        </li>

            </ul>
        </div>
</header>

<!-- /131332370/MatchCentreLeaderboard -->
<div id="div-gpt-ad-1608029112627-0" class="DFP-banner" style="display: none;">
    <script type="text/javascript">
        googletag.cmd.push(function() {

            var mapping = googletag.sizeMapping().
            addSize([0, 0], []).
            addSize([200, 300], [[320, 50], [320, 480]]).
            addSize([450, 300], [[320, 50], [1600, 900]]).
            addSize([750, 300], [[728, 90], [1600, 900]]).
            addSize([990, 300], [[1600, 900],[970, 250], [728,90]]).build();

            googletag.defineSlot('/131332370/MatchCentreLeaderboard', [[320, 50], [728, 90]], 'div-gpt-ad-1608029112627-0').
                defineSizeMapping(mapping).
                addService(googletag.pubads());
            googletag.pubads().enableSingleRequest();
            googletag.pubads().collapseEmptyDivs();
                googletag.pubads().setTargeting('section', [ '46605' ] );
            googletag.enableServices();

            googletag.display('div-gpt-ad-1608029112627-0');

        });
    </script>
<div id="google_ads_iframe_/131332370/MatchCentreLeaderboard_0__container__" style="border: 0pt none; width: 1600px; height: 0px;"></div></div>
<section class="js-kotm-modal kotm-modal" data-home="t14">
    <div class="kotm-modal__container js-kotm-modal-container kotm-modal__container--results">
        <button class="kotm-modal__close js-close">
            <i class="kotm-modal__close-icon icn kotm-close"></i>
            Close
        </button>


        <div class="kotm-voting js-kotm-voting u-hide">
            <i class="icn budweiser kotm-modal__icn"></i>

            <h1 class="kotm-modal__title">King of the match</h1>
            <p class="kotm-modal__subtitle js-prompt">Click a player to cast your vote</p>

            <div class="kotm-players js-players"><div class="col-6 col-6-m col-6-s kotm-players__col "><span class="kotm-players__team u-hide-mob ">Liverpool</span> <span class="kotm-players__team u-show-mob kotm-players__team--mob ">LIV</span><ul><li class="kotm-players__list-item"><button class="kotm-players__item  js-player js-player-p118748" data-player-id="p118748"><span class="kotm-players__name ">Mohamed <strong>Salah</strong></span><div class="kotm-players__img-container "><div class="kotm-players__img-mask"></div><img class="kotm-players__img js-candidate-image" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p118748.png" data-player="p118748"><div class="kotm-players__score js-score">49.8%</div></div></button></li><li class="kotm-players__list-item"><button class="kotm-players__item  js-player js-player-p97032" data-player-id="p97032"><span class="kotm-players__name ">Virgil <strong>van Dijk</strong></span><div class="kotm-players__img-container "><div class="kotm-players__img-mask"></div><img class="kotm-players__img js-candidate-image" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p97032.png" data-player="p97032"><div class="kotm-players__score js-score">17.9%</div></div></button></li><li class="kotm-players__list-item"><button class="kotm-players__item  js-player js-player-p152760" data-player-id="p152760"><span class="kotm-players__name ">Divock <strong>Origi</strong></span><div class="kotm-players__img-container "><div class="kotm-players__img-mask"></div><img class="kotm-players__img js-candidate-image" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p152760.png" data-player="p152760"><div class="kotm-players__score js-score">9.7%</div></div></button></li><li class="kotm-players__list-item"><button class="kotm-players__item  js-player js-player-p92217" data-player-id="p92217"><span class="kotm-players__name ">Roberto <strong>Firmino</strong></span><div class="kotm-players__img-container "><div class="kotm-players__img-mask"></div><img class="kotm-players__img js-candidate-image" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p92217.png" data-player="p92217"><div class="kotm-players__score js-score">9.2%</div></div></button></li><li class="kotm-players__list-item"><button class="kotm-players__item  js-player js-player-p169187" data-player-id="p169187"><span class="kotm-players__name ">Trent <strong>Alexander-Arnold</strong></span><div class="kotm-players__img-container "><div class="kotm-players__img-mask"></div><img class="kotm-players__img js-candidate-image" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p169187.png" data-player="p169187"><div class="kotm-players__score js-score">8.7%</div></div></button></li></ul></div><div class="col-6 col-6-m col-6-s kotm-players__col kotm-players__col--alt kotm-players__col-border"><span class="kotm-players__team u-hide-mob kotm-players__team--alt">Norwich</span> <span class="kotm-players__team u-show-mob kotm-players__team--mob kotm-players__team--alt">NOR</span><ul><li class="kotm-players__list-item"><button class="kotm-players__item kotm-players__item--alt  js-player js-player-p57127" data-player-id="p57127"><span class="kotm-players__name kotm-players__name--alt ">Teemu <strong>Pukki</strong></span><div class="kotm-players__img-container kotm-players__img-container--alt "><div class="kotm-players__img-mask"></div><img class="kotm-players__img js-candidate-image" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p57127.png" data-player="p57127"><div class="kotm-players__score js-score">3.1%</div></div></button></li><li class="kotm-players__list-item"><button class="kotm-players__item kotm-players__item--alt  js-player js-player-p232980" data-player-id="p232980"><span class="kotm-players__name kotm-players__name--alt ">Maximillian <strong>Aarons</strong></span><div class="kotm-players__img-container kotm-players__img-container--alt "><div class="kotm-players__img-mask"></div><img class="kotm-players__img js-candidate-image" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p232980.png" data-player="p232980"><div class="kotm-players__score js-score">1.0%</div></div></button></li><li class="kotm-players__list-item"><button class="kotm-players__item kotm-players__item--alt  js-player js-player-p194799" data-player-id="p194799"><span class="kotm-players__name kotm-players__name--alt ">Jamal <strong>Lewis</strong></span><div class="kotm-players__img-container kotm-players__img-container--alt "><div class="kotm-players__img-mask"></div><img class="kotm-players__img js-candidate-image" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p194799.png" data-player="p194799"><div class="kotm-players__score js-score">0.3%</div></div></button></li><li class="kotm-players__list-item"><button class="kotm-players__item kotm-players__item--alt  js-player js-player-p195546" data-player-id="p195546"><span class="kotm-players__name kotm-players__name--alt ">Emiliano <strong>Buendía</strong></span><div class="kotm-players__img-container kotm-players__img-container--alt "><div class="kotm-players__img-mask"></div><img class="kotm-players__img js-candidate-image" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p195546.png" data-player="p195546"><div class="kotm-players__score js-score">0.2%</div></div></button></li><li class="kotm-players__list-item"><button class="kotm-players__item kotm-players__item--alt  js-player js-player-p198826" data-player-id="p198826"><span class="kotm-players__name kotm-players__name--alt ">Ben <strong>Godfrey</strong></span><div class="kotm-players__img-container kotm-players__img-container--alt "><div class="kotm-players__img-mask"></div><img class="kotm-players__img js-candidate-image" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p198826.png" data-player="p198826"><div class="kotm-players__score js-score">0.1%</div></div></button></li></ul></div></div>

            <div class="kotm-modal__submit-container js-submit-container kotm-modal__submit-container--disabled">
                <button class="kotm-modal__submit js-submit-vote">
                    Submit Vote
                    <i class="kotm-modal__submit-icn icn arrow-rightwhite"></i>
                </button>
            </div>

            <div class="kotm-modal__sponsors">
                <div class="kotm-modal__sponsor-item"></div>
                <div class="kotm-modal__sponsor-item kotm-modal__logo-link kotm-results__logo-link-wrapper">
                    <div class="kotm-results__sponsor-logo icn commercial-official-beer-sponsor"></div>
                    <a target="_blank" href="/kotm-explained" class="kotm-results__link">Budweiser King of the Match explained and statistics<span class="icn arrow-rightwhite"></span></a>
                </div>
                <div class="kotm-modal__sponsor-item kotm-modal__sponsor-item--right">
                    <i class="icn drinkaware u-inline"></i>
                </div>
            </div>

        </div>

        <div class="kotm-results js-kotm-results is-opt-out" data-widget="kotm-results">

            <div class="kotm-results__player-column">
                <i class="icn budweiser kotm-modal__icn"></i>

                <div class="kotm-player kotm-player--large js-kotm-winner-container"><h4 class="kotm-player__first-name">Mohamed</h4><h3 class="kotm-player__second-name">Salah</h3><div class="kotm-player__player-image-wrapper"><img class="kotm-player__player-image js-winner-image kotm-player__player-image--default" data-player="p118748" src="https://resources.premierleague.com/premierleague/photos/players/250x250/p118748.png"></div> <div class="kotm-player__bowtie kotm-player__bowtie--opt-out"><h3 class="kotm-player__bowtie-text">KING OF THE MATCH</h3></div></div>

                <div class="kotm-modal__sponsors">
                    <div class="kotm-modal__sponsor-item kotm-modal__logo-link kotm-results__logo-link-wrapper">
                        <div class="kotm-results__sponsor-logo icn commercial-official-beer-sponsor"></div>
                        <a target="_blank" href="/king-of-the-match" class="kotm-results__link"><span class="kotm-results__bud-link-text">Budweiser King of the Match explained and statistics</span><span class="kotm-results__opt-out-link-text">King of the Match explained and statistics</span><span class="icn arrow-rightwhite"></span></a>
                    </div>
                    <div class="kotm-modal__sponsor-item kotm-modal__sponsor-item--right">
                        <i class="icn drinkaware u-inline"></i>
                    </div>
                </div>
            </div>

            <div class="kotm-results__results-column">
                <div data-script="pl_tabbed" data-widget="tabbed-content" class="tabLinks center" data-tab-class="kotmModalTab" data-tab-wrap=".tabs">
                    <div class="tabs toggle js-kotm-results-tabs"><ul class="tablist" role="tablist"><li role="tab" tabindex="0" data-tab-index="0" class="active">Match Stats</li><li role="tab" tabindex="0" data-tab-index="1">Voting Results</li></ul></div>
                </div>
                <div class="tabbedContent"><div data-ui-tab="Match Stats" class="js-fixture-stats-container kotmModalTab active" data-tab-aware-default="true"><div class="kotm-results__fixture"><div class="kotm-results__fixture-player"><h2>Mohamed</h2><h2>Salah Ghaly</h2><h4>Forward</h4></div><div class="kotm-results__fixture-stats"><div class="kotm-results__fixture-stats-row"><span class="kotm-results__fixture-stats-value">Goals</span> <span class="kotm-results__fixture-stats-value kotm-results__fixture-stats-value--bold">1</span></div><div class="kotm-results__fixture-stats-row"><span class="kotm-results__fixture-stats-value">Assists</span> <span class="kotm-results__fixture-stats-value kotm-results__fixture-stats-value--bold">1</span></div><div class="kotm-results__fixture-stats-row"><span class="kotm-results__fixture-stats-value">Shots on Target</span> <span class="kotm-results__fixture-stats-value kotm-results__fixture-stats-value--bold">1</span></div><div class="kotm-results__fixture-stats-row"><span class="kotm-results__fixture-stats-value">Big Chances Created</span> <span class="kotm-results__fixture-stats-value kotm-results__fixture-stats-value--bold">0</span></div><div class="kotm-results__fixture-stats-row"><span class="kotm-results__fixture-stats-value">Key Passes</span> <span class="kotm-results__fixture-stats-value kotm-results__fixture-stats-value--bold">3</span></div><div class="kotm-results__fixture-stats-row"><span class="kotm-results__fixture-stats-value">Successful Dribbles</span> <span class="kotm-results__fixture-stats-value kotm-results__fixture-stats-value--bold">2</span></div></div><a class="btn widget-button" href="//www.premierleague.com/players/5178/Mohamed-Salah/overview">Player Profile <span class="icn arrow-right"></span></a></div></div><div data-ui-tab="Voting Results" class="js-table-container kotmModalTab"><table class="kotm-results__results-table table"><thead class="kotm-results__results-table-head"><tr><th class="kotm-results__results-table-cell kotm-results__results-table-cell--left" scope="col">Pos</th><th class="kotm-results__results-table-cell kotm-results__results-table-cell--left" scope="col">Player</th><th class="kotm-results__results-table-cell" scope="col">Team</th><th class="kotm-results__results-table-cell kotm-results__results-table-cell--right" scope="col">Votes %</th></tr></thead><tbody><tr><td class="kotm-results__results-table-cell kotm-results__results-table-cell--left" scope="col">1</td><td class="kotm-results__results-table-cell kotm-results__results-table-cell--left" scope="col">Mohamed Salah</td><td class="kotm-results__results-table-cell" scope="col"><span class="kotm-results__results-badge badge badge-image-container" data-widget="club-badge-image" data-size="50"><img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t14.png, https://resources.premierleague.com/premierleague/badges/50/t14@x2.png 2x"></span></td><td class="kotm-results__results-table-cell kotm-results__results-table-cell--right" scope="col">49.8%</td></tr><tr><td class="kotm-results__results-table-cell kotm-results__results-table-cell--left" scope="col">2</td><td class="kotm-results__results-table-cell kotm-results__results-table-cell--left" scope="col">Virgil van Dijk</td><td class="kotm-results__results-table-cell" scope="col"><span class="kotm-results__results-badge badge badge-image-container" data-widget="club-badge-image" data-size="50"><img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t14.png, https://resources.premierleague.com/premierleague/badges/50/t14@x2.png 2x"></span></td><td class="kotm-results__results-table-cell kotm-results__results-table-cell--right" scope="col">17.9%</td></tr><tr><td class="kotm-results__results-table-cell kotm-results__results-table-cell--left" scope="col">3</td><td class="kotm-results__results-table-cell kotm-results__results-table-cell--left" scope="col">Divock Origi</td><td class="kotm-results__results-table-cell" scope="col"><span class="kotm-results__results-badge badge badge-image-container" data-widget="club-badge-image" data-size="50"><img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t14.png, https://resources.premierleague.com/premierleague/badges/50/t14@x2.png 2x"></span></td><td class="kotm-results__results-table-cell kotm-results__results-table-cell--right" scope="col">9.7%</td></tr><tr><td class="kotm-results__results-table-cell kotm-results__results-table-cell--left" scope="col">4</td><td class="kotm-results__results-table-cell kotm-results__results-table-cell--left" scope="col">Roberto Firmino</td><td class="kotm-results__results-table-cell" scope="col"><span class="kotm-results__results-badge badge badge-image-container" data-widget="club-badge-image" data-size="50"><img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t14.png, https://resources.premierleague.com/premierleague/badges/50/t14@x2.png 2x"></span></td><td class="kotm-results__results-table-cell kotm-results__results-table-cell--right" scope="col">9.2%</td></tr><tr><td class="kotm-results__results-table-cell kotm-results__results-table-cell--left" scope="col">5</td><td class="kotm-results__results-table-cell kotm-results__results-table-cell--left" scope="col">Trent Alexander-Arnold</td><td class="kotm-results__results-table-cell" scope="col"><span class="kotm-results__results-badge badge badge-image-container" data-widget="club-badge-image" data-size="50"><img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t14.png, https://resources.premierleague.com/premierleague/badges/50/t14@x2.png 2x"></span></td><td class="kotm-results__results-table-cell kotm-results__results-table-cell--right" scope="col">8.7%</td></tr><tr><td class="kotm-results__results-table-cell kotm-results__results-table-cell--left" scope="col">6</td><td class="kotm-results__results-table-cell kotm-results__results-table-cell--left" scope="col">Teemu Pukki</td><td class="kotm-results__results-table-cell" scope="col"><span class="kotm-results__results-badge badge badge-image-container" data-widget="club-badge-image" data-size="50"><img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t45.png, https://resources.premierleague.com/premierleague/badges/50/t45@x2.png 2x"></span></td><td class="kotm-results__results-table-cell kotm-results__results-table-cell--right" scope="col">3.1%</td></tr><tr><td class="kotm-results__results-table-cell kotm-results__results-table-cell--left" scope="col">7</td><td class="kotm-results__results-table-cell kotm-results__results-table-cell--left" scope="col">Maximillian Aarons</td><td class="kotm-results__results-table-cell" scope="col"><span class="kotm-results__results-badge badge badge-image-container" data-widget="club-badge-image" data-size="50"><img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t45.png, https://resources.premierleague.com/premierleague/badges/50/t45@x2.png 2x"></span></td><td class="kotm-results__results-table-cell kotm-results__results-table-cell--right" scope="col">1.0%</td></tr><tr><td class="kotm-results__results-table-cell kotm-results__results-table-cell--left" scope="col">8</td><td class="kotm-results__results-table-cell kotm-results__results-table-cell--left" scope="col">Jamal Lewis</td><td class="kotm-results__results-table-cell" scope="col"><span class="kotm-results__results-badge badge badge-image-container" data-widget="club-badge-image" data-size="50"><img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t45.png, https://resources.premierleague.com/premierleague/badges/50/t45@x2.png 2x"></span></td><td class="kotm-results__results-table-cell kotm-results__results-table-cell--right" scope="col">0.3%</td></tr><tr><td class="kotm-results__results-table-cell kotm-results__results-table-cell--left" scope="col">9</td><td class="kotm-results__results-table-cell kotm-results__results-table-cell--left" scope="col">Emiliano Buendía</td><td class="kotm-results__results-table-cell" scope="col"><span class="kotm-results__results-badge badge badge-image-container" data-widget="club-badge-image" data-size="50"><img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t45.png, https://resources.premierleague.com/premierleague/badges/50/t45@x2.png 2x"></span></td><td class="kotm-results__results-table-cell kotm-results__results-table-cell--right" scope="col">0.2%</td></tr><tr><td class="kotm-results__results-table-cell kotm-results__results-table-cell--left" scope="col">10</td><td class="kotm-results__results-table-cell kotm-results__results-table-cell--left" scope="col">Ben Godfrey</td><td class="kotm-results__results-table-cell" scope="col"><span class="kotm-results__results-badge badge badge-image-container" data-widget="club-badge-image" data-size="50"><img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t45.png, https://resources.premierleague.com/premierleague/badges/50/t45@x2.png 2x"></span></td><td class="kotm-results__results-table-cell kotm-results__results-table-cell--right" scope="col">0.1%</td></tr></tbody></table><p class="kotm-results__total-results">6374 Total Votes</p></div></div>
                
            </div>
        </div>
    </div>
</section>

            
        <section class="mcContent">

                








<div class="matchWeekNavContainer" data-script="pl_match-week" data-widget="match-week-nav" data-gameweeks="4291" data-sort="ASCENDING" data-auto-url="/match/46605">
    <nav class="mcNav">
        <ul>
               <li class="mcNavLink">
                   <a href="/matchweek/4291/blog" class=" mcNavButton" data-nav-tab-index="1"><span class="nav-icn icn blog-hi"></span>Live Blog<span class="icn chevron-rightblack-normal"></span></a>
              </li>
            <li class="mobileButtonContainer">
                <a href="/matchweek/4291/scores" class=" mcNavButton" data-nav-tab-index="2"><span class="nav-icn icn table-hi"></span>Scores</a>
            </li>
            <li class="mobileButtonContainer">
                <a href="/matchweek/4291/table" class=" mcNavButton" data-nav-tab-index="3"><span class="nav-icn icn table-hi"></span>League Table</a>
            </li>
            <li class="desktopButtonContainer mcNavLink">
                <a href="/matchweek/4291/table" class=" mcNavButton matchWeekTableButton" data-nav-tab-index="3"><span class="nav-icn icn table-hi"></span>League Table<span class="icn chevron-rightblack-normal"></span></a>
            </li>
                <li class="mobileButtonContainer">
                    <a href="/matchweek/4291/latest" class=" mcNavButton" data-nav-tab-index="6"><span class="nav-icn icn news-hi-c"></span>News &amp; Videos<span class="icn chevron-rightblack-normal"></span></a>
                </li>

                <ul class="matchWeekFixtureListContainer matchList ">
                    <div class="navLocalTimeContainer">
                            <p>Latest Results</p>
                    </div>
                <li><div class="mcNavButton dayToggle open mcDayToggleNavContainer">Friday 9 August<span class="icn chevron-downblack-normal"></span></div><ul class="Friday 9 AugustMatchContainer dayList"><a data-kickoff="1565377200000" href="/match/46605" data-id="46605" class="active matchAbridged  fullTime matchWeekMatchContainer">
            <strong class="minutes matchMinuteContainer" role="timer">FT</strong>
        <span class="teamName">
            <abbr title="Liverpool">
                LIV
            </abbr>
        </span>
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                <img class="badge-image badge-image--25" src="https://resources.premierleague.com/premierleague/badges/25/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t14.png, https://resources.premierleague.com/premierleague/badges/25/t14@x2.png 2x">
            </span>
        <span class="matchScoreContainer">
                <span class="score">4<span>-</span>1</span>
        </span>
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                <img class="badge-image badge-image--25" src="https://resources.premierleague.com/premierleague/badges/25/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t45.png, https://resources.premierleague.com/premierleague/badges/25/t45@x2.png 2x">
            </span>
        <span class="teamName">
            <abbr title="Norwich City">
                NOR
            </abbr>
        </span>
        <span class="icn arrow-right"></span>
        <div data-id="46605" data-comp="1" class="mcNavBroadcasterContainer">  <div class="broadcasterContainer "> <span class="logo broadcaster-image-container"><img class="broadcaster-image js-broadcaster-logo" src="https://resources.premierleague.com/premierleague/broadcasters/global/supersa.png" srcset="https://resources.premierleague.com/premierleague/broadcasters/global/supersa.png, https://resources.premierleague.com/premierleague/broadcasters/global/supersa@x2.png 2x"></span></div> </div>
    </a></ul></li><li><div class="mcNavButton dayToggle open mcDayToggleNavContainer">Saturday 10 August<span class="icn chevron-downblack-normal"></span></div><ul class="Saturday 10 AugustMatchContainer dayList"><a data-kickoff="1565436600000" href="/match/46612" data-id="46612" class=" matchAbridged  fullTime matchWeekMatchContainer">
            <strong class="minutes matchMinuteContainer" role="timer">FT</strong>
        <span class="teamName">
            <abbr title="West Ham United">
                WHU
            </abbr>
        </span>
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                <img class="badge-image badge-image--25" src="https://resources.premierleague.com/premierleague/badges/25/t21.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t21.png, https://resources.premierleague.com/premierleague/badges/25/t21@x2.png 2x">
            </span>
        <span class="matchScoreContainer">
                <span class="score">0<span>-</span>5</span>
        </span>
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                <img class="badge-image badge-image--25" src="https://resources.premierleague.com/premierleague/badges/25/t43.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t43.png, https://resources.premierleague.com/premierleague/badges/25/t43@x2.png 2x">
            </span>
        <span class="teamName">
            <abbr title="Manchester City">
                MCI
            </abbr>
        </span>
        <span class="icn arrow-right"></span>
        <div data-id="46612" data-comp="1" class="mcNavBroadcasterContainer">  <div class="broadcasterContainer "> <span class="logo broadcaster-image-container"><img class="broadcaster-image js-broadcaster-logo" src="https://resources.premierleague.com/premierleague/broadcasters/global/supersa.png" srcset="https://resources.premierleague.com/premierleague/broadcasters/global/supersa.png, https://resources.premierleague.com/premierleague/broadcasters/global/supersa@x2.png 2x"></span></div> </div>
    </a><a data-kickoff="1565445600000" href="/match/46606" data-id="46606" class=" matchAbridged  fullTime matchWeekMatchContainer">
            <strong class="minutes matchMinuteContainer" role="timer">FT</strong>
        <span class="teamName">
            <abbr title="AFC Bournemouth">
                BOU
            </abbr>
        </span>
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                <img class="badge-image badge-image--25" src="https://resources.premierleague.com/premierleague/badges/25/t91.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t91.png, https://resources.premierleague.com/premierleague/badges/25/t91@x2.png 2x">
            </span>
        <span class="matchScoreContainer">
                <span class="score">1<span>-</span>1</span>
        </span>
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                <img class="badge-image badge-image--25" src="https://resources.premierleague.com/premierleague/badges/25/t49.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t49.png, https://resources.premierleague.com/premierleague/badges/25/t49@x2.png 2x">
            </span>
        <span class="teamName">
            <abbr title="Sheffield United">
                SHU
            </abbr>
        </span>
        <span class="icn arrow-right"></span>
        <div data-id="46606" data-comp="1" class="mcNavBroadcasterContainer">  <div class="broadcasterContainer "> <span class="logo broadcaster-image-container"><img class="broadcaster-image js-broadcaster-logo" src="https://resources.premierleague.com/premierleague/broadcasters/global/supersa.png" srcset="https://resources.premierleague.com/premierleague/broadcasters/global/supersa.png, https://resources.premierleague.com/premierleague/broadcasters/global/supersa@x2.png 2x"></span></div> </div>
    </a><a data-kickoff="1565445600000" href="/match/46607" data-id="46607" class=" matchAbridged  fullTime matchWeekMatchContainer">
            <strong class="minutes matchMinuteContainer" role="timer">FT</strong>
        <span class="teamName">
            <abbr title="Burnley">
                BUR
            </abbr>
        </span>
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                <img class="badge-image badge-image--25" src="https://resources.premierleague.com/premierleague/badges/25/t90.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t90.png, https://resources.premierleague.com/premierleague/badges/25/t90@x2.png 2x">
            </span>
        <span class="matchScoreContainer">
                <span class="score">3<span>-</span>0</span>
        </span>
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                <img class="badge-image badge-image--25" src="https://resources.premierleague.com/premierleague/badges/25/t20.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t20.png, https://resources.premierleague.com/premierleague/badges/25/t20@x2.png 2x">
            </span>
        <span class="teamName">
            <abbr title="Southampton">
                SOU
            </abbr>
        </span>
        <span class="icn arrow-right"></span>
        <div data-id="46607" data-comp="1" class="mcNavBroadcasterContainer">  <div class="broadcasterContainer "> <span class="logo broadcaster-image-container"><img class="broadcaster-image js-broadcaster-logo" src="https://resources.premierleague.com/premierleague/broadcasters/global/supersa.png" srcset="https://resources.premierleague.com/premierleague/broadcasters/global/supersa.png, https://resources.premierleague.com/premierleague/broadcasters/global/supersa@x2.png 2x"></span></div> </div>
    </a><a data-kickoff="1565445600000" href="/match/46608" data-id="46608" class=" matchAbridged  fullTime matchWeekMatchContainer">
            <strong class="minutes matchMinuteContainer" role="timer">FT</strong>
        <span class="teamName">
            <abbr title="Crystal Palace">
                CRY
            </abbr>
        </span>
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                <img class="badge-image badge-image--25" src="https://resources.premierleague.com/premierleague/badges/25/t31.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t31.png, https://resources.premierleague.com/premierleague/badges/25/t31@x2.png 2x">
            </span>
        <span class="matchScoreContainer">
                <span class="score">0<span>-</span>0</span>
        </span>
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                <img class="badge-image badge-image--25" src="https://resources.premierleague.com/premierleague/badges/25/t11.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t11.png, https://resources.premierleague.com/premierleague/badges/25/t11@x2.png 2x">
            </span>
        <span class="teamName">
            <abbr title="Everton">
                EVE
            </abbr>
        </span>
        <span class="icn arrow-right"></span>
        <div data-id="46608" data-comp="1" class="mcNavBroadcasterContainer">  <div class="broadcasterContainer "> <span class="logo broadcaster-image-container"><img class="broadcaster-image js-broadcaster-logo" src="https://resources.premierleague.com/premierleague/broadcasters/global/supersa.png" srcset="https://resources.premierleague.com/premierleague/broadcasters/global/supersa.png, https://resources.premierleague.com/premierleague/broadcasters/global/supersa@x2.png 2x"></span></div> </div>
    </a><a data-kickoff="1565445600000" href="/match/46611" data-id="46611" class=" matchAbridged  fullTime matchWeekMatchContainer">
            <strong class="minutes matchMinuteContainer" role="timer">FT</strong>
        <span class="teamName">
            <abbr title="Watford">
                WAT
            </abbr>
        </span>
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                <img class="badge-image badge-image--25" src="https://resources.premierleague.com/premierleague/badges/25/t57.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t57.png, https://resources.premierleague.com/premierleague/badges/25/t57@x2.png 2x">
            </span>
        <span class="matchScoreContainer">
                <span class="score">0<span>-</span>3</span>
        </span>
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                <img class="badge-image badge-image--25" src="https://resources.premierleague.com/premierleague/badges/25/t36.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t36.png, https://resources.premierleague.com/premierleague/badges/25/t36@x2.png 2x">
            </span>
        <span class="teamName">
            <abbr title="Brighton and Hove Albion">
                BHA
            </abbr>
        </span>
        <span class="icn arrow-right"></span>
        <div data-id="46611" data-comp="1" class="mcNavBroadcasterContainer">  <div class="broadcasterContainer "> <span class="logo broadcaster-image-container"><img class="broadcaster-image js-broadcaster-logo" src="https://resources.premierleague.com/premierleague/broadcasters/global/supersa.png" srcset="https://resources.premierleague.com/premierleague/broadcasters/global/supersa.png, https://resources.premierleague.com/premierleague/broadcasters/global/supersa@x2.png 2x"></span></div> </div>
    </a><a data-kickoff="1565454600000" href="/match/46610" data-id="46610" class=" matchAbridged  fullTime matchWeekMatchContainer">
            <strong class="minutes matchMinuteContainer" role="timer">FT</strong>
        <span class="teamName">
            <abbr title="Tottenham Hotspur">
                TOT
            </abbr>
        </span>
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                <img class="badge-image badge-image--25" src="https://resources.premierleague.com/premierleague/badges/25/t6.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t6.png, https://resources.premierleague.com/premierleague/badges/25/t6@x2.png 2x">
            </span>
        <span class="matchScoreContainer">
                <span class="score">3<span>-</span>1</span>
        </span>
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                <img class="badge-image badge-image--25" src="https://resources.premierleague.com/premierleague/badges/25/t7.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t7.png, https://resources.premierleague.com/premierleague/badges/25/t7@x2.png 2x">
            </span>
        <span class="teamName">
            <abbr title="Aston Villa">
                AVL
            </abbr>
        </span>
        <span class="icn arrow-right"></span>
        <div data-id="46610" data-comp="1" class="mcNavBroadcasterContainer">  <div class="broadcasterContainer "> <span class="logo broadcaster-image-container"><img class="broadcaster-image js-broadcaster-logo" src="https://resources.premierleague.com/premierleague/broadcasters/global/supersa.png" srcset="https://resources.premierleague.com/premierleague/broadcasters/global/supersa.png, https://resources.premierleague.com/premierleague/broadcasters/global/supersa@x2.png 2x"></span></div> </div>
    </a></ul></li><li><div class="mcNavButton dayToggle open mcDayToggleNavContainer">Sunday 11 August<span class="icn chevron-downblack-normal"></span></div><ul class="Sunday 11 AugustMatchContainer dayList"><a data-kickoff="1565528400000" href="/match/46609" data-id="46609" class=" matchAbridged  fullTime matchWeekMatchContainer">
            <strong class="minutes matchMinuteContainer" role="timer">FT</strong>
        <span class="teamName">
            <abbr title="Leicester City">
                LEI
            </abbr>
        </span>
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                <img class="badge-image badge-image--25" src="https://resources.premierleague.com/premierleague/badges/25/t13.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t13.png, https://resources.premierleague.com/premierleague/badges/25/t13@x2.png 2x">
            </span>
        <span class="matchScoreContainer">
                <span class="score">0<span>-</span>0</span>
        </span>
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                <img class="badge-image badge-image--25" src="https://resources.premierleague.com/premierleague/badges/25/t39.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t39.png, https://resources.premierleague.com/premierleague/badges/25/t39@x2.png 2x">
            </span>
        <span class="teamName">
            <abbr title="Wolverhampton Wanderers">
                WOL
            </abbr>
        </span>
        <span class="icn arrow-right"></span>
        <div data-id="46609" data-comp="1" class="mcNavBroadcasterContainer">  <div class="broadcasterContainer "> <span class="logo broadcaster-image-container"><img class="broadcaster-image js-broadcaster-logo" src="https://resources.premierleague.com/premierleague/broadcasters/global/supersa.png" srcset="https://resources.premierleague.com/premierleague/broadcasters/global/supersa.png, https://resources.premierleague.com/premierleague/broadcasters/global/supersa@x2.png 2x"></span></div> </div>
    </a><a data-kickoff="1565528400000" href="/match/46614" data-id="46614" class=" matchAbridged  fullTime matchWeekMatchContainer">
            <strong class="minutes matchMinuteContainer" role="timer">FT</strong>
        <span class="teamName">
            <abbr title="Newcastle United">
                NEW
            </abbr>
        </span>
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                <img class="badge-image badge-image--25" src="https://resources.premierleague.com/premierleague/badges/25/t4.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t4.png, https://resources.premierleague.com/premierleague/badges/25/t4@x2.png 2x">
            </span>
        <span class="matchScoreContainer">
                <span class="score">0<span>-</span>1</span>
        </span>
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                <img class="badge-image badge-image--25" src="https://resources.premierleague.com/premierleague/badges/25/t3.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t3.png, https://resources.premierleague.com/premierleague/badges/25/t3@x2.png 2x">
            </span>
        <span class="teamName">
            <abbr title="Arsenal">
                ARS
            </abbr>
        </span>
        <span class="icn arrow-right"></span>
        <div data-id="46614" data-comp="1" class="mcNavBroadcasterContainer">  <div class="broadcasterContainer "> <span class="logo broadcaster-image-container"><img class="broadcaster-image js-broadcaster-logo" src="https://resources.premierleague.com/premierleague/broadcasters/global/supersa.png" srcset="https://resources.premierleague.com/premierleague/broadcasters/global/supersa.png, https://resources.premierleague.com/premierleague/broadcasters/global/supersa@x2.png 2x"></span></div> </div>
    </a><a data-kickoff="1565537400000" href="/match/46613" data-id="46613" class=" matchAbridged  fullTime matchWeekMatchContainer">
            <strong class="minutes matchMinuteContainer" role="timer">FT</strong>
        <span class="teamName">
            <abbr title="Manchester United">
                MUN
            </abbr>
        </span>
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                <img class="badge-image badge-image--25" src="https://resources.premierleague.com/premierleague/badges/25/t1.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t1.png, https://resources.premierleague.com/premierleague/badges/25/t1@x2.png 2x">
            </span>
        <span class="matchScoreContainer">
                <span class="score">4<span>-</span>0</span>
        </span>
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                <img class="badge-image badge-image--25" src="https://resources.premierleague.com/premierleague/badges/25/t8.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t8.png, https://resources.premierleague.com/premierleague/badges/25/t8@x2.png 2x">
            </span>
        <span class="teamName">
            <abbr title="Chelsea">
                CHE
            </abbr>
        </span>
        <span class="icn arrow-right"></span>
        <div data-id="46613" data-comp="1" class="mcNavBroadcasterContainer">  <div class="broadcasterContainer "> <span class="logo broadcaster-image-container"><img class="broadcaster-image js-broadcaster-logo" src="https://resources.premierleague.com/premierleague/broadcasters/global/supersa.png" srcset="https://resources.premierleague.com/premierleague/broadcasters/global/supersa.png, https://resources.premierleague.com/premierleague/broadcasters/global/supersa@x2.png 2x"></span></div> </div>
    </a></ul></li></ul>




    


    


    


    


    


    


    


    


    


    

                <li class="desktopButtonContainer mcNavLink">
                    <a href="/matchweek/4291/latest" class=" mcNavButton" data-nav-tab-index="6"><span class="nav-icn icn news-hi-c"></span>News &amp; Videos<span class="icn chevron-rightblack-normal"></span></a>
                </li>

        </ul>
        <div class="sponsor u-hide">
            <p><span>BROUGHT TO YOU BY</span></p>
        </div>
    </nav>
    <div class="leageTableContainer matchWeekLeagueTableContainer" data-gameweek="4291">
        <section class="leagueTable">
            <header class="leagueTableHeader">
                <h3><span class="matchweekAmountContainer"></span> Table</h3>
                <div class="close tableCloseButtonContainer" role="button" tabindex="0">
                    <div class="icn close-sm-hi"></div>
                </div>
            </header>
            <div class="tablesContainer">
                <div class="table tableSmall homeStandings">
    <div class="liveLeague toggle-btn js-live-toggle-container is-active u-hide">
        <div class="live-animation"><span></span></div>
        <span><span class="liveLeague__live"> Live</span> League Table</span>
    </div>
                    <summary class="visuallyHidden">This abridged table charts the Premier League teams</summary>
                    <table>
                        <thead>
                            <tr>
                                <th scope="col"><abbr title="Position">Position</abbr></th>
                                <th class="Club" scope="col">Club</th>
                                <th scope="col"><abbr title="Played">Pl</abbr></th>
                                <th scope="col"><abbr title="Goal Difference">GD</abbr></th>
                                <th scope="col"><abbr title="Points">Pts</abbr></th>
                            </tr>
                        </thead>

                        <tbody class="standingEntriesContainer">
                        </tbody>
                    </table>
                </div>
            </div>
        </section>
    </div>
</div>

            <div class="centralContent">
                


  <section data-script="pl_match-centre" data-widget="match-summary" class="scorebox " data-status="C" data-ground-id="901" data-id="46605" data-is-neutral="false">
    <picture class="scoreboxBG matchBackgroundPictureContainer"><source media="(min-width: 1024px)" srcset="https://resources.premierleague.com/photos/2022/05/20/96f69e56-e862-4c03-9b31-b10c608b48d3/Anfield.jpg?width=1600&amp;height=600, https://resources.premierleague.com/photos/2022/05/20/96f69e56-e862-4c03-9b31-b10c608b48d3/Anfield.jpg?width=1600&amp;height=600 2x"><source media="(max-width: 500px)" srcset="https://resources.premierleague.com/photos/2022/05/20/96f69e56-e862-4c03-9b31-b10c608b48d3/Anfield.jpg?width=500&amp;height=203, https://resources.premierleague.com/photos/2022/05/20/96f69e56-e862-4c03-9b31-b10c608b48d3/Anfield.jpg?width=1000&amp;height=563 2x"><source srcset="https://resources.premierleague.com/photos/2022/05/20/96f69e56-e862-4c03-9b31-b10c608b48d3/Anfield.jpg?width=1000&amp;height=563, https://resources.premierleague.com/photos/2022/05/20/96f69e56-e862-4c03-9b31-b10c608b48d3/Anfield.jpg?width=1600&amp;height=600 2x"><img src="https://resources.premierleague.com/photos/2022/05/20/96f69e56-e862-4c03-9b31-b10c608b48d3/Anfield.jpg?width=1350&amp;height=759" alt="Anfield Stadium image v4"></picture>
  <div class="wrapper col-12">
    <div class="matchBar">
      <div class="matchInfo">
            <div class="matchDate renderMatchDateContainer" data-kickoff="1565377200000">Fri 9 Aug 2019</div>
            <div class="referee">
              <div alt="" class="icn whistle-w"></div>Michael Oliver
            </div>
          <div class="stadium"><div alt="" class="icn stadium-w"></div>Anfield, Liverpool
          </div>
          <div class="attendance hide-m">Att: 53,333</div>
      </div>
      <div class="tweet" data-body="#LIVNOR" data-script="pl_social-share" data-widget="social-page-share" data-social-service="twitter">
        <strong>#LIVNOR</strong><div alt="" class="icn twitter-w"><span class="visuallyHidden">Share on Twitter</span></div>
      </div>
    </div>
  </div>
      <div class="matchTimeContainer">
    <time class="matchTime" role="timer">
    <span class="hublot-watch-container">
        <div id="flashContentHublot">
            <a href="https://www.hublot.com?utm_source=PremierLeague&amp;utm_medium=site&amp;utm_campaign=official-timekeeper" target="_blank" class="global-link">
                <div class="hublot-timekeeper visible">
                    <div class="hublot-watch">
                        <img class="watch desktop" src="/resources/prod/v6.98.1-4068/i/hublot-watch/watch.png" alt="">
                        <p class="timer">
                            <span id="timer-hours">20</span>:<span id="timer-minutes">08</span>
                        </p>
                    </div>
                </div>
	<svg class="hublot-logo">
		<use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/resources/prod/v6.98.1-4068/i/svg-output/icons.svg#partners-hublot-official-timekeeper"></use>
	</svg>
            </a>
        </div>
    </span>
        <span class="js-match-time">
          <strong>FT</strong>
        </span>
    </time>
      </div>
      <div class="scoreboxContainer">
        <div class="wrapper">
          <div class="col-10 centered">
          <div class="teamsContainer" aria-live="polite" aria-atomic="true">


  <div class="team home">

      <a aria-hidden="true" href="/clubs/10/Liverpool/overview" class="badgeContainer">
            <span class="badge badge--large badge-image-container" data-widget="club-badge-image" data-size="50">
                <img class="badge-image badge-image--50" src="https://resources.premierleague.com/premierleague/badges/50/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t14.png, https://resources.premierleague.com/premierleague/badges/50/t14@x2.png 2x">
            </span>
            <span class="badge badge--small badge-image-container" data-widget="club-badge-image" data-size="25">
                <img class="badge-image badge-image--25" src="https://resources.premierleague.com/premierleague/badges/25/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t14.png, https://resources.premierleague.com/premierleague/badges/25/t14@x2.png 2x">
            </span>
      </a>
      <a aria-hidden="true" href="/clubs/10/Liverpool/overview" class="teamName">
        <span class="long">Liverpool</span>
        <span class="short">LIV</span>
      </a>
  </div>
            <div class="matchScoreContainer">
  <div class="centre">
      <div class="score fullTime">4<span>-</span>1</div>
  </div>
            </div>


  <div class="team away">

      <a aria-hidden="true" href="/clubs/14/Norwich-City/overview" class="badgeContainer">
            <span class="badge badge--large badge-image-container" data-widget="club-badge-image" data-size="50">
                <img class="badge-image badge-image--50" src="https://resources.premierleague.com/premierleague/badges/50/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t45.png, https://resources.premierleague.com/premierleague/badges/50/t45@x2.png 2x">
            </span>
            <span class="badge badge--small badge-image-container" data-widget="club-badge-image" data-size="25">
                <img class="badge-image badge-image--25" src="https://resources.premierleague.com/premierleague/badges/25/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t45.png, https://resources.premierleague.com/premierleague/badges/25/t45@x2.png 2x">
            </span>
      </a>
      <a aria-hidden="true" href="/clubs/14/Norwich-City/overview" class="teamName">
        <span class="long">Norwich City</span>
        <span class="short">NOR</span>
      </a>
  </div>
          </div>

          <div class="matchStats">
  <div class="halfTime">
    <span class="long">Half Time: </span>
      4-0
  </div>
              <div class="attendance show-m"> | Att: 53,333</div>
          </div>

    <div class="kickoff">Kick Off: <strong class="renderKOContainer" data-kickoff="1565377200000">21:00</strong></div>
    <div class="matchEvents matchEventsContainer">


  <div class="home">



                    <div class="event" aria-live="polite" aria-atomic="true">
                        <a href="/players/3819/Grant-Hanley/overview">Grant Hanley</a> 7' (og)
                        <div class="icnContainer">
                          <div alt="" class="icn og-d"><span class="visuallyHidden">Own Goal</span></div>
                        </div>
                    </div>






                    <div class="event" aria-live="polite" aria-atomic="true">
                        <a href="/players/5178/Mohamed-Salah/overview">Mohamed Salah</a> 19'
                        <div class="icnContainer">
                          <div alt="" class="icn ball-sm-w ball-white"><span class="visuallyHidden">Goal</span></div>
                        </div>
                    </div>






                    <div class="event" aria-live="polite" aria-atomic="true">
                        <a href="/players/5140/Virgil-van-Dijk/overview">Virgil van Dijk</a> 28'
                        <div class="icnContainer">
                          <div alt="" class="icn ball-sm-w ball-white"><span class="visuallyHidden">Goal</span></div>
                        </div>
                    </div>






                    <div class="event" aria-live="polite" aria-atomic="true">
                        <a href="/players/10465/Divock-Origi/overview">Divock Origi</a> 42'
                        <div class="icnContainer">
                          <div alt="" class="icn ball-sm-w ball-white"><span class="visuallyHidden">Goal</span></div>
                        </div>
                    </div>



  </div>


  <div class="away">



                    <div class="event" aria-live="polite" aria-atomic="true">
                        <a href="/players/5169/Teemu-Pukki/overview">Teemu Pukki</a> 64'
                        <div class="icnContainer">
                          <div alt="" class="icn ball-sm-w ball-white"><span class="visuallyHidden">Goal</span></div>
                        </div>
                    </div>



  </div>
    </div>
    <div class="assists">
      <div class="title matchAssistsTitle">Assists</div>
      <div class="matchAssistsContainer">


  <div class="home">
          <div class="event">
            <a href="/players/13511/Roberto-Firmino/overview">Roberto Firmino</a> 19'
          </div>
          <div class="event">
            <a href="/players/5178/Mohamed-Salah/overview">Mohamed Salah</a> 28'
          </div>
          <div class="event">
            <a href="/players/14732/Trent-Alexander-Arnold/overview">Trent Alexander-Arnold</a> 42'
          </div>
  </div>


  <div class="away">
          <div class="event">
            <a href="/players/26408/Emiliano-Buendía/overview">Emiliano Buendía</a> 64'
          </div>
  </div>
      </div>
    </div>
  <div class="timeLine timeLineContainer">

  <a href="/clubs/10/Liverpool/overview" class="team">
        <span class="badge-20-bg">
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="20">
                <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t14.png, https://resources.premierleague.com/premierleague/badges/20/t14@x2.png 2x">
            </span>
        </span>
    LIV
  </a>
        <div class="eventLine timeLineEventsContainer">
  <div tabindex="0" class="event home" style="left: 7%;">
    <span class="icn og-d"><span class="visuallyHidden">Own Goal</span></span>7<span class="visuallyHidden">Mins</span>


    <div class="eventInfoContainer ">
      <div class="eventInfo">
        <header class="eventInfoHeader">
          <div alt="" class="icn og-d"></div><time class="min">7'</time>Own Goal<span class="visuallyHidden">Own Goal</span>
          <div class="teamScore">

  <a href="/clubs/10/Liverpool/overview" class="team">
        <span class="badge-20-bg">
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="20">
                <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t14.png, https://resources.premierleague.com/premierleague/badges/20/t14@x2.png 2x">
            </span>
        </span>
    LIV
  </a>
              <span class="team">1</span> - <span class="">0</span>

  <a href="/clubs/14/Norwich-City/overview" class="">
    NOR
        <span class="badge-20-bg">
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="20">
                <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t45.png, https://resources.premierleague.com/premierleague/badges/20/t45@x2.png 2x">
            </span>
        </span>
  </a>
          </div>
        </header>
  <div class="eventInfoContent ">
    <img data-script="pl_player-image" data-widget="player-image" data-player="p83428" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p83428.png" alt="Photo for Grant Hanley">
    <div class="eventPlayerInfo">
      <a href="/players/3819/Grant-Hanley/overview" class="name">5. Grant Hanley
</a>
    </div>
  </div>
      </div>
    </div>
  </div>
  <div tabindex="0" class="event home" style="left: 19%;">
    <span class="icn ball-sm-w ball-white"><span class="visuallyHidden">Goal</span></span>19<span class="visuallyHidden">Mins</span>


    <div class="eventInfoContainer ">
      <div class="eventInfo">
        <header class="eventInfoHeader">
          <div alt="" class="icn ball-sm-w ball-white"></div><time class="min">19'</time>Goal<span class="visuallyHidden">Goal</span>
          <div class="teamScore">

  <a href="/clubs/10/Liverpool/overview" class="team">
        <span class="badge-20-bg">
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="20">
                <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t14.png, https://resources.premierleague.com/premierleague/badges/20/t14@x2.png 2x">
            </span>
        </span>
    LIV
  </a>
              <span class="team">2</span> - <span class="">0</span>

  <a href="/clubs/14/Norwich-City/overview" class="">
    NOR
        <span class="badge-20-bg">
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="20">
                <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t45.png, https://resources.premierleague.com/premierleague/badges/20/t45@x2.png 2x">
            </span>
        </span>
  </a>
          </div>
        </header>
  <div class="eventInfoContent ">
    <img data-script="pl_player-image" data-widget="player-image" data-player="p118748" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p118748.png" alt="Photo for Mohamed Salah">
    <div class="eventPlayerInfo">
      <a href="/players/5178/Mohamed-Salah/overview" class="name">11. Mohamed Salah
</a>
        <div class="assist">Ast. <a href="/players/13511/Roberto-Firmino/overview">Roberto Firmino</a></div>
    </div>
  </div>
      </div>
    </div>
  </div>
  <div tabindex="0" class="event home" style="left: 28%;">
    <span class="icn ball-sm-w ball-white"><span class="visuallyHidden">Goal</span></span>28<span class="visuallyHidden">Mins</span>


    <div class="eventInfoContainer ">
      <div class="eventInfo">
        <header class="eventInfoHeader">
          <div alt="" class="icn ball-sm-w ball-white"></div><time class="min">28'</time>Goal<span class="visuallyHidden">Goal</span>
          <div class="teamScore">

  <a href="/clubs/10/Liverpool/overview" class="team">
        <span class="badge-20-bg">
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="20">
                <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t14.png, https://resources.premierleague.com/premierleague/badges/20/t14@x2.png 2x">
            </span>
        </span>
    LIV
  </a>
              <span class="team">3</span> - <span class="">0</span>

  <a href="/clubs/14/Norwich-City/overview" class="">
    NOR
        <span class="badge-20-bg">
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="20">
                <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t45.png, https://resources.premierleague.com/premierleague/badges/20/t45@x2.png 2x">
            </span>
        </span>
  </a>
          </div>
        </header>
  <div class="eventInfoContent ">
    <img data-script="pl_player-image" data-widget="player-image" data-player="p97032" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p97032.png" alt="Photo for Virgil van Dijk">
    <div class="eventPlayerInfo">
      <a href="/players/5140/Virgil-van-Dijk/overview" class="name">4. Virgil van Dijk
</a>
        <div class="assist">Ast. <a href="/players/5178/Mohamed-Salah/overview">Mohamed Salah</a></div>
    </div>
  </div>
      </div>
    </div>
  </div>
  <div tabindex="0" class="event home" style="left: 39%;">
    <span class="icn sub-w"><span class="visuallyHidden">Substitution</span></span>39<span class="visuallyHidden">Mins</span>


    <div class="eventInfoContainer substitution">
      <div class="eventInfo">
        <header class="eventInfoHeader">
          <div alt="" class="icn sub-w"></div><time class="min">39'</time>Substitution<span class="visuallyHidden">Substitution</span>
          <div class="teamScore">

  <a href="/clubs/10/Liverpool/overview" class="team">
        <span class="badge-20-bg">
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="20">
                <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t14.png, https://resources.premierleague.com/premierleague/badges/20/t14@x2.png 2x">
            </span>
        </span>
    LIV
  </a>
              <span class="team">3</span> - <span class="">0</span>

  <a href="/clubs/14/Norwich-City/overview" class="">
    NOR
        <span class="badge-20-bg">
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="20">
                <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t45.png, https://resources.premierleague.com/premierleague/badges/20/t45@x2.png 2x">
            </span>
        </span>
  </a>
          </div>
        </header>
  <div class="eventInfoContent ">
    <img data-script="pl_player-image" data-widget="player-image" data-player="p116535" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p116535.png" alt="Photo for Alisson">
    <div class="eventPlayerInfo">
      <a href="/players/20559/Alisson/overview" class="name">1. Alisson
          <div alt="" class="icn sub-off"><span class="visuallyHidden">Substitution Off</span></div>
      </a>
    </div>
  </div>
  <div class="eventInfoContent subOn">
    <img data-script="pl_player-image" data-widget="player-image" data-player="p60706" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p60706.png" alt="Photo for Adrián">
    <div class="eventPlayerInfo">
      <a href="/players/20559/Adrián/overview" class="name">13. Adrián
          <div alt="" class="icn sub-on"><span class="visuallyHidden">Substitution On</span></div>
      </a>
    </div>
  </div>
      </div>
    </div>
  </div>
  <div tabindex="0" class="event home" style="left: 42%;">
    <span class="icn ball-sm-w ball-white"><span class="visuallyHidden">Goal</span></span>42<span class="visuallyHidden">Mins</span>


    <div class="eventInfoContainer ">
      <div class="eventInfo">
        <header class="eventInfoHeader">
          <div alt="" class="icn ball-sm-w ball-white"></div><time class="min">42'</time>Goal<span class="visuallyHidden">Goal</span>
          <div class="teamScore">

  <a href="/clubs/10/Liverpool/overview" class="team">
        <span class="badge-20-bg">
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="20">
                <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t14.png, https://resources.premierleague.com/premierleague/badges/20/t14@x2.png 2x">
            </span>
        </span>
    LIV
  </a>
              <span class="team">4</span> - <span class="">0</span>

  <a href="/clubs/14/Norwich-City/overview" class="">
    NOR
        <span class="badge-20-bg">
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="20">
                <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t45.png, https://resources.premierleague.com/premierleague/badges/20/t45@x2.png 2x">
            </span>
        </span>
  </a>
          </div>
        </header>
  <div class="eventInfoContent ">
    <img data-script="pl_player-image" data-widget="player-image" data-player="p152760" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p152760.png" alt="Photo for Divock Origi">
    <div class="eventPlayerInfo">
      <a href="/players/10465/Divock-Origi/overview" class="name">27. Divock Origi
</a>
        <div class="assist">Ast. <a href="/players/14732/Trent-Alexander-Arnold/overview">Trent Alexander-Arnold</a></div>
    </div>
  </div>
      </div>
    </div>
  </div>
  <div tabindex="0" class="event away" style="left: 58%;">
    <span class="icn sub-w"><span class="visuallyHidden">Substitution</span></span>58<span class="visuallyHidden">Mins</span>


    <div class="eventInfoContainer substitution">
      <div class="eventInfo">
        <header class="eventInfoHeader">
          <div alt="" class="icn sub-w"></div><time class="min">58'</time>Substitution<span class="visuallyHidden">Substitution</span>
          <div class="teamScore">

  <a href="/clubs/10/Liverpool/overview" class="">
        <span class="badge-20-bg">
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="20">
                <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t14.png, https://resources.premierleague.com/premierleague/badges/20/t14@x2.png 2x">
            </span>
        </span>
    LIV
  </a>
              <span class="">4</span> - <span class="team">0</span>

  <a href="/clubs/14/Norwich-City/overview" class="team">
    NOR
        <span class="badge-20-bg">
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="20">
                <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t45.png, https://resources.premierleague.com/premierleague/badges/20/t45@x2.png 2x">
            </span>
        </span>
  </a>
          </div>
        </header>
  <div class="eventInfoContent ">
    <img data-script="pl_player-image" data-widget="player-image" data-player="p71738" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p71738.png" alt="Photo for Marco Stiepermann">
    <div class="eventPlayerInfo">
      <a href="/players/23199/Marco-Stiepermann/overview" class="name">18. Marco Stiepermann
          <div alt="" class="icn sub-off"><span class="visuallyHidden">Substitution Off</span></div>
      </a>
    </div>
  </div>
  <div class="eventInfoContent subOn">
    <img data-script="pl_player-image" data-widget="player-image" data-player="p87396" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p87396.png" alt="Photo for Moritz Leitner">
    <div class="eventPlayerInfo">
      <a href="/players/23199/Moritz-Leitner/overview" class="name">10. Moritz Leitner
          <div alt="" class="icn sub-on"><span class="visuallyHidden">Substitution On</span></div>
      </a>
    </div>
  </div>
      </div>
    </div>
  </div>
  <div tabindex="0" class="event away" style="left: 60%;">
    <span class="icn card-yellow"><span class="visuallyHidden">Yellow Card</span></span>60<span class="visuallyHidden">Mins</span>


    <div class="eventInfoContainer ">
      <div class="eventInfo">
        <header class="eventInfoHeader">
          <div alt="" class="icn card-yellow"></div><time class="min">60'</time>Yellow Card<span class="visuallyHidden">Yellow Card</span>
          <div class="teamScore">

  <a href="/clubs/10/Liverpool/overview" class="">
        <span class="badge-20-bg">
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="20">
                <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t14.png, https://resources.premierleague.com/premierleague/badges/20/t14@x2.png 2x">
            </span>
        </span>
    LIV
  </a>
              <span class="">4</span> - <span class="team">0</span>

  <a href="/clubs/14/Norwich-City/overview" class="team">
    NOR
        <span class="badge-20-bg">
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="20">
                <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t45.png, https://resources.premierleague.com/premierleague/badges/20/t45@x2.png 2x">
            </span>
        </span>
  </a>
          </div>
        </header>
  <div class="eventInfoContent ">
    <img data-script="pl_player-image" data-widget="player-image" data-player="p87396" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p87396.png" alt="Photo for Moritz Leitner">
    <div class="eventPlayerInfo">
      <a href="/players/15558/Moritz-Leitner/overview" class="name">10. Moritz Leitner
</a>
    </div>
  </div>
      </div>
    </div>
  </div>
  <div tabindex="0" class="event away" style="left: 64%;">
    <span class="icn ball-sm-w ball-white"><span class="visuallyHidden">Goal</span></span>64<span class="visuallyHidden">Mins</span>


    <div class="eventInfoContainer ">
      <div class="eventInfo">
        <header class="eventInfoHeader">
          <div alt="" class="icn ball-sm-w ball-white"></div><time class="min">64'</time>Goal<span class="visuallyHidden">Goal</span>
          <div class="teamScore">

  <a href="/clubs/10/Liverpool/overview" class="">
        <span class="badge-20-bg">
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="20">
                <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t14.png, https://resources.premierleague.com/premierleague/badges/20/t14@x2.png 2x">
            </span>
        </span>
    LIV
  </a>
              <span class="">4</span> - <span class="team">1</span>

  <a href="/clubs/14/Norwich-City/overview" class="team">
    NOR
        <span class="badge-20-bg">
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="20">
                <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t45.png, https://resources.premierleague.com/premierleague/badges/20/t45@x2.png 2x">
            </span>
        </span>
  </a>
          </div>
        </header>
  <div class="eventInfoContent ">
    <img data-script="pl_player-image" data-widget="player-image" data-player="p57127" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p57127.png" alt="Photo for Teemu Pukki">
    <div class="eventPlayerInfo">
      <a href="/players/5169/Teemu-Pukki/overview" class="name">22. Teemu Pukki
</a>
        <div class="assist">Ast. <a href="/players/26408/Emiliano-Buendía/overview">Emiliano Buendía</a></div>
    </div>
  </div>
      </div>
    </div>
  </div>
  <div tabindex="0" class="event away" style="left: 66%;">
    <span class="icn card-yellow"><span class="visuallyHidden">Yellow Card</span></span>65<span class="visuallyHidden">Mins</span>


    <div class="eventInfoContainer ">
      <div class="eventInfo">
        <header class="eventInfoHeader">
          <div alt="" class="icn card-yellow"></div><time class="min">65'</time>Yellow Card<span class="visuallyHidden">Yellow Card</span>
          <div class="teamScore">

  <a href="/clubs/10/Liverpool/overview" class="">
        <span class="badge-20-bg">
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="20">
                <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t14.png, https://resources.premierleague.com/premierleague/badges/20/t14@x2.png 2x">
            </span>
        </span>
    LIV
  </a>
              <span class="">4</span> - <span class="team">1</span>

  <a href="/clubs/14/Norwich-City/overview" class="team">
    NOR
        <span class="badge-20-bg">
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="20">
                <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t45.png, https://resources.premierleague.com/premierleague/badges/20/t45@x2.png 2x">
            </span>
        </span>
  </a>
          </div>
        </header>
  <div class="eventInfoContent ">
    <img data-script="pl_player-image" data-widget="player-image" data-player="p195546" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p195546.png" alt="Photo for Emiliano Buendía">
    <div class="eventPlayerInfo">
      <a href="/players/26408/Emiliano-Buendía/overview" class="name">17. Emiliano Buendía
</a>
    </div>
  </div>
      </div>
    </div>
  </div>
  <div tabindex="0" class="event away" style="left: 71%;">
    <span class="icn sub-w"><span class="visuallyHidden">Substitution</span></span>70<span class="visuallyHidden">Mins</span>


    <div class="eventInfoContainer substitution">
      <div class="eventInfo">
        <header class="eventInfoHeader">
          <div alt="" class="icn sub-w"></div><time class="min">70'</time>Substitution<span class="visuallyHidden">Substitution</span>
          <div class="teamScore">

  <a href="/clubs/10/Liverpool/overview" class="">
        <span class="badge-20-bg">
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="20">
                <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t14.png, https://resources.premierleague.com/premierleague/badges/20/t14@x2.png 2x">
            </span>
        </span>
    LIV
  </a>
              <span class="">4</span> - <span class="team">1</span>

  <a href="/clubs/14/Norwich-City/overview" class="team">
    NOR
        <span class="badge-20-bg">
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="20">
                <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t45.png, https://resources.premierleague.com/premierleague/badges/20/t45@x2.png 2x">
            </span>
        </span>
  </a>
          </div>
        </header>
  <div class="eventInfoContent ">
    <img data-script="pl_player-image" data-widget="player-image" data-player="p90440" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p90440.png" alt="Photo for Tom Trybull">
    <div class="eventPlayerInfo">
      <a href="/players/24412/Tom-Trybull/overview" class="name">19. Tom Trybull
          <div alt="" class="icn sub-off"><span class="visuallyHidden">Substitution Off</span></div>
      </a>
    </div>
  </div>
  <div class="eventInfoContent subOn">
    <img data-script="pl_player-image" data-widget="player-image" data-player="p89470" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p89470.png" alt="Photo for Onel Hernández">
    <div class="eventPlayerInfo">
      <a href="/players/24412/Onel-Hernández/overview" class="name">11. Onel Hernández
          <div alt="" class="icn sub-on"><span class="visuallyHidden">Substitution On</span></div>
      </a>
    </div>
  </div>
      </div>
    </div>
  </div>
  <div tabindex="0" class="event home" style="left: 75%;">
    <span class="icn sub-w"><span class="visuallyHidden">Substitution</span></span>74<span class="visuallyHidden">Mins</span>


    <div class="eventInfoContainer substitution">
      <div class="eventInfo">
        <header class="eventInfoHeader">
          <div alt="" class="icn sub-w"></div><time class="min">74'</time>Substitution<span class="visuallyHidden">Substitution</span>
          <div class="teamScore">

  <a href="/clubs/10/Liverpool/overview" class="team">
        <span class="badge-20-bg">
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="20">
                <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t14.png, https://resources.premierleague.com/premierleague/badges/20/t14@x2.png 2x">
            </span>
        </span>
    LIV
  </a>
              <span class="team">4</span> - <span class="">1</span>

  <a href="/clubs/14/Norwich-City/overview" class="">
    NOR
        <span class="badge-20-bg">
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="20">
                <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t45.png, https://resources.premierleague.com/premierleague/badges/20/t45@x2.png 2x">
            </span>
        </span>
  </a>
          </div>
        </header>
  <div class="eventInfoContent ">
    <img data-script="pl_player-image" data-widget="player-image" data-player="p152760" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p152760.png" alt="Photo for Divock Origi">
    <div class="eventPlayerInfo">
      <a href="/players/10465/Divock-Origi/overview" class="name">27. Divock Origi
          <div alt="" class="icn sub-off"><span class="visuallyHidden">Substitution Off</span></div>
      </a>
    </div>
  </div>
  <div class="eventInfoContent subOn">
    <img data-script="pl_player-image" data-widget="player-image" data-player="p110979" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p110979.png" alt="Photo for Sadio Mané">
    <div class="eventPlayerInfo">
      <a href="/players/10465/Sadio-Mané/overview" class="name">10. Sadio Mané
          <div alt="" class="icn sub-on"><span class="visuallyHidden">Substitution On</span></div>
      </a>
    </div>
  </div>
      </div>
    </div>
  </div>
  <div tabindex="0" class="event away" style="left: 84%;">
    <span class="icn sub-w"><span class="visuallyHidden">Substitution</span></span>83<span class="visuallyHidden">Mins</span>


    <div class="eventInfoContainer substitution">
      <div class="eventInfo">
        <header class="eventInfoHeader">
          <div alt="" class="icn sub-w"></div><time class="min">83'</time>Substitution<span class="visuallyHidden">Substitution</span>
          <div class="teamScore">

  <a href="/clubs/10/Liverpool/overview" class="">
        <span class="badge-20-bg">
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="20">
                <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t14.png, https://resources.premierleague.com/premierleague/badges/20/t14@x2.png 2x">
            </span>
        </span>
    LIV
  </a>
              <span class="">4</span> - <span class="team">1</span>

  <a href="/clubs/14/Norwich-City/overview" class="team">
    NOR
        <span class="badge-20-bg">
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="20">
                <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t45.png, https://resources.premierleague.com/premierleague/badges/20/t45@x2.png 2x">
            </span>
        </span>
  </a>
          </div>
        </header>
  <div class="eventInfoContent ">
    <img data-script="pl_player-image" data-widget="player-image" data-player="p57127" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p57127.png" alt="Photo for Teemu Pukki">
    <div class="eventPlayerInfo">
      <a href="/players/5169/Teemu-Pukki/overview" class="name">22. Teemu Pukki
          <div alt="" class="icn sub-off"><span class="visuallyHidden">Substitution Off</span></div>
      </a>
    </div>
  </div>
  <div class="eventInfoContent subOn">
    <img data-script="pl_player-image" data-widget="player-image" data-player="p81048" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p81048.png" alt="Photo for Josip Drmic">
    <div class="eventPlayerInfo">
      <a href="/players/5169/Josip-Drmic/overview" class="name">20. Josip Drmic
          <div alt="" class="icn sub-on"><span class="visuallyHidden">Substitution On</span></div>
      </a>
    </div>
  </div>
      </div>
    </div>
  </div>
  <div tabindex="0" class="event home" style="left: 87%;">
    <span class="icn sub-w"><span class="visuallyHidden">Substitution</span></span>86<span class="visuallyHidden">Mins</span>


    <div class="eventInfoContainer substitution">
      <div class="eventInfo">
        <header class="eventInfoHeader">
          <div alt="" class="icn sub-w"></div><time class="min">86'</time>Substitution<span class="visuallyHidden">Substitution</span>
          <div class="teamScore">

  <a href="/clubs/10/Liverpool/overview" class="team">
        <span class="badge-20-bg">
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="20">
                <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t14.png, https://resources.premierleague.com/premierleague/badges/20/t14@x2.png 2x">
            </span>
        </span>
    LIV
  </a>
              <span class="team">4</span> - <span class="">1</span>

  <a href="/clubs/14/Norwich-City/overview" class="">
    NOR
        <span class="badge-20-bg">
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="20">
                <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t45.png, https://resources.premierleague.com/premierleague/badges/20/t45@x2.png 2x">
            </span>
        </span>
  </a>
          </div>
        </header>
  <div class="eventInfoContent ">
    <img data-script="pl_player-image" data-widget="player-image" data-player="p92217" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p92217.png" alt="Photo for Roberto Firmino">
    <div class="eventPlayerInfo">
      <a href="/players/13511/Roberto-Firmino/overview" class="name">9. Roberto Firmino
          <div alt="" class="icn sub-off"><span class="visuallyHidden">Substitution Off</span></div>
      </a>
    </div>
  </div>
  <div class="eventInfoContent subOn">
    <img data-script="pl_player-image" data-widget="player-image" data-player="p15157" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p15157.png" alt="Photo for James Milner">
    <div class="eventPlayerInfo">
      <a href="/players/13511/James-Milner/overview" class="name">7. James Milner
          <div alt="" class="icn sub-on"><span class="visuallyHidden">Substitution On</span></div>
      </a>
    </div>
  </div>
      </div>
    </div>
  </div>

  <div tabindex="0" class="event ko" style="left: 0%;">
    <span class="icn "><span class="visuallyHidden"></span></span>KO<span class="visuallyHidden">Mins</span>
  </div>
  <div tabindex="0" class="event ht" style="left: 49%;">
    <span class="icn "><span class="visuallyHidden"></span></span>HT<span class="visuallyHidden">Mins</span>
  </div>
  <div tabindex="0" class="event ft" style="left: 90%;">
    <span class="icn "><span class="visuallyHidden"></span></span>FT<span class="visuallyHidden">Mins</span>
  </div>
        </div>

  <a href="/clubs/14/Norwich-City/overview" class="team">
        <span class="badge-20-bg">
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="20">
                <img class="badge-image badge-image--20" src="https://resources.premierleague.com/premierleague/badges/20/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/20/t45.png, https://resources.premierleague.com/premierleague/badges/20/t45@x2.png 2x">
            </span>
        </span>
    NOR
  </a>
  </div>

        </div>
      </div>
  </div></section>

  <div id="broadcasterInfoWrapModal" class="plBroadcastModal">
    <div id="broadcasterInfoContentModal" class="plBroadcastModalContent">
      <a class="close broadcastModalCloseButton" role="button" tabindex="0">close</a>
      <div id="broadcastersModal" class="broadcastersModal open">
        <div class="broadcastersTvInfoHeader"><span class="broadcastersTvInfoHeaderInner"><span class="icn tv-w"></span>TV Info</span></div>
        <div class="broadcastersModalHeader">Broadcasters</div>
        <div class="allBroadcastersModalContainer"></div>
      </div>
    </div>
  </div>


	


    <div class="mcTabsContainer" data-script="pl_match-centre" data-widget="match-tabs" data-fixture="{&quot;gameweek&quot;:{&quot;id&quot;:4291,&quot;compSeason&quot;:{&quot;label&quot;:&quot;2019/20&quot;,&quot;competition&quot;:{&quot;abbreviation&quot;:&quot;EN_PR&quot;,&quot;description&quot;:&quot;Premier League&quot;,&quot;level&quot;:&quot;SEN&quot;,&quot;source&quot;:&quot;&quot;,&quot;id&quot;:1,&quot;altIds&quot;:{&quot;opta&quot;:&quot;8&quot;}},&quot;id&quot;:274},&quot;gameweek&quot;:1,&quot;competitionPhase&quot;:{&quot;id&quot;:1040,&quot;type&quot;:&quot;L&quot;,&quot;gameweekRange&quot;:[1,38]}},&quot;kickoff&quot;:{&quot;completeness&quot;:3,&quot;millis&quot;:1565377200000,&quot;label&quot;:&quot;Fri 9 Aug 2019, 20:00 BST&quot;,&quot;gmtOffset&quot;:1.0},&quot;provisionalKickoff&quot;:{&quot;completeness&quot;:3,&quot;millis&quot;:1565377200000,&quot;label&quot;:&quot;Fri 9 Aug 2019, 20:00 BST&quot;,&quot;gmtOffset&quot;:1.0},&quot;teams&quot;:[{&quot;team&quot;:{&quot;name&quot;:&quot;Liverpool&quot;,&quot;club&quot;:{&quot;name&quot;:&quot;Liverpool&quot;,&quot;shortName&quot;:&quot;Liverpool&quot;,&quot;abbr&quot;:&quot;LIV&quot;,&quot;id&quot;:10},&quot;teamType&quot;:&quot;FIRST&quot;,&quot;shortName&quot;:&quot;Liverpool&quot;,&quot;id&quot;:10,&quot;altIds&quot;:{&quot;opta&quot;:&quot;t14&quot;}},&quot;score&quot;:4},{&quot;team&quot;:{&quot;name&quot;:&quot;Norwich City&quot;,&quot;club&quot;:{&quot;name&quot;:&quot;Norwich City&quot;,&quot;shortName&quot;:&qu
u002700&quot;},&quot;phase&quot;:&quot;2&quot;,&quot;type&quot;:&quot;S&quot;,&quot;description&quot;:&quot;OFF&quot;,&quot;time&quot;:{&quot;millis&quot;:1565383790000,&quot;label&quot;:&quot;9 August 2019, 21:49&quot;,&quot;gmtOffset&quot;:1.0},&quot;score&quot;:{&quot;homeScore&quot;:4,&quot;awayScore&quot;:1}},{&quot;clock&quot;:{&quot;secs&quot;:5580,&quot;label&quot;:&quot;90 +3\u002700&quot;},&quot;phase&quot;:&quot;2&quot;,&quot;type&quot;:&quot;PE&quot;,&quot;time&quot;:{&quot;millis&quot;:1565384157000,&quot;label&quot;:&quot;9 August 2019, 21:55&quot;,&quot;gmtOffset&quot;:1.0},&quot;score&quot;:{&quot;homeScore&quot;:4,&quot;awayScore&quot;:1}}],&quot;penaltyShootouts&quot;:[],&quot;behindClosedDoors&quot;:false,&quot;id&quot;:46605,&quot;altIds&quot;:{&quot;opta&quot;:&quot;g1059702&quot;},&quot;metadata&quot;:{}}">

        <div class="wrapper col-12">
            <div class="tabLinks matchNav">
                <div class="tabs"><ul class="tablist" role="tablist"><li role="tab" tabindex="0" data-tab-index="0" class="active">Latest</li><li role="tab" tabindex="0" data-tab-index="1" class="matchCentreSquadLabelContainer">Line-ups</li><li role="tab" tabindex="0" data-tab-index="2">Stats</li><li role="tab" tabindex="0" data-tab-index="3" class="js-mc-related-tab">Related</li></ul></div>
            </div>
        </div>

        <!-- LATEST TAB -->
        <div class="mcTabs"><section class="mcLatestContainer mcMainTab active" data-ui-tab="Latest" data-ui-args="{&quot;type&quot;: &quot;latest&quot;}">

            <nav data-script="pl_tabbed" data-widget="tabbed-content" class="tabs" data-tab-wrap=".tabs" data-built-class="matchLatestContainer" data-tab-class="mcLatestTab"></nav>

            <div class="matchLatestContainer"><nav class="tabs"><ul class="tablist" role="tablist"><li role="tab" tabindex="0" data-tab-index="0" class="active">Latest</li><li role="tab" tabindex="0" data-tab-index="1">Photos</li></ul></nav><div data-ui-tab="Latest" class="blogStreamMatchContainer mcLatestTab active" data-tab-aware-default="true">

                
    <div data-fixture-status="C" data-fixture-id="46605" data-comp-id="274" data-opta-id="g1059702">
        


    <div class="kotm-live-commentary is-winner is-opt-out is-full-time" data-script="pl_kotm" data-widget="kotm-controller">
        <div class="kotm-live-commentary__content">
                <span class="kotm-live-commentary__logo icn commercial-white-budweiser"></span>
            <div class="js-content"><h4 class="kotm-player__first-name">Mohamed</h4><h3 class="kotm-player__second-name">Salah</h3><div class="kotm-player__player-image-wrapper"><span class="kotm-player__glow"></span> <img class="kotm-player__player-image kotm-player__player-image--promo js-winner-image kotm-player__player-image--default" data-player="p118748" src="https://resources.premierleague.com/premierleague/photos/players/250x250/p118748.png"></div> <div class="kotm-player__bowtie kotm-player__bowtie--opt-out"><h3 class="kotm-player__bowtie-text">King of the match</h3></div><div class="kotm-live-commentary__button-link-container js-button-link-container"><button class="kotm-live-commentary__btn">View More<span class="icn arrow-rightwhite"></span></button></div></div>
        </div>

        <div class="kotm-live-commentary__footer-logo">
            <i class="icn drinkaware"></i>
        </div>
    </div>

    </div>


                <div class="preMatchContainer" style="display: none;">
                    <div class="matchPreviewStreamContainer"></div>
                    <p class="noContentAvailableContainer" style="display: none;">Match related content will appear here</p>
                </div>
                <div class="liveMatchContainer" style="">
                    <section class="matchBlog">
                        <div class="wrapper">
                            <div class="mcBlogStream">
                                <div class="matchReportStreamContainer" data-report-rendered="true"><header><h3 class="subHeader">Match summary</h3></header> 



<div class="wrapper col-12">
	<div class="standardArticle">
	<p>Mohamed Salah was among the goalscorers as Liverpool opened the 2019/20 Premier League season with a 4-1 win over Norwich City at Anfield.</p>
<p>The first goal of the new season came after just seven minutes, with Divock Origi’s cross diverted into his own net by Norwich defender Grant Hanley.</p>
<p>Liverpool doubled their lead 12 minutes later, with Roberto Firmino playing in Salah, who scored on the opening weekend for the third consecutive season.</p>
<p>Salah's corner was headed in by Virgil van Dijk for the third, before Origi glanced in Trent Alexander-Arnold's cross to make it 4-0 before half-time.</p>
<p>Norwich pulled a goal back on 64 minutes, with Teemu Pukki finishing past Adrian, who replaced the injured Alisson in goal to make his Liverpool debut.</p>
<p>Substitute Onel Hernandez became the first Cuban to play in the Premier League, and he forced Adrian into a late save as the 2018/19 runners-up saw out the win.</p>
<p>See: <a href="https://www.liverpoolfc.com/news/first-team/359939-liverpool-norwich-match-report-premier-league" target="_blank" rel="noopener">Liverpool report</a> | <a href="https://www.canaries.co.uk/News/2019/august/match-report-for-liverpool-vs-norwich-city-on-09-aug-19/" target="_blank" rel="noopener">Norwich report</a></p>
<h6>Next fixtures</h6>
<p>Liverpool: 17 Aug v Southampton (A)<br>Norwich: 17 Aug v Newcastle (H)</p>
<p><strong>Referee:</strong>&nbsp;Michael Oliver;&nbsp;<strong>Assistants:</strong>&nbsp;Stuart Burt, Simon Bennett;&nbsp;<strong>Fourth official:</strong>&nbsp;Graham Scott;&nbsp;<strong>VAR:</strong>&nbsp;Andre Marriner;&nbsp;<strong>Assistant VAR:</strong>&nbsp;Scott Ledger</p>
	</div>
</div>

<script src="/resources/ver/app/app-pulse.js"></script>
<script data-script-created="true" type="text/javascript" src="https://www.premierleague.com/resources/ver/app/app-external.js"></script><script data-script-created="true" type="text/javascript" src="https://www.premierleague.com/resources/ver/app/app-widgets.js"></script></div>
                                <header>
                                    <div class="title">
                                        <h3 class="subHeader"><span>Live</span>
                                            Match Commentary
                                        </h3>
                                    </div>
                                </header>
                                <ul class="commentaryContainer"><li><div class="blogCard time-full majorEvent"><div class="cardMeta"><div class="icon"><div class="icn time-full-w"></div></div></div><div class="cardContent"><div class="innerContent"><h6>Full-time</h6><p>Match ends, Liverpool 4, Norwich City 1.</p></div></div></div></li><li><div class="blogCard time majorEvent"><div class="cardMeta"><div class="icon"><div class="icn time-w"></div></div> <time>90 +3'</time> </div><div class="cardContent"><div class="innerContent"><h6></h6><p>Second Half ends, Liverpool 4, Norwich City 1.</p></div></div></div></li><li><div class="blogCard blog-text"><div class="cardMeta"><div class="icon"><div class="icn blog-text"></div></div> <time>90 +1'</time> </div><div class="cardContent"><div class="innerContent"><h6></h6><p>Attempt blocked. Onel Hernández (Norwich City) left footed shot from the left side of the box is blocked.</p></div></div></div></li><li><div class="blogCard blog-text"><div class="cardMeta"><div class="icon"><div class="icn blog-text"></div></div> <time>90 +1'</time> </div><div class="cardContent"><div class="innerContent"><h6></h6><p>Attempt saved. Ben Godfrey (Norwich City) right footed shot from outside the box is saved in the bottom left corner. Assisted by Jamal Lewis.</p></div></div></div></li><li><div class="blogCard blog-text"><div class="cardMeta"><div class="icon"><div class="icn blog-text"></div></div> <time>90 +1'</time> </div><div class="cardContent"><div class="innerContent"><h6></h6><p>Todd Cantwell (Norwich City) wins a free kick in the defensive half.</p></div></div></div></li><li><div class="blogCard blog-text"><div class="cardMeta"><div class="icon"><div class="icn blog-text"></div></div> <time>90 +1'</time> </div><div class="cardContent"><div class="innerContent"><h6></h6><p>Foul by Georginio Wijnaldum (Liverpool).</p></div></div></div></li><li><div class="blogCard blog-text"><div class="cardMeta"><div class="icon"><div class="icn blog-text"></div></div> <time>90'</time> </div><div class="cardContent"><div class="innerContent"><h6></h6><p>Moritz Leitner (Norwich City) wins a free kick in the defensive half.</p></div></div></div></li><li><div class="blogCard blog-text"><div class="cardMeta"><div class="icon"><div class="icn blog-text"></div></div> <time>90'</time> </div><div class="cardContent"><div class="innerContent"><h6></h6><p>Foul by Mohamed Salah (Liverpool).</p></div></div></div></li><li><div class="blogCard blog-text"><div class="cardMeta"><div class="icon"><div class="icn blog-text"></div></div> <time>88'</time> </div><div class="cardContent"><div class="innerContent"><h6></h6><p>Offside, Norwich City. Todd Cantwell tries a through ball, but Onel Hernández is caught offside.</p></div></div></div></li><li><div class="blogCard blog-text"><div class="cardMeta"><div class="icon"><div class="icn blog-text"></div></div> <time>88'</time> </div><div class="cardContent"><div class="innerContent"><h6></h6><p>Corner,  Norwich City. Conceded by Trent Alexander-Arnold.</p></div></div></div></li><li><div class="blogCard substitution minorEvent"><div class="cardMeta"><div class="icon"><div class="icn sub-n"></div></div> <time>86'</time> </div><div class="cardContent"><div class="innerContent"><h6>Substitution</h6><p>Substitution, Liverpool. James Milner replaces Roberto Firmino.</p></div></div></div></li><li><div class="blogCard blog-text"><div class="cardMeta"><div class="icon"><div class="icn blog-text"></div></div> <time>85'</time> </div><div class="cardContent"><div class="innerContent"><h6></h6><p>Corner,  Liverpool. Conceded by Tim Krul.</p></div></div></div></li><li><div class="blogCard blog-text"><div class="cardMeta"><div class="icon"><div class="icn blog-text"></div></div> <time>85'</time> </div><div class="cardContent"><div class="innerContent"><h6></h6><p>Attempt saved. Trent Alexander-Arnold (Liverpool) right footed shot from outside the box is saved in the top right corner.</p></div></div></div></li><li><div class="blogCard blog-text"><div class="cardMeta"><div class="icon"><div class="icn blog-text"></div></div> <time>83'</time> </div><div class="cardContent"><div class="innerContent"><h6></h6><p>Foul by Grant Hanley (Norwich City).</p></div></div></div></li><li><div class="blogCard blog-text"><div class="cardMeta"><div class="icon"><div class="icn blog-text"></div></div> <time>83'</time> </div><div class="cardContent"><div class="innerContent"><h6></h6><p>Roberto Firmino (Liverpool) wins a free kick in the attacking half.</p></div></div></div></li><li><div class="blogCard substitution minorEvent"><div class="cardMeta"><div class="icon"><div class="icn sub-n"></div></div> <time>83'</time> </div><div class="cardContent"><div class="innerContent"><h6>Substitution</h6><p>Substitution, Norwich City. Josip Drmic replaces Teemu Pukki.</p></div></div></div></li><li><div class="blogCard blog-text"><div class="cardMeta"><div class="icon"><div class="icn blog-text"></div></div> <time>81'</time> </div><div class="cardContent"><div class="innerContent"><h6></h6><p>Corner,  Liverpool. Conceded by Max Aarons.</p></div></div></div></li><li><div class="blogCard blog-text"><div class="cardMeta"><div class="icon"><div class="icn blog-text"></div></div> <time>80'</time> </div><div class="cardContent"><div class="innerContent"><h6></h6><p>Attempt saved. Emiliano Buendía (Norwich City) right footed shot from outside the box is saved in the centre of the goal.</p></div></div></div></li><li><div class="blogCard blog-text"><div class="cardMeta"><div class="icon"><div class="icn blog-text"></div></div> <time>79'</time> </div><div class="cardContent"><div class="innerContent"><h6></h6><p>Teemu Pukki (Norwich City) wins a free kick in the attacking half.</p></div></div></div></li><li><div class="blogCard blog-text"><div class="cardMeta"><div class="icon"><div class="icn blog-text"></div></div> <time>79'</time> </div><div class="cardContent"><div class="innerContent"><h6></h6><p>Foul by Joseph Gomez (Liverpool).</p></div></div></div></li><li><div class="blogCard blog-text"><div class="cardMeta"><div class="icon"><div class="icn blog-text"></div></div> <time>79'</time> </div><div class="cardContent"><div class="innerContent"><h6></h6><p>Offside, Norwich City. Moritz Leitner tries a through ball, but Onel Hernández is caught offside.</p></div></div></div></li><li><div class="blogCard blog-text"><div class="cardMeta"><div class="icon"><div class="icn blog-text"></div></div> <time>76'</time> </div><div class="cardContent"><div class="innerContent"><h6></h6><p>Corner,  Liverpool. Conceded by Ben Godfrey.</p></div></div></div></li><li><div class="blogCard blog-text"><div class="cardMeta"><div class="icon"><div class="icn blog-text"></div></div> <time>75'</time> </div><div class="cardContent"><div class="innerContent"><h6></h6><p>Georginio Wijnaldum (Liverpool) wins a free kick in the defensive half.</p></div></div></div></li><li><div class="blogCard blog-text"><div class="cardMeta"><div class="icon"><div class="icn blog-text"></div></div> <time>75'</time> </div><div class="cardContent"><div class="innerContent"><h6></h6><p>Foul by Max Aarons (Norwich City).</p></div></div></div></li><li><div class="blogCard substitution minorEvent"><div class="cardMeta"><div class="icon"><div class="icn sub-n"></div></div> <time>74'</time> </div><div class="cardContent"><div class="innerContent"><h6>Substitution</h6><p>Substitution, Liverpool. Sadio Mané replaces Divock Origi.</p></div></div></div></li><li><div class="blogCard blog-text"><div class="cardMeta"><div class="icon"><div class="icn blog-text"></div></div> <time>73'</time> </div><div class="cardContent"><div class="innerContent"><h6></h6><p>Attempt missed. Trent Alexander-Arnold (Liverpool) right footed shot from outside the box is too high. Assisted by Joseph Gomez.</p></div></div></div></li><li><div class="blogCard blog-text"><div class="cardMeta"><div class="icon"><div class="icn blog-text"></div></div> <time>72'</time> </div><div class="cardContent"><div class="innerContent"><h6></h6><p>Corner,  Liverpool. Conceded by Max Aarons.</p></div></div></div></li><li><div class="blogCard blog-text"><div class="cardMeta"><div class="icon"><div class="icn blog-text"></div></div> <time>71'</time> </div><div class="cardContent"><div class="innerContent"><h6></h6><p>Corner,  Liverpool. Conceded by Grant Hanley.</p></div></div></div></li><li><div class="blogCard blog-text"><div class="cardMeta"><div class="icon"><div class="icn blog-text"></div></div> <time>71'</time> </div><div class="cardContent"><div class="innerContent"><h6></h6><p>Attempt blocked. Roberto Firmino (Liverpool) right footed shot from the centre of the box is blocked. Assisted by Mohamed Salah.</p></div></div></div></li><li><div class="blogCard substitution minorEvent"><div class="cardMeta"><div class="icon"><div class="icn sub-n"></div></div> <time>70'</time> </div><div class="cardContent"><div class="innerContent"><h6>Substitution</h6><p>Substitution, Norwich City. Onel Hernández replaces Tom Trybull.</p></div></div></div></li></ul>
                            <div class="loader" data-scroll-loader="" style="min-height:10px;"></div></div>
                        </div>
                    </section>
                </div>
            </div><div data-ui-tab="Photos" class="sideWidget vidiprinter matchPhotosContainer mcLatestTab">
                <header>
                    <div class="title">
                        <h3 class="subHeader">
                            Match Photos
                        </h3>
                        <div class="sponsor u-hide">
                            BROUGHT TO YOU BY
                        </div>
                    </div>
                </header>
                <ul class="matchPhotoContainer"><li class="galleryItem" data-ui-src="https://resources.premierleague.com/photos/premierleague/photo/2019/08/09
            </div></div>
            
        </section><section class="squads mcMainTab" data-ui-class="matchCentreSquadLabelContainer" data-ui-tab="Squads" data-ui-args="{&quot;type&quot;: &quot;squad&quot;}" data-compseason="274">

                <nav data-script="pl_tabbed" data-widget="tabbed-content" class="tabs" data-tab-wrap=".tabs" data-built-class="matchLineups" data-tab-class="mcLineUpContainter"></nav>

                <div class="wrapper">


    <div class="matchLineups"><nav class="tabs"><ul class="tablist" role="tablist"><li role="tab" tabindex="0" data-tab-index="0" class="active">LIV</li><li role="tab" tabindex="0" data-tab-index="1">Pitch</li><li role="tab" tabindex="0" data-tab-index="2">NOR</li></ul></nav><div class="teamList mcLineUpContainter homeLineup active" data-ui-tab="LIV" data-tab-aware-default="true">
        <div class="col-4-m ">
            <header class="squadHeader">
    <a href="/clubs/10/Liverpool/overview">
            <div class="badge badge-image-container" data-widget="club-badge-image" data-size="50">
                <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t14.png, https://resources.premierleague.com/premierleague/badges/50/t14@x2.png 2x">
            </div>
            <span class="visuallyHidden">Liverpool overview page</span>
    </a>
                <div class="position">
                    Liverpool
                    <strong class="matchTeamFormation" data-team-id="10">4-3-3</strong>
                </div>
            </header>
            <div class="matchLineupTeamContainer" data-team-id="10" data-index-class="home">
                    <ul class="startingLineUpContainer squadList home">
        <li class="player" data-position="0" data-age="717984000000">
            <a href="/players/20559/Alisson/overview">
                <div class="number">1</div>
                <img data-script="pl_player-image" data-widget="player-image" data-player="p116535" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p116535.png" alt="Alisson">
                <div class="info">
                    <div class="name">
                        Alisson
                        <div class="playerLineupEventContainer-20,559">
            <span class="icn sub-off"></span>
                <span class="sub">39'</span>
                        </div>
                    </div>
                    <span class="position">
                        <span>Goalkeeper</span>
                    </span>
                </div>
            </a>
        </li>
        <li class="player" data-position="1" data-age="864345600000">
            <a href="/players/10651/Joseph-Gomez/overview">
                <div class="number">12</div>
                <img data-script="pl_player-image" data-widget="player-image" data-player="p171287" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p171287.png" alt="Joseph Gomez">
                <div class="info">
                    <div class="name">
                        Joseph Gomez
                        <div class="playerLineupEventContainer-10,651">
                        </div>
                    </div>
                    <span class="position">
                        <span>Defender</span>
                    </span>
                </div>
            </a>
        </li>
        <li class="player" data-position="2" data-age="763344000000">
            <a href="/players/10458/Andrew-Robertson/overview">
                <div class="number">26</div>
                <img data-script="pl_player-image" data-widget="player-image" data-player="p122798" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p122798.png" alt="Andrew Robertson">
                <div class="info">
                    <div class="name">
                        Andrew Robertson
                        <div class="playerLineupEventContainer-10,458">
                        </div>
                    </div>
                    <span class="position">
                        <span>Defender</span>
                    </span>
                </div>
            </a>
        </li>
        <li class="player" data-position="3" data-age="907718400000">
            <a href="/players/14732/Trent-Alexander-Arnold/overview">
                <div class="number">66</div>
                <img data-script="pl_player-image" data-widget="player-image" data-player="p169187" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p169187.png" alt="Trent Alexander-Arnold">
                <div class="info">
                    <div class="name">
                        Trent Alexander-Arnold
                        <div class="playerLineupEventContainer-14,732">
                        </div>
                    </div>
                    <span class="position">
                        <span>Defender</span>
                    </span>
                </div>
            </a>
        </li>
        <li class="player" data-position="4" data-age="678931200000">
            <a href="/players/5140/Virgil-van-Dijk/overview">
                <div class="number">4</div>
                <img data-script="pl_player-image" data-widget="player-image" data-player="p97032" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p97032.png" alt="Virgil van Dijk">
                <div class="info">
                    <div class="name">
                        Virgil van Dijk
                        <div class="playerLineupEventContainer-5,140">
            <span class="icn ball-small"></span>
                        </div>
                    </div>
                    <span class="position">
                        <span>Defender</span>
                    </span>
                </div>
            </a>
        </li>
        <li class="player" data-position="5" data-age="658281600000">
            <a href="/players/7114/Georginio-Wijnaldum/overview">
                <div class="number">5</div>
                <img data-script="pl_player-image" data-widget="player-image" data-player="p41733" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p41733.png" alt="Georginio Wijnaldum">
                <div class="info">
                    <div class="name">
                        Georginio Wijnaldum
                        <div class="playerLineupEventContainer-7,114">
                        </div>
                    </div>
                    <span class="position">
                        <span>Midfielder</span>
                    </span>
                </div>
            </a>
        </li>
        <li class="player" data-position="6" data-age="751334400000">
            <a href="/players/11247/Fabinho/overview">
                <div class="number">3</div>
                <img data-script="pl_player-image" data-widget="player-image" data-player="p116643" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p116643.png" alt="Fabinho">
                <div class="info">
                    <div class="name">
                        Fabinho
                        <div class="playerLineupEventContainer-11,247">
                        </div>
                    </div>
                    <span class="position">
                        <span>Midfielder</span>
                    </span>
                </div>
            </a>
        </li>
        <li class="player" data-position="7" data-age="645580800000">
            <a href="/players/3712/Jordan-Henderson/overview">
                <div class="number">14</div>
                <img data-script="pl_player-image" data-widget="player-image" data-player="p56979" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p56979.png" alt="Jordan Henderson">
                <div class="info">
                    <div class="name">
                        Jordan Henderson
                        <div class="playerLineupEventContainer-3,712">
                        </div>
                    </div>
                    <span class="position">
                            <div class="cpt">C</div>
                        <span>Midfielder</span>
                    </span>
                </div>
            </a>
        </li>
        <li class="player" data-position="8" data-age="686361600000">
            <a href="/players/13511/Roberto-Firmino/overview">
                <div class="number">9</div>
                <img data-script="pl_player-image" data-widget="player-image" data-player="p92217" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p92217.png" alt="Roberto Firmino">
                <div class="info">
                    <div class="name">
                        Roberto Firmino
                        <div class="playerLineupEventContainer-13,511">
            <span class="icn sub-off"></span>
                <span class="sub">86'</span>
                        </div>
                    </div>
                    <span class="position">
                        <span>Forward</span>
                    </span>
                </div>
            </a>
        </li>
        <li class="player" data-position="9" data-age="708566400000">
            <a href="/players/5178/Mohamed-Salah/overview">
                <div class="number">11</div>
                <img data-script="pl_player-image" data-widget="player-image" data-player="p118748" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p118748.png" alt="Mohamed Salah">
                <div class="info">
                    <div class="name">
                        Mohamed Salah
                        <div class="playerLineupEventContainer-5,178">
            <span class="icn ball-small"></span>
                        </div>
                    </div>
                    <span class="position">
                        <span>Forward</span>
                    </span>
                </div>
            </a>
        </li>
        <li class="player" data-position="10" data-age="798163200000">
            <a href="/players/10465/Divock-Origi/overview">
                <div class="number">27</div>
                <img data-script="pl_player-image" data-widget="player-image" data-player="p152760" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p152760.png" alt="Divock Origi">
                <div class="info">
                    <div class="name">
                        Divock Origi
                        <div class="playerLineupEventContainer-10,465">
            <span class="icn ball-small"></span>
            <span class="icn sub-off"></span>
                <span class="sub">74'</span>
                        </div>
                    </div>
                    <span class="position">
                        <span>Forward</span>
                    </span>
                </div>
            </a>
        </li>
                    </ul>
                    <h3 class="substituteHeader home">Substitutes </h3>
                    <ul class="startingLineUpContainer squadList home">
        <li class="player" data-position="0" data-age="536630400000">
            <a href="/players/4852/Adrián/overview">
                <div class="number">13</div>
                <img data-script="pl_player-image" data-widget="player-image" data-player="p60706" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p60706.png" alt="Adrián">
                <div class="info">
                    <div class="name">
                        Adrián
                        <div class="playerLineupEventContainer-4,852">
            <span class="icn sub-on"></span>
                <span class="sub">39'</span>
                        </div>
                    </div>
                    <span class="position">
                        <span>Goalkeeper</span>
                    </span>
                </div>
            </a>
        </li>
        <li class="player" data-position="1" data-age="681609600000">
            <a href="/players/5375/Joel-Matip/overview">
                <div class="number">32</div>
                <img data-script="pl_player-image" data-widget="player-image" data-player="p60914" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p60914.png" alt="Joel Matip">
                <div class="info">
                    <div class="name">
                        Joel Matip
                        <div class="playerLineupEventContainer-5,375">
                        </div>
                    </div>
                    <span class="position">
                        <span>Defender</span>
                    </span>
                </div>
            </a>
        </li>
        <li class="player" data-position="2" data-age="745372800000">
            <a href="/players/4252/Alex-Oxlade-Chamberlain/overview">
                <div class="number">15</div>
                <img data-script="pl_player-image" data-widget="player-image" data-player="p81880" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p81880.png" alt="Alex Oxlade-Chamberlain">
                <div class="info">
                    <div class="name">
                        Alex Oxlade-Chamberlain
                        <div class="playerLineupEventContainer-4,252">
                        </div>
                    </div>
                    <span class="position">
                        <span>Midfielder</span>
                    </span>
                </div>
            </a>
        </li>
        <li class="player" data-position="3" data-age="792374400000">
            <a href="/players/12316/Naby-Keïta/overview">
                <div class="number">8</div>
                <img data-script="pl_player-image" data-widget="player-image" data-player="p175592" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p175592.png" alt="Naby Keïta">
                <div class="info">
                    <div class="name">
                        Naby Keïta
                        <div class="playerLineupEventContainer-12,316">
                        </div>
                    </div>
                    <span class="position">
                        <span>Midfielder</span>
                    </span>
                </div>
            </a>
        </li>
        <li class="player" data-position="4" data-age="505180800000">
            <a href="/players/2100/James-Milner/overview">
                <div class="number">7</div>
                <img data-script="pl_player-image" data-widget="player-image" data-player="p15157" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p15157.png" alt="James Milner">
                <div class="info">
                    <div class="name">
                        James Milner
                        <div class="playerLineupEventContainer-2,100">
            <span class="icn sub-on"></span>
                <span class="sub">86'</span>
                        </div>
                    </div>
                    <span class="position">
                        <span>Midfielder</span>
                    </span>
                </div>
            </a>
        </li>
        <li class="player" data-position="5" data-age="687052800000">
            <a href="/players/5267/Xherdan-Shaqiri/overview">
                <div class="number">23</div>
                <img data-script="pl_player-image" data-widget="player-image" data-player="p68312" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p68312.png" alt="Xherdan Shaqiri">
                <div class="info">
                    <div class="name">
                        Xherdan Shaqiri
                        <div class="playerLineupEventContainer-5,267">
                        </div>
                    </div>
                    <span class="position">
                        <span>Midfielder</span>
                    </span>
                </div>
            </a>
        </li>
        <li class="player" data-position="6" data-age="702864000000">
            <a href="/players/6519/Sadio-Mané/overview">
                <div class="number">10</div>
                <img data-script="pl_player-image" data-widget="player-image" data-player="p110979" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p110979.png" alt="Sadio Mané">
                <div class="info">
                    <div class="name">
                        Sadio Mané
                        <div class="playerLineupEventContainer-6,519">
            <span class="icn sub-on"></span>
                <span class="sub">74'</span>
                        </div>
                    </div>
                    <span class="position">
                        <span>Forward</span>
                    </span>
                </div>
            </a>
        </li>
                    </ul>
            </div>
        </div>
    </div><div aria-hidden="true" class="mcLineUpContainter matchCentrePitchContainer" data-ui-tab="Pitch" style="">
        <div class="col-4-m pitchContainer">

    <a href="/clubs/10/Liverpool/overview">
            <div class="badge badge-image-container" data-widget="club-badge-image" data-size="50">
                <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t14.png, https://resources.premierleague.com/premierleague/badges/50/t14@x2.png 2x">
            </div>
            <span class="visuallyHidden">Liverpool overview page</span>
    </a>
            <div class="pitch">
                <img src="/resources/prod/v6.98.1-4068/i/elements/lineup-pitch.jpg" alt="Pitch">
    <div class="team home pitchPositonsContainer" data-team-id="10" aria-hidden="true">
                <div class="row">
                            <div alt="" class="pos t14-bg">1</div>
                </div>
                <div class="row">
                            <div alt="" class="pos t14-bg">66</div>
                            <div alt="" class="pos t14-bg">12</div>
                            <div alt="" class="pos t14-bg">4</div>
                            <div alt="" class="pos t14-bg">26</div>
                </div>
                <div class="row">
                            <div alt="" class="pos t14-bg">14</div>
                            <div alt="" class="pos t14-bg">3</div>
                            <div alt="" class="pos t14-bg">5</div>
                </div>
                <div class="row">
                            <div alt="" class="pos t14-bg">11</div>
                            <div alt="" class="pos t14-bg">9</div>
                            <div alt="" class="pos t14-bg">27</div>
                </div>
    </div>
    <div class="team away pitchPositonsContainer" data-team-id="14" aria-hidden="true">
                <div class="row">
                            <div alt="" class="pos t45-bg">1</div>
                </div>
                <div class="row">
                            <div alt="" class="pos t45-bg">2</div>
                            <div alt="" class="pos t45-bg">5</div>
                            <div alt="" class="pos t45-bg">4</div>
                            <div alt="" class="pos t45-bg">12</div>
                </div>
                <div class="row">
                            <div alt="" class="pos t45-bg">23</div>
                            <div alt="" class="pos t45-bg">19</div>
                </div>
                <div class="row">
                            <div alt="" class="pos t45-bg">17</div>
                            <div alt="" class="pos t45-bg">18</div>
                            <div alt="" class="pos t45-bg">14</div>
                </div>
                <div class="row">
                            <div alt="" class="pos t45-bg">22</div>
                </div>
    </div>
            </div>
    <a href="/clubs/14/Norwich-City/overview">
            <div class="badge badge-image-container" data-widget="club-badge-image" data-size="50">
                <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t45.png, https://resources.premierleague.com/premierleague/badges/50/t45@x2.png 2x">
            </div>
            <span class="visuallyHidden">Norwich City overview page</span>
    </a>
        </div>
    </div><div class="teamList mcLineUpContainter awayLineup" data-ui-tab="NOR">
        <div class="col-4-m right">
            <header class="squadHeader">
    <a href="/clubs/14/Norwich-City/overview">
            <div class="badge badge-image-container" data-widget="club-badge-image" data-size="50">
                <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t45.png, https://resources.premierleague.com/premierleague/badges/50/t45@x2.png 2x">
            </div>
            <span class="visuallyHidden">Norwich City overview page</span>
    </a>
                <div class="position">
                    Norwich City
                    <strong class="matchTeamFormation" data-team-id="14">4-2-3-1</strong>
                </div>
            </header>
            <div class="matchLineupTeamContainer" data-team-id="14" data-index-class="">
                    <ul class="startingLineUpContainer squadList ">
        <li class="player" data-position="0" data-age="576028800000">
            <a href="/players/3169/Tim-Krul/overview">
                <div class="number">1</div>
                <img data-script="pl_player-image" data-widget="player-image" data-player="p20480" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p20480.png" alt="Tim Krul">
                <div class="info">
                    <div class="name">
                        Tim Krul
                        <div class="playerLineupEventContainer-3,169">
                        </div>
                    </div>
                    <span class="position">
                        <span>Goalkeeper</span>
                    </span>
                </div>
            </a>
        </li>
        <li class="player" data-position="1" data-age="946944000000">
            <a href="/players/19970/Max-Aarons/overview">
                <div class="number">2</div>
                <img data-script="pl_player-image" data-widget="player-image" data-player="p232980" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p232980.png" alt="Max Aarons">
                <div class="info">
                    <div class="name">
                        Max Aarons
                        <div class="playerLineupEventContainer-19,970">
                        </div>
                    </div>
                    <span class="position">
                        <span>Defender</span>
                    </span>
                </div>
            </a>
        </li>
        <li class="player" data-position="2" data-age="884822400000">
            <a href="/players/10968/Ben-Godfrey/overview">
                <div class="number">4</div>
                <img data-script="pl_player-image" data-widget="player-image" data-player="p198826" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p198826.png" alt="Ben Godfrey">
                <div class="info">
                    <div class="name">
                        Ben Godfrey
                        <div class="playerLineupEventContainer-10,968">
                        </div>
                    </div>
                    <span class="position">
                        <span>Defender</span>
                    </span>
                </div>
            </a>
        </li>
        <li class="player" data-position="3" data-age="885686400000">
            <a href="/players/14938/Jamal-Lewis/overview">
                <div class="number">12</div>
                <img data-script="pl_player-image" data-widget="player-image" data-player="p194799" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p194799.png" alt="Jamal Lewis">
                <div class="info">
                    <div class="name">
                        Jamal Lewis
                        <div class="playerLineupEventContainer-14,938">
                        </div>
                    </div>
                    <span class="position">
                        <span>Defender</span>
                    </span>
                </div>
            </a>
        </li>
        <li class="player" data-position="4" data-age="690595200000">
            <a href="/players/3819/Grant-Hanley/overview">
                <div class="number">5</div>
                <img data-script="pl_player-image" data-widget="player-image" data-player="p83428" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p83428.png" alt="Grant Hanley">
                <div class="info">
                    <div class="name">
                        Grant Hanley
                        <div class="playerLineupEventContainer-3,819">
            <span class="icn og-w"></span>
                        </div>
                    </div>
                    <span class="position">
                            <div class="cpt">C</div>
                        <span>Defender</span>
                    </span>
                </div>
            </a>
        </li>
        <li class="player" data-position="5" data-age="694828800000">
            <a href="/players/33061/Kenny-McLean/overview">
                <div class="number">23</div>
                <img data-script="pl_player-image" data-widget="player-image" data-player="p78607" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p78607.png" alt="Kenny McLean">
                <div class="info">
                    <div class="name">
                        Kenny McLean
                        <div class="playerLineupEventContainer-33,061">
                        </div>
                    </div>
                    <span class="position">
                        <span>Midfielder</span>
                    </span>
                </div>
            </a>
        </li>
        <li class="player" data-position="6" data-age="731635200000">
            <a href="/players/24412/Tom-Trybull/overview">
                <div class="number">19</div>
                <img data-script="pl_player-image" data-widget="player-image" data-player="p90440" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p90440.png" alt="Tom Trybull">
                <div class="info">
                    <div class="name">
                        Tom Trybull
                        <div class="playerLineupEventContainer-24,412">
            <span class="icn sub-off"></span>
                <span class="sub">70'</span>
                        </div>
                    </div>
                    <span class="position">
                        <span>Midfielder</span>
                    </span>
                </div>
            </a>
        </li>
        <li class="player" data-position="7" data-age="851472000000">
            <a href="/players/26408/Emiliano-Buendía/overview">
                <div class="number">17</div>
                <img data-script="pl_player-image" data-widget="player-image" data-player="p195546" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p195546.png" alt="Emiliano Buendía">
                <div class="info">
                    <div class="name">
                        Emiliano Buendía
                        <div class="playerLineupEventContainer-26,408">
            <span class="icn card-yellow"></span>
                        </div>
                    </div>
                    <span class="position">
                        <span>Midfielder</span>
                    </span>
                </div>
            </a>
        </li>
        <li class="player" data-position="8" data-age="888537600000">
            <a href="/players/14944/Todd-Cantwell/overview">
                <div class="number">14</div>
                <img data-script="pl_player-image" data-widget="player-image" data-player="p193111" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p193111.png" alt="Todd Cantwell">
                <div class="info">
                    <div class="name">
                        Todd Cantwell
                        <div class="playerLineupEventContainer-14,944">
                        </div>
                    </div>
                    <span class="position">
                        <span>Midfielder</span>
                    </span>
                </div>
            </a>
        </li>
        <li class="player" data-position="9" data-age="666057600000">
            <a href="/players/23199/Marco-Stiepermann/overview">
                <div class="number">18</div>
                <img data-script="pl_player-image" data-widget="player-image" data-player="p71738" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p71738.png" alt="Marco Stiepermann">
                <div class="info">
                    <div class="name">
                        Marco Stiepermann
                        <div class="playerLineupEventContainer-23,199">
            <span class="icn sub-off"></span>
                <span class="sub">58'</span>
                        </div>
                    </div>
                    <span class="position">
                        <span>Midfielder</span>
                    </span>
                </div>
            </a>
        </li>
        <li class="player" data-position="10" data-age="638668800000">
            <a href="/players/5169/Teemu-Pukki/overview">
                <div class="number">22</div>
                <img data-script="pl_player-image" data-widget="player-image" data-player="p57127" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p57127.png" alt="Teemu Pukki">
                <div class="info">
                    <div class="name">
                        Teemu Pukki
                        <div class="playerLineupEventContainer-5,169">
            <span class="icn ball-small"></span>
            <span class="icn sub-off"></span>
                <span class="sub">83'</span>
                        </div>
                    </div>
                    <span class="position">
                        <span>Forward</span>
                    </span>
                </div>
            </a>
        </li>
                    </ul>
                    <h3 class="substituteHeader ">Substitutes </h3>
                    <ul class="startingLineUpContainer squadList ">
        <li class="player" data-position="0" data-age="591321600000">
            <a href="/players/5361/Ralf-Fährmann/overview">
                <div class="number">21</div>
                <img data-script="pl_player-image" data-widget="player-image" data-player="p28082" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p28082.png" alt="Ralf Fährmann">
                <div class="info">
                    <div class="name">
                        Ralf Fährmann
                        <div class="playerLineupEventContainer-5,361">
                        </div>
                    </div>
                    <span class="position">
                        <span>Goalkeeper</span>
                    </span>
                </div>
            </a>
        </li>
        <li class="player" data-position="1" data-age="748137600000">
            <a href="/players/8945/Sam-Byram/overview">
                <div class="number">3</div>
                <img data-script="pl_player-image" data-widget="player-image" data-player="p113564" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p113564.png" alt="Sam Byram">
                <div class="info">
                    <div class="name">
                        Sam Byram
                        <div class="playerLineupEventContainer-8,945">
                        </div>
                    </div>
                    <span class="position">
                        <span>Defender</span>
                    </span>
                </div>
            </a>
        </li>
        <li class="player" data-position="2" data-age="723772800000">
            <a href="/players/15558/Moritz-Leitner/overview">
                <div class="number">10</div>
                <img data-script="pl_player-image" data-widget="player-image" data-player="p87396" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p87396.png" alt="Moritz Leitner">
                <div class="info">
                    <div class="name">
                        Moritz Leitner
                        <div class="playerLineupEventContainer-15,558">
            <span class="icn sub-on"></span>
                <span class="sub">58'</span>
            <span class="icn card-yellow"></span>
                        </div>
                    </div>
                    <span class="position">
                        <span>Midfielder</span>
                    </span>
                </div>
            </a>
        </li>
        <li class="player" data-position="3" data-age="855100800000">
            <a href="/players/8710/Patrick-Roberts/overview">
                <div class="number">7</div>
                <img data-script="pl_player-image" data-widget="player-image" data-player="p124165" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p124165.png" alt="Patrick Roberts">
                <div class="info">
                    <div class="name">
                        Patrick Roberts
                        <div class="playerLineupEventContainer-8,710">
                        </div>
                    </div>
                    <span class="position">
                        <span>Midfielder</span>
                    </span>
                </div>
            </a>
        </li>
        <li class="player" data-position="4" data-age="728524800000">
            <a href="/players/33066/Onel-Hernández/overview">
                <div class="number">11</div>
                <img data-script="pl_player-image" data-widget="player-image" data-player="p89470" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p89470.png" alt="Onel Hernández">
                <div class="info">
                    <div class="name">
                        Onel Hernández
                        <div class="playerLineupEventContainer-33,066">
            <span class="icn sub-on"></span>
                <span class="sub">70'</span>
                        </div>
                    </div>
                    <span class="position">
                        <span>Midfielder</span>
                    </span>
                </div>
            </a>
        </li>
        <li class="player" data-position="5" data-age="611884800000">
            <a href="/players/22040/Mario-Vrancic/overview">
                <div class="number">8</div>
                <img data-script="pl_player-image" data-widget="player-image" data-player="p37614" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p37614.png" alt="Mario Vrancic">
                <div class="info">
                    <div class="name">
                        Mario Vrancic
                        <div class="playerLineupEventContainer-22,040">
                        </div>
                    </div>
                    <span class="position">
                        <span>Midfielder</span>
                    </span>
                </div>
            </a>
        </li>
        <li class="player" data-position="6" data-age="713232000000">
            <a href="/players/11111/Josip-Drmic/overview">
                <div class="number">20</div>
                <img data-script="pl_player-image" data-widget="player-image" data-player="p81048" data-size="110x140" class="img" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p81048.png" alt="Josip Drmic">
                <div class="info">
                    <div class="name">
                        Josip Drmic
                        <div class="playerLineupEventContainer-11,111">
            <span class="icn sub-on"></span>
                <span class="sub">83'</span>
                        </div>
                    </div>
                    <span class="position">
                        <span>Forward</span>
                    </span>
                </div>
            </a>
        </li>
                    </ul>
            </div>
        </div>
    </div></div>
    


    
                </div>
              </section><section class="mcMainTab head-to-head" data-ui-tab="Stats" data-ui-args="{&quot;type&quot;: &quot;stats&quot;}">

                <div class="toggle-button">
                    <ul class="toggle matchCentreStatsTabToggles"><ul class="tablist" role="tablist"><li role="tab" tabindex="0" data-tab-index="0">Head-to-Head</li><li role="tab" tabindex="0" data-tab-index="1" class="active">Match Stats</li></ul></ul>
                </div>

                <div class="mcTabs"><div class="mcStatsTab" data-ui-tab="Head-to-Head" data-ui-args="{&quot;type&quot;: &quot;headToHead&quot;}">
                    <div class="headToHeadTabContainer"><div class="headToHeadFixtureContainer">
		<div class="wrapper col-12">
			<section class="statsSection head-to-head">

				<h3 class="subHeader">Head-to-Head</h3>





	<div class="headToHeadTable headToHeadTableLeft">

	<a href="/clubs/10/Liverpool/overview" class="team">
		Liverpool
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                <img class="badge-image js-badge-image" onerror="this.src='https://resources.premierleague.com/premierleague/badges/25/default.png'" src="https://resources.premierleague.com/premierleague/badges/25/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t14@x2.png 2x">
            </span>
	</a>
		<div class="statRow">
			<div class="statDetails">
				<div class="stat">Total Wins</div>
				<div class="count">15</div>
			</div>
			<div class="status-bar">
				<div class="result" style="width: 88.235%;"></div>
			</div>
		</div>
		<div class="statRow">
			<div class="statDetails">
				<div class="stat">Home</div>
				<div class="count">7</div>
			</div>
			<div class="status-bar">
				<div class="result" style="width: 87.5%;"></div>
			</div>
		</div>
		<div class="statRow">
			<div class="statDetails">
				<div class="stat">Away</div>
				<div class="count">8</div>
			</div>
			<div class="status-bar">
				<div class="result" style="width: 88.889%;"></div>
			</div>
		</div>
	</div>


	<div class="headToHeadTable headToHeadTableRight">

	<a href="/clubs/14/Norwich-City/overview" class="team">
		Norwich
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                <img class="badge-image js-badge-image" onerror="this.src='https://resources.premierleague.com/premierleague/badges/25/default.png'" src="https://resources.premierleague.com/premierleague/badges/25/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t45@x2.png 2x">
            </span>
	</a>
		<div class="statRow">
			<div class="statDetails">
				<div class="stat">Total Wins</div>
				<div class="count">2</div>
			</div>
			<div class="status-bar">
				<div class="result" style="width: 11.765%;"></div>
			</div>
		</div>
		<div class="statRow">
			<div class="statDetails">
				<div class="stat">Home</div>
				<div class="count">1</div>
			</div>
			<div class="status-bar">
				<div class="result" style="width: 12.5%;"></div>
			</div>
		</div>
		<div class="statRow">
			<div class="statDetails">
				<div class="stat">Away</div>
				<div class="count">1</div>
			</div>
			<div class="status-bar">
				<div class="result" style="width: 11.111%;"></div>
			</div>
		</div>
	</div>

				<div class="middle-section">
					<p class="header">Played</p>
					<p class="number">20</p>
					<p class="draws">Draws
						<span>3</span>
					</p>
				</div>

			</section>
		</div>

			<div class="wrapper col-12">
				<section class="statsSection h2h-previous-meetings">
					<h3 class="subHeader">Recent Meetings</h3>
					<ul class="previous-meetings">
	<li class="matchFixtureContainer">
		<time>Saturday 19 February 2022</time>
		<span class="stadiumName"><p><span class="icn stadium"></span>Anfield, Liverpool</p></span>
		<a href="/match/66597" class="fixture">
			<span class="overview">
				<span class="teams">
					<span class="team">
						<span class="teamName">Liverpool</span>
                             <div class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                                <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t14@x2.png 2x">
                            </div>
					</span>
					<span class="score">3<span>-</span>1</span>
					<span class="team">
                             <div class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                                <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t45@x2.png 2x">
                             </div>
			            <span class="teamName">Norwich</span>
					</span>
				</span>
				<span class="icn arrow-right"></span>
			</span>
		</a>
	</li>
	<li class="matchFixtureContainer">
		<time>Saturday 14 August 2021</time>
		<span class="stadiumName"><p><span class="icn stadium"></span>Carrow Road, Norwich</p></span>
		<a href="/match/66349" class="fixture">
			<span class="overview">
				<span class="teams">
					<span class="team">
						<span class="teamName">Norwich</span>
                             <div class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                                <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t45@x2.png 2x">
                            </div>
					</span>
					<span class="score">0<span>-</span>3</span>
					<span class="team">
                             <div class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                                <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t14@x2.png 2x">
                             </div>
			            <span class="teamName">Liverpool</span>
					</span>
				</span>
				<span class="icn arrow-right"></span>
			</span>
		</a>
	</li>
	<li class="matchFixtureContainer">
		<time>Saturday 15 February 2020</time>
		<span class="stadiumName"><p><span class="icn stadium"></span>Carrow Road, Norwich</p></span>
		<a href="/match/46861" class="fixture">
			<span class="overview">
				<span class="teams">
					<span class="team">
						<span class="teamName">Norwich</span>
                             <div class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                                <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t45@x2.png 2x">
                            </div>
					</span>
					<span class="score">0<span>-</span>1</span>
					<span class="team">
                             <div class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                                <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t14@x2.png 2x">
                             </div>
			            <span class="teamName">Liverpool</span>
					</span>
				</span>
				<span class="icn arrow-right"></span>
			</span>
		</a>
	</li>
	<li class="matchFixtureContainer">
		<time>Friday 09 August 2019</time>
		<span class="stadiumName"><p><span class="icn stadium"></span>Anfield, Liverpool</p></span>
		<a href="/match/46605" class="fixture">
			<span class="overview">
				<span class="teams">
					<span class="team">
						<span class="teamName">Liverpool</span>
                             <div class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                                <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t14@x2.png 2x">
                            </div>
					</span>
					<span class="score">4<span>-</span>1</span>
					<span class="team">
                             <div class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                                <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t45@x2.png 2x">
                             </div>
			            <span class="teamName">Norwich</span>
					</span>
				</span>
				<span class="icn arrow-right"></span>
			</span>
		</a>
	</li>
	<li class="matchFixtureContainer">
		<time>Saturday 23 January 2016</time>
		<span class="stadiumName"><p><span class="icn stadium"></span>Carrow Road, Norwich</p></span>
		<a href="/match/12338" class="fixture">
			<span class="overview">
				<span class="teams">
					<span class="team">
						<span class="teamName">Norwich</span>
                             <div class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                                <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t45@x2.png 2x">
                            </div>
					</span>
					<span class="score">4<span>-</span>5</span>
					<span class="team">
                             <div class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                                <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t14@x2.png 2x">
                             </div>
			            <span class="teamName">Liverpool</span>
					</span>
				</span>
				<span class="icn arrow-right"></span>
			</span>
		</a>
	</li>
					</ul>
				</section>
			</div>

			<div class="wrapper col-12">
				<section class="statsSection form-guide">
					<h3 class="subHeader">Form Guide</h3>




	<div class="team teamLeft">

	<a href="/clubs/10/Liverpool/overview" class="teamName">
		Liverpool
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                <img class="badge-image js-badge-image" onerror="this.src='https://resources.premierleague.com/premierleague/badges/25/default.png'" src="https://resources.premierleague.com/premierleague/badges/25/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t14@x2.png 2x">
            </span>
	</a>
			<div class="formRow">
				<a href="/match/66719">
					<span class="result win">W</span>
					<strong>H</strong>
                        <span class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                           <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t39.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t39@x2.png 2x">
                       </span>
					<span class="opposition">3-1 v Wolves</span>
				</a>
			</div>
			<div class="formRow">
				<a href="/match/66707">
					<span class="result win">W</span>
					<strong>A</strong>
                        <span class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                           <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t20.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t20@x2.png 2x">
                       </span>
					<span class="opposition">2-1 v Southampton</span>
				</a>
			</div>
			<div class="formRow">
				<a href="/match/66662">
					<span class="result win">W</span>
					<strong>A</strong>
                        <span class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                           <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t7.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t7@x2.png 2x">
                       </span>
					<span class="opposition">2-1 v Aston Villa</span>
				</a>
			</div>
			<div class="formRow">
				<a href="/match/66699">
					<span class="result draw">D</span>
					<strong>H</strong>
                        <span class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                           <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t6.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t6@x2.png 2x">
                       </span>
					<span class="opposition">1-1 v Spurs</span>
				</a>
			</div>
			<div class="formRow">
				<a href="/match/66686">
					<span class="result win">W</span>
					<strong>A</strong>
                        <span class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                           <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t4.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t4@x2.png 2x">
                       </span>
					<span class="opposition">1-0 v Newcastle</span>
				</a>
			</div>
	</div>


	<div class="team teamRight">

	<a href="/clubs/14/Norwich-City/overview" class="teamName">
		Norwich
            <span class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                <img class="badge-image js-badge-image" onerror="this.src='https://resources.premierleague.com/premierleague/badges/25/default.png'" src="https://resources.premierleague.com/premierleague/badges/25/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t45@x2.png 2x">
            </span>
	</a>
			<div class="formRow">
				<a href="/match/66721">
					<span class="result lose">L</span>
					<strong>H</strong>
                        <span class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                           <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t6.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t6@x2.png 2x">
                       </span>
					<span class="opposition">0-5 v Spurs</span>
				</a>
			</div>
			<div class="formRow">
				<a href="/match/66711">
					<span class="result draw">D</span>
					<strong>A</strong>
                        <span class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                           <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t39.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t39@x2.png 2x">
                       </span>
					<span class="opposition">1-1 v Wolves</span>
				</a>
			</div>
			<div class="formRow">
				<a href="/match/66548">
					<span class="result lose">L</span>
					<strong>A</strong>
                        <span class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                           <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t13.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t13@x2.png 2x">
                       </span>
					<span class="opposition">0-3 v Leicester</span>
				</a>
			</div>
			<div class="formRow">
				<a href="/match/66701">
					<span class="result lose">L</span>
					<strong>H</strong>
                        <span class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                           <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t21.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t21@x2.png 2x">
                       </span>
					<span class="opposition">0-4 v West Ham</span>
				</a>
			</div>
			<div class="formRow">
				<a href="/match/66682">
					<span class="result lose">L</span>
					<strong>A</strong>
                        <span class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                           <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t7.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t7@x2.png 2x">
                       </span>
					<span class="opposition">0-2 v Aston Villa</span>
				</a>
			</div>
	</div>
				</section>
			</div>
	</div></div>
                    <div class="wrapper col-12">
                        <section class="statsSection season-so-far">
                            <h3 class="subHeader">Season So Far</h3>
                            <table>
                                <thead>
                                    <tr>
                                        <th>    <a href="/clubs/10/Liverpool/overview">
            <div class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t14.png, https://resources.premierleague.com/premierleague/badges/25/t14@x2.png 2x">
            </div>
            Liverpool
    </a>
</th>
                                        <th>&nbsp;</th>
                                        <th>    <a href="/clubs/14/Norwich-City/overview">
            <div class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t45.png, https://resources.premierleague.com/premierleague/badges/25/t45@x2.png 2x">
            </div>
            Norwich City
    </a>
</th>
                                    </tr>
                                </thead>
                                <tbody class="seasonSoFarTabContainer"></tbody>
                            </table>
                        </section>

                        <div class="statsSection season-stats">
                            <h3 class="subHeader">Top Player Stats</h3>
                            <section class="mainWidget statsRow">
                                <ul data-script="pl_stats" data-widget="top-stats-header" data-header-id="matchCentreTopPlayers" class="block-list-4 mobileScrollList"><li><div data-stat-header="matchCentreTopPlayers" class="statsCard">


    <header>
      <h4 class="statsTitle"><a href="/stats/top/players/goals?se=274&amp;cl=10">Goals</a></h4>
      <div data-script="pl_social-share" data-widget="social-page-share" data-render="statsshare" data-link-to="/stats/top/players/goals?se=274&amp;cl=10" data-body="Official Premier League Stats - Goals"><div class="socialShare widgetShare"><div class="socialShareBtn" tabindex="0" role="button"><div class="icn share-black"></div><span class="share-label">Share</span></div><ul class="socialOptions" role="listbox"><li><div role="option" class="option twitter" tabindex="0"><span class="icn twitter-w" data-social-service="twitter"><span class="visuallyHidden">Share on Twitter</span></span></div></li><li><div role="option" class="option facebook" tabindex="0"><span class="icn facebook-w" data-social-service="facebook"><span class="visuallyHidden">Share on Facebook</span></span></div></li><li><div role="option" class="option whatsapp" tabindex="0"><span class="icn whatsapp-w" data-social-service="whatsapp"><span class="visuallyHidden">action.share.whatsApp</span></span></div></li></ul></div></div>
    </header>

    <ul class="statsList">
  <li class="statsHero  ">
    <div class="statInfo">
      <div class="pos">1.</div>
        <a href="/players/5178/Mohamed-Salah/overview" class="statName">Mohamed<br>Salah Ghaly</a>

        <a href="/clubs/10/Liverpool/overview" class="statNameSecondary">Liverpool</a>

      <div class="stat">
          19
      </div>
    </div>
        <div class="heroBadgeContainer">
          <div class="statsBadge">
            <div class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t14@x2.png 2x">
            </div>
          </div>
        </div>
    <div class="imgCropContainer">
      <img data-script="pl_player-image" data-widget="player-image" data-player="p118748" data-size="110x140" class="img statCardImg" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p118748.png" alt="Photo for Mohamed Salah">
    </div>
  </li>

  <li class="statsRow">
    <div class="pos">2.</div>
    <div class="teamInfo">
        <a href="/players/6519/Sadio-Mané/overview" class="statName">Sadio Mané</a>
    </div>

    <div class="stat">
      18
    </div>
  </li>
  <li class="statsRow">
    <div class="pos">3.</div>
    <div class="teamInfo">
        <a href="/players/5169/Teemu-Pukki/overview" class="statName">Teemu Pukki</a>
    </div>

    <div class="stat">
      11
    </div>
  </li>
    </ul>

      <a class="statsCard__button" href="/stats/top/players/goals?se=274&amp;cl=10">View More<span class="visuallyHidden"> Goals</span><span class="statsCard__button-icon icn arrow-rightpink"></span></a>

  </div></li><li><div data-stat-header="matchCentreTopPlayers" class="statsCard">


    <header>
      <h4 class="statsTitle"><a href="/stats/top/players/goal_assist?se=274&amp;cl=10">Assists</a></h4>
      <div data-script="pl_social-share" data-widget="social-page-share" data-render="statsshare" data-link-to="/stats/top/players/goal_assist?se=274&amp;cl=10" data-body="Official Premier League Stats - Assists"><div class="socialShare widgetShare"><div class="socialShareBtn" tabindex="0" role="button"><div class="icn share-black"></div><span class="share-label">Share</span></div><ul class="socialOptions" role="listbox"><li><div role="option" class="option twitter" tabindex="0"><span class="icn twitter-w" data-social-service="twitter"><span class="visuallyHidden">Share on Twitter</span></span></div></li><li><div role="option" class="option facebook" tabindex="0"><span class="icn facebook-w" data-social-service="facebook"><span class="visuallyHidden">Share on Facebook</span></span></div></li><li><div role="option" class="option whatsapp" tabindex="0"><span class="icn whatsapp-w" data-social-service="whatsapp"><span class="visuallyHidden">action.share.whatsApp</span></span></div></li></ul></div></div>
    </header>

    <ul class="statsList">
  <li class="statsHero  ">
    <div class="statInfo">
      <div class="pos">1.</div>
        <a href="/players/14732/Trent-Alexander-Arnold/overview" class="statName">Trent<br>Alexander-Arnold</a>
      <div class="stat">
          13
      </div>
    </div>
    <div class="imgCropContainer">
      <img data-script="pl_player-image" data-widget="player-image" data-player="p169187" data-size="110x140" class="img statCardImg" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p169187.png" alt="Photo for Trent Alexander-Arnold">
    </div>
  </li>

  <li class="statsRow">
    <div class="pos">2.</div>
    <div class="teamInfo">
        <a href="/players/10458/Andrew-Robertson/overview" class="statName">Andrew Robertson</a>
    </div>

    <div class="stat">
      12
    </div>
  </li>
  <li class="statsRow">
    <div class="pos">3.</div>
    <div class="teamInfo">
        <a href="/players/5178/Mohamed-Salah/overview" class="statName">Mohamed Salah</a>
    </div>

    <div class="stat">
      10
    </div>
  </li>
    </ul>

      <a class="statsCard__button" href="/stats/top/players/goal_assist?se=274&amp;cl=10">View More<span class="visuallyHidden"> Assists</span><span class="statsCard__button-icon icn arrow-rightpink"></span></a>

  </div></li><li><div data-stat-header="matchCentreTopPlayers" class="statsCard">


    <header>
      <h4 class="statsTitle"><a href="/stats/top/players/total_pass?se=274&amp;cl=10">Passes</a></h4>
      <div data-script="pl_social-share" data-widget="social-page-share" data-render="statsshare" data-link-to="/stats/top/players/total_pass?se=274&amp;cl=10" data-body="Official Premier League Stats - Passes"><div class="socialShare widgetShare"><div class="socialShareBtn" tabindex="0" role="button"><div class="icn share-black"></div><span class="share-label">Share</span></div><ul class="socialOptions" role="listbox"><li><div role="option" class="option twitter" tabindex="0"><span class="icn twitter-w" data-social-service="twitter"><span class="visuallyHidden">Share on Twitter</span></span></div></li><li><div role="option" class="option facebook" tabindex="0"><span class="icn facebook-w" data-social-service="facebook"><span class="visuallyHidden">Share on Facebook</span></span></div></li><li><div role="option" class="option whatsapp" tabindex="0"><span class="icn whatsapp-w" data-social-service="whatsapp"><span class="visuallyHidden">action.share.whatsApp</span></span></div></li></ul></div></div>
    </header>

    <ul class="statsList">
  <li class="statsHero  ">
    <div class="statInfo">
      <div class="pos">1.</div>
        <a href="/players/5140/Virgil-van-Dijk/overview" class="statName">Virgil<br>van Dijk</a>

        <a href="/clubs/10/Liverpool/overview" class="statNameSecondary">Liverpool</a>

      <div class="stat">
          3,259
      </div>
    </div>
        <div class="heroBadgeContainer">
          <div class="statsBadge">
            <div class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t14@x2.png 2x">
            </div>
          </div>
        </div>
    <div class="imgCropContainer">
      <img data-script="pl_player-image" data-widget="player-image" data-player="p97032" data-size="110x140" class="img statCardImg" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p97032.png" alt="Photo for Virgil van Dijk">
    </div>
  </li>

  <li class="statsRow">
    <div class="pos">2.</div>
        <div class="statsBadge">
            <div class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t14@x2.png 2x">
            </div>
        </div>
    <div class="teamInfo">
        <a href="/players/10458/Andrew-Robertson/overview" class="statName">Andrew Robertson</a>

        <a href="/clubs/10/Liverpool/overview" class="statNameSecondary">Liverpool</a>

    </div>

    <div class="stat">
      2,492
    </div>
  </li>
  <li class="statsRow">
    <div class="pos">3.</div>
        <div class="statsBadge">
            <div class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t14@x2.png 2x">
            </div>
        </div>
    <div class="teamInfo">
        <a href="/players/14732/Trent-Alexander-Arnold/overview" class="statName">Trent Alexander-Arnold</a>

        <a href="/clubs/10/Liverpool/overview" class="statNameSecondary">Liverpool</a>

    </div>

    <div class="stat">
      2,440
    </div>
  </li>
    </ul>

      <a class="statsCard__button" href="/stats/top/players/total_pass?se=274&amp;cl=10">View More<span class="visuallyHidden"> Passes</span><span class="statsCard__button-icon icn arrow-rightpink"></span></a>

  </div></li><li><div data-stat-header="matchCentreTopPlayers" class="statsCard">


    <header>
      <h4 class="statsTitle"><a href="/stats/top/players/total_tackle?se=274&amp;cl=10">Tackles</a></h4>
      <div data-script="pl_social-share" data-widget="social-page-share" data-render="statsshare" data-link-to="/stats/top/players/total_tackle?se=274&amp;cl=10" data-body="Official Premier League Stats - Tackles"><div class="socialShare widgetShare"><div class="socialShareBtn" tabindex="0" role="button"><div class="icn share-black"></div><span class="share-label">Share</span></div><ul class="socialOptions" role="listbox"><li><div role="option" class="option twitter" tabindex="0"><span class="icn twitter-w" data-social-service="twitter"><span class="visuallyHidden">Share on Twitter</span></span></div></li><li><div role="option" class="option facebook" tabindex="0"><span class="icn facebook-w" data-social-service="facebook"><span class="visuallyHidden">Share on Facebook</span></span></div></li><li><div role="option" class="option whatsapp" tabindex="0"><span class="icn whatsapp-w" data-social-service="whatsapp"><span class="visuallyHidden">action.share.whatsApp</span></span></div></li></ul></div></div>
    </header>

    <ul class="statsList">
  <li class="statsHero  ">
    <div class="statInfo">
      <div class="pos">1.</div>
        <a href="/players/26408/Emiliano-Buendía/overview" class="statName">Emiliano<br>Buendía</a>
      <div class="stat">
          82
      </div>
    </div>
    <div class="imgCropContainer">
      <img data-script="pl_player-image" data-widget="player-image" data-player="p195546" data-size="110x140" class="img statCardImg" src="https://resources.premierleague.com/premierleague/photos/players/110x140/p195546.png" alt="Photo for Emiliano Buendía">
    </div>
  </li>

  <li class="statsRow">
    <div class="pos">2.</div>
        <div class="statsBadge">
            <div class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t14@x2.png 2x">
            </div>
        </div>
    <div class="teamInfo">
        <a href="/players/3712/Jordan-Henderson/overview" class="statName">Jordan Henderson</a>

        <a href="/clubs/10/Liverpool/overview" class="statNameSecondary">Liverpool</a>

    </div>

    <div class="stat">
      63
    </div>
  </li>
  <li class="statsRow">
    <div class="pos">3.</div>
        <div class="statsBadge">
            <div class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t14@x2.png 2x">
            </div>
        </div>
    <div class="teamInfo">
        <a href="/players/11247/Fabinho/overview" class="statName">Fabinho</a>

        <a href="/clubs/10/Liverpool/overview" class="statNameSecondary">Liverpool</a>

    </div>

    <div class="stat">
      62
    </div>
  </li>
    </ul>

      <a class="statsCard__button" href="/stats/top/players/total_tackle?se=274&amp;cl=10">View More<span class="visuallyHidden"> Tackles</span><span class="statsCard__button-icon icn arrow-rightpink"></span></a>

  </div></li></ul>
                            </section>
                        </div>
                    </div>
                </div><div class="mcStatsTab statsSection season-so-far wrapper col-12 active" data-ui-tab="Match Stats" data-ui-args="{&quot;type&quot;: &quot;stats&quot;}">
                    <h3 class="subHeader">Match Stats</h3>
                    <table>
                        <thead>
                            <tr>
                                <th>    <a href="/clubs/10/Liverpool/overview">
            <div class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t14.png, https://resources.premierleague.com/premierleague/badges/25/t14@x2.png 2x">
            </div>
            Liverpool
    </a>
</th>
                                <th>&nbsp;</th>
                                <th>    <a href="/clubs/14/Norwich-City/overview">
            <div class="badge badge-image-container" data-widget="club-badge-image" data-size="25">
                <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t45.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t45.png, https://resources.premierleague.com/premierleague/badges/25/t45@x2.png 2x">
            </div>
            Norwich City
    </a>
</th>
                            </tr>
                        </thead>
                        <tbody class="matchCentreStatsContainer"></tbody>
                    </table>
                </div></div>

                
            </section><section class="mcMainTab" data-ui-class="js-mc-related-tab" data-ui-tab="Related" data-ui-args="{&quot;type&quot;: &quot;related&quot;}">
            <div class="wrapper">
                <div class="col-12 mcRelatedContainer">
                    



	<section class="mainWidget latestFeatures ">
		<!-- TO-TRANSLATE -->
	        <header>
	            <h3 class="subHeader">Related News</h3>
	        </header>



        <ul class="block-list-4" data-widget="lazy-load">
	<li class="article-thumb placeholder js-content-load" data-initialised="false">


		<a href="/news/1348626" class="thumbnail">
			<figure>
				<span class="image thumbCrop-latestnews">
				
						<img class="article-thumb__img" src="https://resources.premierleague.com/photos/2019/09/18/a7f2f8e2-c640-4e4d-89ed-adb98253d931/cantwell-farke-pl-debut-ball.png?width=100&amp;height=56" data-src="            https://resources.premierleague.com/photos/2019/09/18/a7f2f8e2-c640-4e4d-89ed-adb98253d931/cantwell-farke-pl-debut-ball.png?width=500&amp;height=333
" data-src-placeholder="https://resources.premierleague.com/photos/2019/09/18/a7f2f8e2-c640-4e4d-89ed-adb98253d931/cantwell-farke-pl-debut-ball.png?width=100&amp;height=56" alt="Cantwell: Playing in PL for Norwich is extra special">
					
				</span>
				<figcaption>


					<span class="tag">Feature</span>
					<span class="title">Cantwell: Playing for my boyhood club is surreal</span>
				</figcaption>
			</figure>
		</a>
			<div class="relatedArticles">

	<a href="/news/1348683" class="relatedArticle club text">
		<p>
			GW6 Ones to watch: Todd Cantwell
		</p>
	</a>

	<a href="/news/1347318" class="relatedArticle club text">
		<p>
			Norwich defeat of champions no longer such a shock
		</p>
	</a>
			</div>
	</li>
	<li class="article-thumb placeholder js-content-load" data-initialised="false">


		<a href="/news/1310396" class="thumbnail">
			<figure>
				<span class="image thumbCrop-latestnews">
				
                        <img class="article-thumb__img" src="https://resources.premierleague.com/photos/2019/08/12/4eb12887-b80d-4c77-8da0-6b9a3ff55a36/GettyImages-1167130784.jpg?width=100&amp;height=67" data-src="            https://resources.premierleague.com/photos/2019/08/12/4eb12887-b80d-4c77-8da0-6b9a3ff55a36/GettyImages-1167130784.jpg?width=500&amp;height=333
					<span class="title">MW1 stats: Arsenal get their teenage kicks</span>
				</figcaption>
			</figure>
		</a>
			<div class="relatedArticles">

	<a href="/news/1301791" class="relatedArticle club text">
		<p>
			Aubameyang matches Torres with winner
		</p>
	</a>

	<a href="/news/1306457" class="relatedArticle club text">
		<p>
			Sterling joins opening day hat-trick kings
		</p>
	</a>
			</div>
	</li>
		</ul>



			<a class="btn moreBtn widget-button" href="/news/fixture/46605">More News<span class="visuallyHidden">: Related News</span><span class="icn arrow-right"></span></a>
	</section>






    <section class="mainWidget thumbnailList   " data-script="pl_editorial-lists" data-widget="video-list">
            <header>
                <h3 class="subHeader">Related Videos</h3>
            </header>



        <ul class="block-list-4" data-widget="lazy-load">



    <li data-ui-modal="#videoPlayer" data-link="/video/single/596411?TAG=On this Day" data-ui-args="{&quot;contentId&quot;: 596411, &quot;mediaId&quot;:5712809167001, &quot;mediaTitle&quot;:&quot;Flashback: Liverpool 5-0 Norwich&quot;, &quot;mediaDescription&quot;:&quot;A Jordan Henderson hammer helped the Reds to a big victory at Anfield&quot;, &quot;mediaDate&quot;:&quot;17/2/2022&quot;, &quot;mediaDuration&quot;:&quot;01:18 &quot;, &quot;mediaHotlinkUrl&quot;:&quot;&quot;, &quot;mediaHotlinkText&quot;:&quot;&quot;}" data-modal-active="true">
            <a href="/video/single/596411?TAG=On this Day" class="thumbnail videoThumb placeholder js-content-load " data-initialised="false">
            <figure>
            <span class="image thumbCrop-video-small">
                <svg class="videoThumb__play-icon" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 35 40">
                    <path d="M0 3.29C0 .743 2.805-.835 5.017.468l28.361 16.71c2.163 1.273 2.163 4.373 0 5.645L5.018 39.533C2.804 40.836 0 39.257 0 36.709V3.291z"></path>
                </svg>
                    <img class="videoThumb__img" src="https://resources.premierleague.com/premierleague/photo/2018/01/16/7f1eb65a-f09f-443e-9e68-684343804cab/GettyImages-159718552.jpg" data-src="https://resources.premierleague.com/photos/premierleague/photo/2018/01/16/fe07dc85-1b17-4afc-80fa-2aed3693db4c/GettyImages-159718552.jpg?width=320&amp;height=180" data-src-placeholder="https://resources.premierleague.com/premierleague/photo/2018/01/16/7f1eb65a-f09f-443e-9e68-684343804cab/GettyImages-159718552.jpg" alt="">
                <span class="runTime">
                    <span class="icn play-w"></span>
                    <time datetime="PT2M59S">01:18</time>
                </span>
            </span>
                <figcaption>
                    <span class="title">Flashback: Liverpool 5-0 Norwich</span>
                    <time class="published">17/2/2022</time>
        <span class="closedCaption">CC</span>
        <span class="audioDesc">AD</span>
                </figcaption>
            </figure>
        </a>
    </li>




    <li data-ui-modal="#videoPlayer" data-link="/video/single/2207949?TAG=On this Day" data-ui-args="{&quot;contentId&quot;: 2207949, &quot;mediaId&quot;:6266773611001, &quot;mediaTitle&quot;:&quot;Flashback: Liverpool 4-1 Norwich&quot;, &quot;mediaDescription&quot;:&quot;The Reds kicked off their title-winning 2019/20 campaign with a stylish victory at Anfield&quot;, &quot;mediaDate&quot;:&quot;17/2/2022&quot;, &quot;mediaDuration&quot;:&quot;02:20 &quot;, &quot;mediaHotlinkUrl&quot;:&quot;&quot;, &quot;mediaHotlinkText&quot;:&quot;&quot;}" data-modal-active="true">
            <a href="/video/single/2207949?TAG=On this Day" class="thumbnail videoThumb placeholder js-content-load " data-initialised="false">
            <figure>
            <span class="image thumbCrop-video-small">
                <svg class="videoThumb__play-icon" xmlns="http://www.w3.org/2000/svg" viewBox="0 0
                </span>
            </span>
                <figcaption>
                    <span class="title">Watch Suarez's first hat-trick at Norwich</span>
                    <time class="published">13/8/2021</time>
        <span class="closedCaption">CC</span>
        <span class="audioDesc">AD</span>
                </figcaption>
            </figure>
        </a>
    </li>




    <li data-ui-modal="#videoPlayer" data-link="/video/single/424888?TAG=Iconic Moments" data-ui-args="{&quot;contentId&quot;: 424888, &quot;mediaId&quot;:5487429845001, &quot;mediaTitle&quot;:&quot;Iconic Moment: Lallana seals epic Liverpool win at Norwich&quot;, &quot;mediaDescription&quot;:&quot;Jurgen Klopp joined the mass celebrations as the Reds won 5-4 in 2015/16&quot;, &quot;mediaDate&quot;:&quot;13/8/2021&quot;, &quot;mediaDuration&quot;:&quot;01:35 &quot;, &quot;mediaHotlinkUrl&quot;:&quot;&quot;, &quot;mediaHotlinkText&quot;:&quot;&quot;}" data-modal-active="true">
            <a href="/video/single/424888?TAG=Iconic Moments" class="thumbnail videoThumb placeholder js-content-load " data-initialised="false">
            <figure>
            <span class="image thumbCrop-video-small">
                <svg class="videoThumb__play-icon" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 35 40">
                    <path d="M0 3.29C0 .743 2.805-.835 5.017.468l28.361 16.71c2.163 1.273 2.163 4.373 0 5.645L5.018 39.533C2.804 40.836 0 39.257 0 36.709V3.291z"></path>
                </svg>
                    <img class="videoThumb__img" src="https://resources.premierleague.com/photos/2019/06/13/4ce2a1fe-2a76-4c40-b58a-ab814963343f/SLpBLqDx.jpg?width=100&amp;height=56" data-src="https://resources.premierleague.com/photos/2019/06/13/4ce2a1fe-2a76-4c40-b58a-ab814963343f/SLpBLqDx.jpg?width=320&amp;height=180" data-src-placeholder="https://resources.premierleague.com/photos/2019/06/13/4ce2a1fe-2a76-4c40-b58a-ab814963343f/SLpBLqDx.jpg?width=100&amp;height=56" alt="">
                <span class="runTime">
                    <span class="icn play-w"></span>
                    <time datetime="PT2M59S">01:35</time>
                </span>
            </span>
                <figcaption>
                    <span class="title">Iconic Moment: Lallana seals epic Liverpool win at Norwich</span>
                    <time class="published">13/8/2021</time>
        <span class="closedCaption">CC</span>
        <span class="audioDesc">AD</span>
                </figcaption>
            </figure>
        </a>
    </li>

        </ul>



			<a class="btn moreBtn widget-button" href="/video/fixture/46605">More Videos<span class="visuallyHidden">: Related Videos</span><span class="icn arrow-right"></span></a>
    </section>


                </div>
            </div>
        </section></div>

        <!-- SQUADS / LINE-UPS TAB -->


            

        <!-- STATS TAB -->
            

        <!-- RELATED NEWS TAB -->
        

        <!-- SOCIAL TAB -->

    </div>






  




  




  




  


            </div>
        </section>
</div>
</main>

<footer class="mainFooter">
	

        <div class="footerSponsorStrip">
            <ul>
    <li class="">
        <a href="https://www.easports.com/fifa?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link" target="_blank">
                <span class="large icn sponsor-footer-ea sponsor-footer-ea-n"></span>
                <span class="small icn sponsor-footer-ea-sm"></span>
            <span class="type">Lead Partner<span class="visuallyHidden">EA SPORTS</span></span>
        </a>
    </li>
    <li class="">
        <a href="https://www.home.barclays/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link" target="_blank">
                <span class="large icn sponsor-footer-barclays sponsor-footer-barclays-n"></span>
                <span class="small icn sponsor-footer-barclays-sm"></span>
            <span class="type">Official Bank<span class="visuallyHidden">Barclays</span></span>
        </a>
    </li>
    <li class="">
        <a href="https://www.budweiser.com" target="_blank">
                <span class="large icn sponsor-footer-budweiser sponsor-footer-budweiser-n"></span>
                <span class="small icn sponsor-footer-budweiser-sm"></span>
            <span class="type">Official Beer<span class="visuallyHidden">Budweiser</span></span>
        </a>
    </li>
    <li class="">
        <a href="https://www.castrol.com/en_gb/united-kingdom/home.html" target="_blank">
                <span class="large icn sponsor-footer-castrol sponsor-footer-castrol-n"></span>
                <span class="small icn sponsor-footer-castrol-sm"></span>
            <span class="type">Official Engine Oil Partner<span class="visuallyHidden">Castrol</span></span>
        </a>
    </li>
    <li class="">
        <a href="https://www.hublot.com/?utm_source=premier-league&amp;utm_medium=referral&amp;utm_campaign=premier-league-website" target="_blank">
    <img src="https://www.premierleague.com/resources/prod/v6.98.1-4068/i/svg-files/partners/hublot.svg" alt="Hublot" class="footerSponsorStrip__image">
            <span class="type">Official Timekeeper<span class="visuallyHidden">Hublot</span></span>
        </a>
    </li>
    <li class="">
        <a href="https://www.nike.com/gb/w/mens-premier-league-accessories-equipment-2spkszawwpwznik1/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link" target="_blank">
                <span class="large icn sponsor-footer-nike sponsor-footer-nike-n"></span>
                <span class="small icn sponsor-footer-nike-sm"></span>
            <span class="type">Official Ball<span class="visuallyHidden">Nike</span></span>
        </a>
    </li>
    <li class="">
        <a href="https://www.oracle.com/premier-league/" target="_blank">
    <img src="https://www.premierleague.com/resources/prod/v6.98.1-4068/i/svg-files/partners/oracle.svg" alt="Oracle" class="footerSponsorStrip__image">
            <span class="type">Official Cloud Partner<span class="visuallyHidden">Oracle</span></span>
        </a>
    </li>
    <li class="">
        <a href="https://sport.averydennison.com/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link" target="_blank">
                <span class="large icn sponsor-footer-avery sponsor-footer-avery-n"></span>
                <span class="small icn sponsor-footer-avery-sm"></span>
            <span class="type">Official Licensee<span class="visuallyHidden">Avery Dennison</span></span>
        </a>
    </li>
    <li class="">
        <a href="http://collectibles.panini.co.uk/home.html?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link" target="_blank">
                <span class="large icn sponsor-footer-panini sponsor-footer-panini-n"></span>
                <span class="small icn sponsor-footer-panini-sm"></span>
            <span class="type">Official Licensee<span class="visuallyHidden">Panini</span></span>
        </a>
    </li>
            </ul>
        </div>

<div class="footerContent">
    <div class="wrapper">
            <div class="footerCol ">
    <h3 class="subHeader">Premier League</h3>
                    <ul class="list--premier-league" role="menu">
                            <li>        <a href="//www.premierleague.com/" target="_self" role="menuitem">
            <span class=" link">Home</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/fixtures" target="_self" role="menuitem">
            <span class=" link">Fixtures</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/results" target="_self" role="menuitem">
            <span class=" link">Results</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/tables" target="_self" role="menuitem">
            <span class=" link">Tables</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/transfers/summer/2019" target="_self" role="menuitem">
            <span class=" link">Transfers</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/broadcast-schedules" target="_self" role="menuitem">
            <span class=" link">Broadcast</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/tickets" target="_self" role="menuitem">
            <span class=" link">Tickets</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/clubs" target="_self" role="menuitem">
            <span class=" link">Clubs</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/players" target="_self" role="menuitem">
            <span class=" link">Players</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/managers" target="_self" role="menuitem">
            <span class=" link">Managers</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/news" target="_self" role="menuitem">
            <span class=" link">News</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/social" target="_self" role="menuitem">
            <span class=" link">Social</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/youth" target="_self" role="menuitem">
            <span class=" link">Youth</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/safeguarding" target="_self" role="menuitem">
            <span class=" link">Safeguarding</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/history" target="_self" role="menuitem">
            <span class=" link">History</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/referees" target="_self" role="menuitem">
            <span class=" link">Referees</span>
        </a>
</li>
                    </ul>
            </div>
            <div class="footerCol ">
    <h3 class="subHeader">Fantasy</h3>
                    <ul class="list--fantasy" role="menu">
                            <li>        <a href="https://fantasy.premierleague.com" target="_blank" role="menuitem">
            <span class=" link">FPL Home</span>
            <span class="icn external-sm-pink"><span class="visuallyHidden">External Link</span></span>
        </a>
</li>
                            <li>        <a href="https://fantasy.premierleague.com/a/team/my" target="_blank" role="menuitem">
            <span class=" link">My Team</span>
            <span class="icn external-sm-pink"><span class="visuallyHidden">External Link</span></span>
        </a>
</li>
                            <li>        <a href="https://fantasy.premierleague.com/a/squad/transfers" target="_blank" role="menuitem">
            <span class=" link">FPL Transfers</span>
            <span class="icn external-sm-pink"><span class="visuallyHidden">External Link</span></span>
        </a>
</li>
                            <li>        <a href="https://fantasy.premierleague.com/a/leagues/main" target="_blank" role="menuitem">
            <span class=" link">Leagues</span>
            <span class="icn external-sm-pink"><span class="visuallyHidden">External Link</span></span>
        </a>
</li>
                            <li>        <a href="https://fantasy.premierleague.com/a/fixtures" target="_blank" role="menuitem">
            <span class=" link">FPL Fixtures</span>
            <span class="icn external-sm-pink"><span class="visuallyHidden">External Link</span></span>
        </a>
</li>
                            <li>        <a href="https://fantasy.premierleague.com/a/statistics/total_points" target="_blank" role="menuitem">
            <span class=" link">Statistics</span>
            <span class="icn external-sm-pink"><span class="visuallyHidden">External Link</span></span>
        </a>
</li>
                            <li>        <a href="https://fantasy.premierleague.com/the-scout" target="_blank" role="menuitem">
            <span class=" link">The Scout</span>
            <span class="icn external-sm-pink"><span class="visuallyHidden">External Link</span></span>
        </a>
</li>
                    </ul>
            </div>
            <div class="footerCol ">
    <h3 class="subHeader">Stats</h3>
                    <ul class="list--stats" role="menu">
                            <li>        <a href="//www.premierleague.com/stats" target="_self" role="menuitem">
            <span class=" link">Dashboard</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/stats/top/players/goals?se=54" target="_self" role="menuitem">
            <span class=" link">Player Stats</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/stats/top/clubs/wins?se=54" target="_self" role="menuitem">
            <span class=" link">Club Stats</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/stats/all-time" target="_self" role="menuitem">
            <span class=" link">All-time Stats</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/stats/records" target="_self" role="menuitem">
            <span class=" link">Records</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/stats/head-to-head" target="_self" role="menuitem">
            <span class=" link">Head-to-Head</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/stats/player-comparison" target="_self" role="menuitem">
            <span class=" link">Player Comparison</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/stats/awards" target="_self" role="menuitem">
            <span class=" link">Awards</span>
        </a>
</li>
                    </ul>
            </div>
            <div class="footerCol ">
    <h3 class="subHeader">Video</h3>
                    <ul class="list--video" role="menu">
                            <li>        <a href="//www.premierleague.com/video" target="_self" role="menuitem">
            <span class=" link">Latest Videos</span>
        </a>
</li>
                    </ul>
            </div>
            <div class="footerCol ">
    <h3 class="subHeader">Communities</h3>
                    <ul class="list--communities" role="menu">
                            <li>        <a href="//www.premierleague.com/communities" target="_self" role="menuitem">
            <span class=" link">Latest</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/communities/programmes" target="_self" role="menuitem">
            <span class=" link">Programmes</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/communities/PLKicksheroes" target="_self" role="menuitem">
            <span class=" link">PL Kicks Heroes</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/communities/strategy" target="_self" role="menuitem">
            <span class=" link">Strategy</span>
        </a>
</li>
                            <li>        <a href="https://plprimarystars.com/" target="_blank" role="menuitem">
            <span class=" link">PL Primary Stars</span>
            <span class="icn external-sm-pink"><span class="visuallyHidden">External Link</span></span>
        </a>
</li>
                    </ul>
            </div>
            <div class="footerCol ">
    <h3 class="subHeader">More</h3>
                    <ul class="list--more" role="menu">
                            <li>        <a href="//www.premierleague.com/stay-well" target="_self" role="menuitem">
            <span class=" link">Stay Well</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/NoRoomForRacism" target="_self" role="menuitem">
            <span class=" link">No Room for Racism</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/RainbowLaces" target="_self" role="menuitem">
            <span class=" link">Rainbow Laces</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/king-of-the-match" target="_self" role="menuitem">
            <span class=" link">King of the Match</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/transfers" target="_self" role="menuitem">
            <span class=" link">Transfers</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/VAR" target="_self" role="menuitem">
            <span class=" link">VAR</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/photos" target="_self" role="menuitem">
            <span class=" link">Photos</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/partners" target="_self" role="menuitem">
            <span class=" link">Partners</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/epl" target="_self" role="menuitem">
            <span class=" link">ePremier League</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/season-review" target="_self" role="menuitem">
            <span class=" link">Season Review</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/about" target="_self" role="menuitem">
            <span class=" link">About</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/nike-ball-hub" target="_self" role="menuitem">
            <span class=" link">Nike Ball Hub</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/contact" target="_self" role="menuitem">
            <span class=" link">Contact Us</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/poppy" target="_self" role="menuitem">
            <span class=" link">Poppy</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/asia-trophy" target="_self" role="menuitem">
            <span class=" link">Asia Trophy</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/pl-live" target="_self" role="menuitem">
            <span class=" link">PL Live</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/publications" target="_self" role="menuitem">
            <span class=" link">Publications</span>
        </a>
</li>
                            <li>        <a href="//www.premierleague.com/legal" target="_self" role="menuitem">
            <span class=" link">Legal</span>
        </a>
</li>
                    </ul>
            </div>
            <div class="footerCol ">
    <h3 class="subHeader">Social</h3>
                    <ul class="list--social" role="menu">
                            <li>        <a href="https://www.youtube.com/premierleague" target="_blank" role="menuitem">
            <span class=" link">PL on YouTube</span>
            <span class="icn external-sm-pink"><span class="visuallyHidden">External Link</span></span>
        </a>
</li>
                            <li>        <a href="https://www.facebook.com/premierleague" target="_blank" role="menuitem">
            <span class=" link">PL on Facebook</span>
            <span class="icn external-sm-pink"><span class="visuallyHidden">External Link</span></span>
        </a>
</li>
                            <li>        <a href="https://www.facebook.com/OfficialFPL/" target="_blank" role="menuitem">
            <span class=" link">FPL on Facebook</span>
            <span class="icn external-sm-pink"><span class="visuallyHidden">External Link</span></span>
        </a>
</li>
                            <li>        <a href="https://twitter.com/premierleague" target="_blank" role="menuitem">
            <span class=" link">PL on Twitter</span>
            <span class="icn external-sm-pink"><span class="visuallyHidden">External Link</span></span>
        </a>
</li>
                            <li>        <a href="https://twitter.com/OfficialFPL" target="_blank" role="menuitem">
            <span class=" link">FPL on Twitter</span>
            <span class="icn external-sm-pink"><span class="visuallyHidden">External Link</span></span>
        </a>
</li>
                            <li>        <a href="https://twitter.com/PLCommunities" target="_blank" role="menuitem">
            <span class=" link">PL Communities on Twitter</span>
            <span class="icn external-sm-pink"><span class="visuallyHidden">External Link</span></span>
        </a>
</li>
                            <li>        <a href="https://twitter.com/PLYouth" target="_blank" role="menuitem">
            <span class=" link">PL Youth on Twitter</span>
            <span class="icn external-sm-pink"><span class="visuallyHidden">External Link</span></span>
        </a>
</li>
                            <li>        <a href="https://www.instagram.com/premierleague" target="_blank" role="menuitem">
            <span class=" link">PL on Instagram</span>
            <span class="icn external-sm-pink"><span class="visuallyHidden">External Link</span></span>
        </a>
</li>
                            <li>        <a href="https://twitter.com/PLinUSA" target="_blank" role="menuitem">
            <span class=" link">PL USA on Twitter</span>
            <span class="icn external-sm-pink"><span class="visuallyHidden">External Link</span></span>
        </a>
</li>
                            <li>        <a href="https://www.instagram.com/plinusa/" target="_blank" role="menuitem">
            <span class=" link">PL USA on Instagram</span>
            <span class="icn external-sm-pink"><span class="visuallyHidden">External Link</span></span>
        </a>
</li>
                            <li>        <a href="https://twitter.com/PLforIndia" target="_blank" role="menuitem">
            <span class=" link">PL India on Twitter</span>
            <span class="icn external-sm-pink"><span class="visuallyHidden">External Link</span></span>
        </a>
</li>
                            <li>        <a href="https://www.instagram.com/plforindia/" target="_blank" role="menuitem">
            <span class=" link">PL India on Instagram</span>
            <span class="icn external-sm-pink"><span class="visuallyHidden">External Link</span></span>
        </a>
</li>
                            <li>        <a href="https://open.spotify.com/user/plplaylists" target="_blank" role="menuitem">
            <span class=" link">PL Music on Spotify</span>
            <span class="icn external-sm-pink"><span class="visuallyHidden">External Link</span></span>
        </a>
</li>
                    </ul>
            </div>
    </div>
</div>
                                        
    <div class="footerCorporate" data-script="pl_footer" data-widget="footer-corporate">
        <div class="wrapper col-12">
            <ul role="menu">
                        <li>
                                <strong class="">© PREMIER LEAGUE 2022</strong>
                        </li>
                        <li>
                                <a href="//www.premierleague.com/modern-slavery-statement" class="" role="menuitem">Modern Slavery Statement</a>
                        </li>
                        <li>
                                <a href="//www.premierleague.com/equality-diversity-and-inclusion-standard" class="" role="menuitem">Equality, Diversity and Inclusion Standard</a>
                        </li>
                        <li>
                                <a href="//www.premierleague.com/terms-and-conditions" class="" role="menuitem">Terms &amp; Conditions</a>
                        </li>
                        <li>
                                <a href="//www.premierleague.com/premier-league-policies" class="" role="menuitem">Policies</a>
                        </li>
                        <li>
                                <a href="//www.premierleague.com/cookie-policy" class="" role="menuitem">Cookie Policy</a>
                        </li>
                        <li>
                                <a href="//www.premierleague.com#" class="backToTopContainer" role="menuitem">Back To Top</a>
                        </li>
            </ul>
            <div class="official"><a href="//www.premierleague.com" class="icn pl-logo-corporate"></a></div>
        </div>
    </div>

</footer>

    <script src="/resources/prod/v6.98.1-4068/scripts/vendors.min.js"></script>
    <script src="/resources/prod/v6.98.1-4068/scripts/main.min.js"></script>
    <script src="/resources/prod/v6.98.1-4068/widgets/common.min.js"></script>
    <!-- S3 -->
    

<!-- Adform tracking code begin -->
<script type="text/javascript">
(function() {
    var adfScr = document.createElement("script");
    adfScr.src = "https://track.adform.net/serving/scripts/trackpoint/";
    adfScr.onload = function() {
        adf.container(998269, 'Master Tag');
    };
    document.head.appendChild(adfScr);
})();
</script>
<!-- Adform tracking code end -->
<div class="tcf-cmp _1Qu7MokjMuBXLOM2oKVLhZ">       
    <div class="_2Mguj83Bz7C9Eq14DJizIM">
        <div class="_90RzEeyM6H7IvIh291DTv">
            <div class="_1QkG3L-zAijqYlFASTvCtT">
                <div class="tcf-cmp__ext-content-above js-ext-content-above">
        
    </div>
                <div class="_3d-o1FWvQYnnnfdFtl2bNb">
                    <h1 class="_2wSuhCQytXcpZN9biQki4I tcf-cmp__title tcf-cmp__title--layer-one js-title">Premier League</h1>
                </div>
                <div class="tcf-cmp__ext-content-below js-ext-content-below">
        
    </div>
                <div class="_1GrZC5ulPdxquUrEilXwH_ js-layer-one-copy">
                    <p class="_34XbQeSjCaXWYFsaKDzkA-">The Premier League website uses essential cookies to make our website work. We would also like to use analytics cookies to improve your user experience. Non-essential cookies will be set only if you accept. For more detailed information about the cookies we use, see our <a href="cookie-policy" class="undefined">Cookie Policy</a>.</p>
                    <p class="_34XbQeSjCaXWYFsaKDzkA-">Essential cookies are required for the operation of our website. You may disable these using your browser settings but this may affect website functionality.</p>
                    <p class="_34XbQeSjCaXWYFsaKDzkA-">Non-essential cookies help us improve the functionality of our website by collecting information and reporting on your use of the website as well as improving your user experience. You can manage your non-essential cookies using the Cookie Settings or at any time via our <a href="cookie-policy" class="undefined">Cookie Policy</a>.</p>
                </div>
                <div class="_24Il51SkQ29P1pCkJOUO-7">
                    <button class="_2hTJ5th4dIYlveipSEMYHH BfdVlAo_cgSVjDUegen0F js-accept-all-close" style="background-color:#37003c;">Accept All Cookies</button>
                    
                    <button class="_2hTJ5th4dIYlveipSEMYHH _2O4QHvcKlG6FUBZlPSyLj1 js-cookie-settings">Cookie Settings</button>
                </div>
            </div>
            <div class="_181C_GHMYUd89bTGJ-t_-5">
                <div class="_3d-o1FWvQYnnnfdFtl2bNb">
                    <h1 class="_2wSuhCQytXcpZN9biQki4I tcf-cmp__title tcf-cmp__title--layer-two">Cookie Settings</h1>
                    <div class="hKgzAxQ54xjeMTwi5V2zj js-back">
                        <img src="data:image/svg+xml,%3csvg xmlns='http://www.w3.org/2000/svg' version='1.1' x='0' y='0' viewBox='0 0 357 357' xml:space='preserve'%3e%3cpolygon points='357 35.7 321.3 0 178.5 142.8 35.7 0 0 35.7 142.8 178.5 0 321.3 35.7 357 178.5 214.2 321.3 357 357 321.3 214.2 178.5 '/%3e%3c/svg%3e">
                    </div>
                </div>
                <div class="_3J89scWE0ceO4h8xtpBq05 js-layer-two-copy">
                    <p class="_34XbQeSjCaXWYFsaKDzkA-">Non-essential cookies help us improve the functionality of our website by collecting information and reporting on your use of the website as well as improving your user experience. You can manage and withdraw your consent of non-essential cookies below.</p>
                </div>
                <div class="_3CDiWJbAo6InPOSTIDE8VN">
                    <div class="_13y2PF0oI7cLFOdUEkvfHu">
                        <button class="_5eccd0RKmeJH0yNfaJmkL js-accept-all" style="color:#37003c;">Accept All</button>
                        <button class="_5eccd0RKmeJH0yNfaJmkL js-reject-all" style="color:#37003c;">Reject All</button>
                    </div>

                    

                    <div class="_2vWZiWYOpenC6H04L-Z4IU">
                        <div class="_30WqhK_osHJS6OXDbDVxFy js-tab JmwsxFfrnKdPixjhdqf4A" data-tab-key="processes" style="border-color:#37003c;">
                            Purposes
                        </div>
                        <div class="_30WqhK_osHJS6OXDbDVxFy js-tab" data-tab-key="vendors" style="border-color:#37003c;">
                            Vendors
                        </div>
                    </div>

                    <div class="_1AqM-R7JFkYFf4xt-i0y_w js-tab-content JmwsxFfrnKdPixjhdqf4A" data-tab-content="processes">
                        <ul class="IHzEulReWVs1ygBjjxtAJ js-process-list">
                            <!-- Processes list populated by JS -->
                        <div class="_3fsrz8NRpcs7-174mGBFTR"><li class="_1HwHO9vQCzhE42XrlVL7OK" data-item-type="purpose" data-item-id="1">
    
    <div class="_3ql0vzdiQOcFmIhzcQJS6k">
        <div class="_2HQ0FQtidNombjpBJJnJrP">
            <div class="_1uMkVepd1R8tkGak2msTxe js-expand">
                <img src="data:image/svg+xml,%3csvg height='100' width='100' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M74.363 56.363l-36 36C36.605 94.121 34.303 95 32 95s-4.605-.879-6.363-2.637a8.997 8.997 0 010-12.727L55.273 50 25.637 20.363a8.997 8.997 0 010-12.727 8.997 8.997 0 0112.727 0l36 36c3.515 3.513 3.515 9.215-.001 12.727z'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _2nfZZ_nLI6dGGUMMtp15EU">
                <span class="">Store and/or access information on a device</span>
            </div>
        </div>
        

    <div class="_2EQa8QtLFBOtmGtirYWPeS" data-state="accepted">
        <label class=" _3uFrIZboRUQNjq-k8pdQHW js-consent-label" style="color: rgb(55, 0, 60);">Accepted</label>
        <label class="_1RrWsn0KKb2A7T8zC2WLHH js-custom-checkbox" style="border-color: rgb(55, 0, 60); background-color: rgb(55, 0, 60);">
            <input class=" js-checkbox" type="checkbox" name="purpose-consent">
            <div class="_1hWTK7MHex3cebeTpAx8KY">
                <img src="data:image/svg+xml,%3csvg id='tick' viewBox='0 0 18 14' xmlns='http://www.w3.org/2000/svg'%3e%3cpath fill='white' d='M5.727 11.075L1.432 6.687 0 8.149 5.727 14 18 1.463 16.568 0z' fill-rule='evenodd'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _15UBTqf8_Ex8a9DLfE8oRT">
                <img src="data:image/svg+xml,%3csvg id='dash' viewBox='0 0 16 2' xmlns='http://www.w3.org/2000/svg'%3e%3cpath fill='white' d='M0 0h16v2H0z' fill-rule='evenodd'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ ">
            </div>
        </label>
    </div>

    </div>
    
    <div class="fNMoi2O825ZaXpK417cfI">
        <div class="_2tU3ciVyEi2bv8_uqHIYeQ">Cookies, device identifiers, or other information can be stored or accessed on your device for the purposes presented to you.</div>

        
            <div class="_24zAM6sJlywYUdBJLjPRXf js-list-item-group">
                <div class="_1PsDdX68HvALSFvJ7VE_HW">
                    <div class="_1uMkVepd1R8tkGak2msTxe js-expand">
                        <img src="data:image/svg+xml,%3csvg height='100' width='100' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M74.363 56.363l-36 36C36.605 94.121 34.303 95 32 95s-4.605-.879-6.363-2.637a8.997 8.997 0 010-12.727L55.273 50 25.637 20.363a8.997 8.997 0 010-12.727 8.997 8.997 0 0112.727 0l36 36c3.515 3.513 3.515 9.215-.001 12.727z'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _18pzpPAQ4yOJa9pZlfEOZC">
                        <span class="">Vendors</span>
                    </div>
                    <div class="_2EQa8QtLFBOtmGtirYWPeS js-consent-text" data-state="accepted">
                        <label class=" js-consent-label" style="color: rgb(55, 0, 60);">Accepted</label>
                    </div>
                </div>
                <div class="A8Mr8mc5PL75p42jJmYx0">
                    <div class="_2tU3ciVyEi2bv8_uqHIYeQ _58cFzB3Lcmp6s2odcqBse">Vendors can:<br>* Store and access information on the device such as cookies and device identifiers presented to a user.</div>
                    <ul class=" _3EHaM4EPZsod94joMjAGva">
                        
                            
                            <li class="_11R82T9EZBVuLfU7Hv9uF2">
                                <a href="https://policies.google.com/privacy" target="_blank" class="_2LU4-A27eZB2BJi17QS1OK" data-flexible="">
                                    Google Advertising Products
                                    <img src="data:image/svg+xml,%3csvg xmlns='http://www.w3.org/2000/svg' viewBox='0 0 9 9'%3e%3cg fill='%23111' fill-rule='evenodd'%3e%3cpath d='M4.093 8.96a4.054 4.054 0 0 0 4.05-4.053.577.577 0 1 0-1.153 0A2.897 2.897 0 1 1 4.093 2.01a.577.577 0 0 0 0-1.154 4.051 4.051 0 0 0 0 8.103z'/%3e%3cpath d='M8.367.04L5.805.116a.577.577 0 1 0 .032 1.154l1.113-.03-3.22 3.216a.577.577 0 1 0 .815.816l3.22-3.22-.034 1.112a.578.578 0 0 0 .56.593h.017a.577.577 0 0 0 .577-.56L8.956.633A.577.577 0 0 0 8.363.04h.004z'/%3e%3c/g%3e%3c/svg%3e" class="E2pznXhxJo3_7gb7pylff js-expand">
                                </a>
                            </li>
                        
                    </ul>
                </div>
            </div>
        

        

    </div>
</li><li class="_1HwHO9vQCzhE42XrlVL7OK" data-item-type="purpose" data-item-id="2">
    
    <div class="_3ql0vzdiQOcFmIhzcQJS6k">
        <div class="_2HQ0FQtidNombjpBJJnJrP">
            <div class="_1uMkVepd1R8tkGak2msTxe js-expand">
                <img src="data:image/svg+xml,%3csvg height='100' width='100' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M74.363 56.363l-36 36C36.605 94.121 34.303 95 32 95s-4.605-.879-6.363-2.637a8.997 8.997 0 010-12.727L55.273 50 25.637 20.363a8.997 8.997 0 010-12.727 8.997 8.997 0 0112.727 0l36 36c3.515 3.513 3.515 9.215-.001 12.727z'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _2nfZZ_nLI6dGGUMMtp15EU">
                <span class="">Select basic ads</span>
            </div>
        </div>
        

    <div class="_2EQa8QtLFBOtmGtirYWPeS" data-state="accepted">
        <label class=" _3uFrIZboRUQNjq-k8pdQHW js-consent-label" style="color: rgb(55, 0, 60);">Accepted</label>
        <label class="_1RrWsn0KKb2A7T8zC2WLHH js-custom-checkbox" style="border-color: rgb(55, 0, 60); background-color: rgb(55, 0, 60);">
            <input class=" js-checkbox" type="checkbox" name="purpose-consent">
            <div class="_1hWTK7MHex3cebeTpAx8KY">
                <img src="data:image/svg+xml,%3csvg id='tick' viewBox='0 0 18 14' xmlns='http://www.w3.org/2000/svg'%3e%3cpath fill='white' d='M5.727 11.075L1.432 6.687 0 8.149 5.727 14 18 1.463 16.568 0z' fill-rule='evenodd'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _15UBTqf8_Ex8a9DLfE8oRT">
                <img src="data:image/svg+xml,%3csvg id='dash' viewBox='0 0 16 2' xmlns='http://www.w3.org/2000/svg'%3e%3cpath fill='white' d='M0 0h16v2H0z' fill-rule='evenodd'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ ">
            </div>
        </label>
    </div>

    </div>
    
    <div class="fNMoi2O825ZaXpK417cfI">
        <div class="_2tU3ciVyEi2bv8_uqHIYeQ">Ads can be shown to you based on the content you’re viewing, the app you’re using, your approximate location, or your device type.</div>

        

        
            <div class="_24zAM6sJlywYUdBJLjPRXf js-list-item-group js-leg-int-group" data-leg-int-opted-out="false">
                <div class="_1PsDdX68HvALSFvJ7VE_HW">
                    <div class="_1uMkVepd1R8tkGak2msTxe js-expand">
                        <img src="data:image/svg+xml,%3csvg height='100' width='100' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M74.363 56.363l-36 36C36.605 94.121 34.303 95 32 95s-4.605-.879-6.363-2.637a8.997 8.997 0 010-12.727L55.273 50 25.637 20.363a8.997 8.997 0 010-12.727 8.997 8.997 0 0112.727 0l36 36c3.515 3.513 3.515 9.215-.001 12.727z'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _18pzpPAQ4yOJa9pZlfEOZC">
                        <span class="">Legitimate Interests</span>
                    </div>
                    <div class="_3UZVhYmmpYlXnegrh5fmkr">
                        <div class="_2KSGk-SAPK28jHbLWjrvV7">
                            <img src="data:image/svg+xml,%3csvg width='20' height='17' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M0 17h20L10 0 0 17zm10.91-2.684H9.09v-1.79h1.82v1.79zm0-3.58H9.09V7.159h1.82v3.579z' fill='%23ffb100' fill-rule='nonzero'/%3e%3c/svg%3e">
                        </div>
                        <div class="_2KknTv5cQqxr-fP0xT9o3K">
                            Opting out of legitimate interests may cause the site to stop functioning properly.
                        </div>
                    </div>
                </div>
                <div class="A8Mr8mc5PL75p42jJmYx0">
                    <ul class=" _3EHaM4EPZsod94joMjAGva">
                        
                            
                            <li class="_11R82T9EZBVuLfU7Hv9uF2">
                                <a href="https://policies.google.com/privacy" target="_blank" class="_2LU4-A27eZB2BJi17QS1OK" data-flexible="">
                                    Google Advertising Products 
                                    <img src="data:image/svg+xml,%3csvg xmlns='http://www.w3.org/2000/svg' viewBox='0 0 9 9'%3e%3cg fill='%23111' fill-rule='evenodd'%3e%3cpath d='M4.093 8.96a4.054 4.054 0 0 0 4.05-4.053.577.577 0 1 0-1.153 0A2.897 2.897 0 1 1 4.093 2.01a.577.577 0 0 0 0-1.154 4.051 4.051 0 0 0 0 8.103z'/%3e%3cpath d='M8.367.04L5.805.116a.577.577 0 1 0 .032 1.154l1.113-.03-3.22 3.216a.577.577 0 1 0 .815.816l3.22-3.22-.034 1.112a.578.578 0 0 0 .56.593h.017a.577.577 0 0 0 .577-.56L8.956.633A.577.577 0 0 0 8.363.04h.004z'/%3e%3c/g%3e%3c/svg%3e" class="E2pznXhxJo3_7gb7pylff js-expand">
                                </a>
                            </li>
                        
                    </ul>
                    <div class="_3JvTBUyAO3xVBcnIxRLwFU">
                        <div class="_1Hu0pBibjnwQQwiAUkTYXe js-legit-int-options-cta" data-leg-int-type="purpose-leg-int">Opt out</div>
                        <div class="_3Sc7o7waynqWs_Ig71k2zC js-legit-int-options-message">Please note that opting out of legitimate interests may cause the site to stop functioning properly.</div>
                    </div>
                </div>
            </div>
        

    </div>
</li><li class="_1HwHO9vQCzhE42XrlVL7OK" data-item-type="purpose" data-item-id="3">
    
    <div class="_3ql0vzdiQOcFmIhzcQJS6k">
        <div class="_2HQ0FQtidNombjpBJJnJrP">
            <div class="_1uMkVepd1R8tkGak2msTxe js-expand">
                <img src="data:image/svg+xml,%3csvg height='100' width='100' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M74.363 56.363l-36 36C36.605 94.121 34.303 95 32 95s-4.605-.879-6.363-2.637a8.997 8.997 0 010-12.727L55.273 50 25.637 20.363a8.997 8.997 0 010-12.727 8.997 8.997 0 0112.727 0l36 36c3.515 3.513 3.515 9.215-.001 12.727z'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _2nfZZ_nLI6dGGUMMtp15EU">
                <span class="">Create a personalised ads profile</span>
            </div>
        </div>
        

    <div class="_2EQa8QtLFBOtmGtirYWPeS" data-state="accepted">
        <label class=" _3uFrIZboRUQNjq-k8pdQHW js-consent-label" style="color: rgb(55, 0, 60);">Accepted</label>
        <label class="_1RrWsn0KKb2A7T8zC2WLHH js-custom-checkbox" style="border-color: rgb(55, 0, 60); background-color: rgb(55, 0, 60);">
            <input class=" js-checkbox" type="checkbox" name="purpose-consent">
            <div class="_1hWTK7MHex3cebeTpAx8KY">
                <img src="data:image/svg+xml,%3csvg id='tick' viewBox='0 0 18 14' xmlns='http://www.w3.org/2000/svg'%3e%3cpath fill='white' d='M5.727 11.075L1.432 6.687 0 8.149 5.727 14 18 1.463 16.568 0z' fill-rule='evenodd'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _15UBTqf8_Ex8a9DLfE8oRT">
                <img src="data:image/svg+xml,%3csvg id='dash' viewBox='0 0 16 2' xmlns='http://www.w3.org/2000/svg'%3e%3cpath fill='white' d='M0 0h16v2H0z' fill-rule='evenodd'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ ">
            </div>
        </label>
    </div>

    </div>
    
    <div class="fNMoi2O825ZaXpK417cfI">
        <div class="_2tU3ciVyEi2bv8_uqHIYeQ">A profile can be built about you and your interests to show you personalised ads that are relevant to you.</div>

        
            <div class="_24zAM6sJlywYUdBJLjPRXf js-list-item-group">
                <div class="_1PsDdX68HvALSFvJ7VE_HW">
                    <div class="_1uMkVepd1R8tkGak2msTxe js-expand">
                        <img src="data:image/svg+xml,%3csvg height='100' width='100' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M74.363 56.363l-36 36C36.605 94.121 34.303 95 32 95s-4.605-.879-6.363-2.637a8.997 8.997 0 010-12.727L55.273 50 25.637 20.363a8.997 8.997 0 010-12.727 8.997 8.997 0 0112.727 0l36 36c3.515 3.513 3.515 9.215-.001 12.727z'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _18pzpPAQ4yOJa9pZlfEOZC">
                        <span class="">Vendors</span>
                    </div>
                    <div class="_2EQa8QtLFBOtmGtirYWPeS js-consent-text" data-state="accepted">
                        <label class=" js-consent-label" style="color: rgb(55, 0, 60);">Accepted</label>
                    </div>
                </div>
                <div class="A8Mr8mc5PL75p42jJmYx0">
                    <div class="_2tU3ciVyEi2bv8_uqHIYeQ _58cFzB3Lcmp6s2odcqBse">To create a personalised ads profile vendors can:<br>* Collect information about a user, including a user's activity, interests, demographic information, or location, to create or edit a user profile for use in personalised advertising.<br>* Combine this information with other information previously collected, including from across websites and apps, to create or edit a user profile for use in personalised advertising.</div>
                    <ul class=" _3EHaM4EPZsod94joMjAGva">
                        
                            
                            <li class="_11R82T9EZBVuLfU7Hv9uF2">
                                <a href="https://policies.google.com/privacy" target="_blank" class="_2LU4-A27eZB2BJi17QS1OK" data-flexible="">
                                    Google Advertising Products
                                    <img src="data:image/svg+xml,%3csvg xmlns='http://www.w3.org/2000/svg' viewBox='0 0 9 9'%3e%3cg fill='%23111' fill-rule='evenodd'%3e%3cpath d='M4.093 8.96a4.054 4.054 0 0 0 4.05-4.053.577.577 0 1 0-1.153 0A2.897 2.897 0 1 1 4.093 2.01a.577.577 0 0 0 0-1.154 4.051 4.051 0 0 0 0 8.103z'/%3e%3cpath d='M8.367.04L5.805.116a.577.577 0 1 0 .032 1.154l1.113-.03-3.22 3.216a.577.577 0 1 0 .815.816l3.22-3.22-.034 1.112a.578.578 0 0 0 .56.593h.017a.577.577 0 0 0 .577-.56L8.956.633A.577.577 0 0 0 8.363.04h.004z'/%3e%3c/g%3e%3c/svg%3e" class="E2pznXhxJo3_7gb7pylff js-expand">
                                </a>
                            </li>
                        
                    </ul>
                </div>
            </div>
        

        

    </div>
</li><li class="_1HwHO9vQCzhE42XrlVL7OK" data-item-type="purpose" data-item-id="4">
    
    <div class="_3ql0vzdiQOcFmIhzcQJS6k">
        <div class="_2HQ0FQtidNombjpBJJnJrP">
            <div class="_1uMkVepd1R8tkGak2msTxe js-expand">
                <img src="data:image/svg+xml,%3csvg height='100' width='100' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M74.363 56.363l-36 36C36.605 94.121 34.303 95 32 95s-4.605-.879-6.363-2.637a8.997 8.997 0 010-12.727L55.273 50 25.637 20.363a8.997 8.997 0 010-12.727 8.997 8.997 0 0112.727 0l36 36c3.515 3.513 3.515 9.215-.001 12.727z'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _2nfZZ_nLI6dGGUMMtp15EU">
                <span class="">Select personalised ads</span>
            </div>
        </div>
        

    <div class="_2EQa8QtLFBOtmGtirYWPeS" data-state="accepted">
        <label class=" _3uFrIZboRUQNjq-k8pdQHW js-consent-label" style="color: rgb(55, 0, 60);">Accepted</label>
        <label class="_1RrWsn0KKb2A7T8zC2WLHH js-custom-checkbox" style="border-color: rgb(55, 0, 60); background-color: rgb(55, 0, 60);">
            <input class=" js-checkbox" type="checkbox" name="purpose-consent">
            <div class="_1hWTK7MHex3cebeTpAx8KY">
                <img src="data:image/svg+xml,%3csvg id='tick' viewBox='0 0 18 14' xmlns='http://www.w3.org/2000/svg'%3e%3cpath fill='white' d='M5.727 11.075L1.432 6.687 0 8.149 5.727 14 18 1.463 16.568 0z' fill-rule='evenodd'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _15UBTqf8_Ex8a9DLfE8oRT">
                <img src="data:image/svg+xml,%3csvg id='dash' viewBox='0 0 16 2' xmlns='http://www.w3.org/2000/svg'%3e%3cpath fill='white' d='M0 0h16v2H0z' fill-rule='evenodd'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ ">
            </div>
        </label>
    </div>

    </div>
    
    <div class="fNMoi2O825ZaXpK417cfI">
        <div class="_2tU3ciVyEi2bv8_uqHIYeQ">Personalised ads can be shown to you based on a profile about you.</div>

        
            <div class="_24zAM6sJlywYUdBJLjPRXf js-list-item-group">
                <div class="_1PsDdX68HvALSFvJ7VE_HW">
                    <div class="_1uMkVepd1R8tkGak2msTxe js-expand">
                        <img src="data:image/svg+xml,%3csvg height='100' width='100' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M74.363 56.363l-36 36C36.605 94.121 34.303 95 32 95s-4.605-.879-6.363-2.637a8.997 8.997 0 010-12.727L55.273 50 25.637 20.363a8.997 8.997 0 010-12.727 8.997 8.997 0 0112.727 0l36 36c3.515 3.513 3.515 9.215-.001 12.727z'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _18pzpPAQ4yOJa9pZlfEOZC">
                        <span class="">Vendors</span>
                    </div>
                    <div class="_2EQa8QtLFBOtmGtirYWPeS js-consent-text" data-state="accepted">
                        <label class=" js-consent-label" style="color: rgb(55, 0, 60);">Accepted</label>
                    </div>
                </div>
                <div class="A8Mr8mc5PL75p42jJmYx0">
                    <div class="_2tU3ciVyEi2bv8_uqHIYeQ _58cFzB3Lcmp6s2odcqBse">To select personalised ads vendors can:<br>* Select personalised ads based on a user profile or other historical user data, including a user’s prior activity, interests, visits to sites or apps, location, or demographic information.</div>
                    <ul class=" _3EHaM4EPZsod94joMjAGva">
                        
                            
                            <li class="_11R82T9EZBVuLfU7Hv9uF2">
                                <a href="https://policies.google.com/privacy" target="_blank" class="_2LU4-A27eZB2BJi17QS1OK" data-flexible="">
                                    Google Advertising Products
                                    <img src="data:image/svg+xml,%3csvg xmlns='http://www.w3.org/2000/svg' viewBox='0 0 9 9'%3e%3cg fill='%23111' fill-rule='evenodd'%3e%3cpath d='M4.093 8.96a4.054 4.054 0 0 0 4.05-4.053.577.577 0 1 0-1.153 0A2.897 2.897 0 1 1 4.093 2.01a.577.577 0 0 0 0-1.154 4.051 4.051 0 0 0 0 8.103z'/%3e%3cpath d='M8.367.04L5.805.116a.577.577 0 1 0 .032 1.154l1.113-.03-3.22 3.216a.577.577 0 1 0 .815.816l3.22-3.22-.034 1.112a.578.578 0 0 0 .56.593h.017a.577.577 0 0 0 .577-.56L8.956.633A.577.577 0 0 0 8.363.04h.004z'/%3e%3c/g%3e%3c/svg%3e" class="E2pznXhxJo3_7gb7pylff js-expand">
                                </a>
                            </li>
                        
                    </ul>
                </div>
            </div>
        

        

    </div>
</li><li class="_1HwHO9vQCzhE42XrlVL7OK" data-item-type="purpose" data-item-id="5">
    
    <div class="_3ql0vzdiQOcFmIhzcQJS6k">
        <div class="_2HQ0FQtidNombjpBJJnJrP">
            <div class="_1uMkVepd1R8tkGak2msTxe js-expand">
                <img src="data:image/svg+xml,%3csvg height='100' width='100' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M74.363 56.363l-36 36C36.605 94.121 34.303 95 32 95s-4.605-.879-6.363-2.637a8.997 8.997 0 010-12.727L55.273 50 25.637 20.363a8.997 8.997 0 010-12.727 8.997 8.997 0 0112.727 0l36 36c3.515 3.513 3.515 9.215-.001 12.727z'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _2nfZZ_nLI6dGGUMMtp15EU">
                <span class="">Create a personalised content profile</span>
            </div>
        </div>
        

    <div class="_2EQa8QtLFBOtmGtirYWPeS" data-state="accepted">
        <label class=" _3uFrIZboRUQNjq-k8pdQHW js-consent-label" style="color: rgb(55, 0, 60);">Accepted</label>
        <label class="_1RrWsn0KKb2A7T8zC2WLHH js-custom-checkbox" style="border-color: rgb(55, 0, 60); background-color: rgb(55, 0, 60);">
            <input class=" js-checkbox" type="checkbox" name="purpose-consent">
            <div class="_1hWTK7MHex3cebeTpAx8KY">
                <img src="data:image/svg+xml,%3csvg id='tick' viewBox='0 0 18 14' xmlns='http://www.w3.org/2000/svg'%3e%3cpath fill='white' d='M5.727 11.075L1.432 6.687 0 8.149 5.727 14 18 1.463 16.568 0z' fill-rule='evenodd'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _15UBTqf8_Ex8a9DLfE8oRT">
                <img src="data:image/svg+xml,%3csvg id='dash' viewBox='0 0 16 2' xmlns='http://www.w3.org/2000/svg'%3e%3cpath fill='white' d='M0 0h16v2H0z' fill-rule='evenodd'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ ">
            </div>
        </label>
    </div>

    </div>
    
    <div class="fNMoi2O825ZaXpK417cfI">
        <div class="_2tU3ciVyEi2bv8_uqHIYeQ">A profile can be built about you and your interests to show you personalised content that is relevant to you.</div>

        

        
            <div class="_24zAM6sJlywYUdBJLjPRXf js-list-item-group js-leg-int-group" data-leg-int-opted-out="false">
                <div class="_1PsDdX68HvALSFvJ7VE_HW">
                    <div class="_1uMkVepd1R8tkGak2msTxe js-expand">
                        <img src="data:image/svg+xml,%3csvg height='100' width='100' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M74.363 56.363l-36 36C36.605 94.121 34.303 95 32 95s-4.605-.879-6.363-2.637a8.997 8.997 0 010-12.727L55.273 50 25.637 20.363a8.997 8.997 0 010-12.727 8.997 8.997 0 0112.727 0l36 36c3.515 3.513 3.515 9.215-.001 12.727z'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _18pzpPAQ4yOJa9pZlfEOZC">
                        <span class="">Legitimate Interests</span>
                    </div>
                    <div class="_3UZVhYmmpYlXnegrh5fmkr">
                        <div class="_2KSGk-SAPK28jHbLWjrvV7">
                            <img src="data:image/svg+xml,%3csvg width='20' height='17' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M0 17h20L10 0 0 17zm10.91-2.684H9.09v-1.79h1.82v1.79zm0-3.58H9.09V7.159h1.82v3.579z' fill='%23ffb100' fill-rule='nonzero'/%3e%3c/svg%3e">
                        </div>
                        <div class="_2KknTv5cQqxr-fP0xT9o3K">
                            Opting out of legitimate interests may cause the site to stop functioning properly.
                        </div>
                    </div>
                </div>
                <div class="A8Mr8mc5PL75p42jJmYx0">
                    <ul class=" _3EHaM4EPZsod94joMjAGva">
                        
                            
                            <li class="_11R82T9EZBVuLfU7Hv9uF2">
                                <a href="https://policies.google.com/privacy" target="_blank" class="_2LU4-A27eZB2BJi17QS1OK" data-flexible="">
                                    Google Advertising Products 
                                    <img src="data:image/svg+xml,%3csvg xmlns='http://www.w3.org/2000/svg' viewBox='0 0 9 9'%3e%3cg fill='%23111' fill-rule='evenodd'%3e%3cpath d='M4.093 8.96a4.054 4.054 0 0 0 4.05-4.053.577.577 0 1 0-1.153 0A2.897 2.897 0 1 1 4.093 2.01a.577.577 0 0 0 0-1.154 4.051 4.051 0 0 0 0 8.103z'/%3e%3cpath d='M8.367.04L5.805.116a.577.577 0 1 0 .032 1.154l1.113-.03-3.22 3.216a.577.577 0 1 0 .815.816l3.22-3.22-.034 1.112a.578.578 0 0 0 .56.593h.017a.577.577 0 0 0 .577-.56L8.956.633A.577.577 0 0 0 8.363.04h.004z'/%3e%3c/g%3e%3c/svg%3e" class="E2pznXhxJo3_7gb7pylff js-expand">
                                </a>
                            </li>
                        
                    </ul>
                    <div class="_3JvTBUyAO3xVBcnIxRLwFU">
                        <div class="_1Hu0pBibjnwQQwiAUkTYXe js-legit-int-options-cta" data-leg-int-type="purpose-leg-int">Opt out</div>
                        <div class="_3Sc7o7waynqWs_Ig71k2zC js-legit-int-options-message">Please note that opting out of legitimate interests may cause the site to stop functioning properly.</div>
                    </div>
                </div>
            </div>
        

    </div>
</li><li class="_1HwHO9vQCzhE42XrlVL7OK" data-item-type="purpose" data-item-id="6">
    
    <div class="_3ql0vzdiQOcFmIhzcQJS6k">
        <div class="_2HQ0FQtidNombjpBJJnJrP">
            <div class="_1uMkVepd1R8tkGak2msTxe js-expand">
                <img src="data:image/svg+xml,%3csvg height='100' width='100' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M74.363 56.363l-36 36C36.605 94.121 34.303 95 32 95s-4.605-.879-6.363-2.637a8.997 8.997 0 010-12.727L55.273 50 25.637 20.363a8.997 8.997 0 010-12.727 8.997 8.997 0 0112.727 0l36 36c3.515 3.513 3.515 9.215-.001 12.727z'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _2nfZZ_nLI6dGGUMMtp15EU">
                <span class="">Select personalised content</span>
            </div>
        </div>
        

    <div class="_2EQa8QtLFBOtmGtirYWPeS" data-state="accepted">
        <label class=" _3uFrIZboRUQNjq-k8pdQHW js-consent-label" style="color: rgb(55, 0, 60);">Accepted</label>
        <label class="_1RrWsn0KKb2A7T8zC2WLHH js-custom-checkbox" style="border-color: rgb(55, 0, 60); background-color: rgb(55, 0, 60);">
            <input class=" js-checkbox" type="checkbox" name="purpose-consent">
            <div class="_1hWTK7MHex3cebeTpAx8KY">
                <img src="data:image/svg+xml,%3csvg id='tick' viewBox='0 0 18 14' xmlns='http://www.w3.org/2000/svg'%3e%3cpath fill='white' d='M5.727 11.075L1.432 6.687 0 8.149 5.727 14 18 1.463 16.568 0z' fill-rule='evenodd'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _15UBTqf8_Ex8a9DLfE8oRT">
                <img src="data:image/svg+xml,%3csvg id='dash' viewBox='0 0 16 2' xmlns='http://www.w3.org/2000/svg'%3e%3cpath fill='white' d='M0 0h16v2H0z' fill-rule='evenodd'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ ">
            </div>
        </label>
    </div>

    </div>
    
    <div class="fNMoi2O825ZaXpK417cfI">
        <div class="_2tU3ciVyEi2bv8_uqHIYeQ">Personalised content can be shown to you based on a profile about you.</div>

        

        
            <div class="_24zAM6sJlywYUdBJLjPRXf js-list-item-group js-leg-int-group" data-leg-int-opted-out="false">
                <div class="_1PsDdX68HvALSFvJ7VE_HW">
                    <div class="_1uMkVepd1R8tkGak2msTxe js-expand">
                        <img src="data:image/svg+xml,%3csvg height='100' width='100' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M74.363 56.363l-36 36C36.605 94.121 34.303 95 32 95s-4.605-.879-6.363-2.637a8.997 8.997 0 010-12.727L55.273 50 25.637 20.363a8.997 8.997 0 010-12.727 8.997 8.997 0 0112.727 0l36 36c3.515 3.513 3.515 9.215-.001 12.727z'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _18pzpPAQ4yOJa9pZlfEOZC">
                        <span class="">Legitimate Interests</span>
                    </div>
                    <div class="_3UZVhYmmpYlXnegrh5fmkr">
                        <div class="_2KSGk-SAPK28jHbLWjrvV7">
                            <img src="data:image/svg+xml,%3csvg width='20' height='17' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M0 17h20L10 0 0 17zm10.91-2.684H9.09v-1.79h1.82v1.79zm0-3.58H9.09V7.159h1.82v3.579z' fill='%23ffb100' fill-rule='nonzero'/%3e%3c/svg%3e">
                        </div>
                        <div class="_2KknTv5cQqxr-fP0xT9o3K">
                            Opting out of legitimate interests may cause the site to stop functioning properly.
                        </div>
                    </div>
                </div>
                <div class="A8Mr8mc5PL75p42jJmYx0">
                    <ul class=" _3EHaM4EPZsod94joMjAGva">
                        
                            
                            <li class="_11R82T9EZBVuLfU7Hv9uF2">
                                <a href="https://policies.google.com/privacy" target="_blank" class="_2LU4-A27eZB2BJi17QS1OK" data-flexible="">
                                    Google Advertising Products 
                                    <img src="data:image/svg+xml,%3csvg xmlns='http://www.w3.org/2000/svg' viewBox='0 0 9 9'%3e%3cg fill='%23111' fill-rule='evenodd'%3e%3cpath d='M4.093 8.96a4.054 4.054 0 0 0 4.05-4.053.577.577 0 1 0-1.153 0A2.897 2.897 0 1 1 4.093 2.01a.577.577 0 0 0 0-1.154 4.051 4.051 0 0 0 0 8.103z'/%3e%3cpath d='M8.367.04L5.805.116a.577.577 0 1 0 .032 1.154l1.113-.03-3.22 3.216a.577.577 0 1 0 .815.816l3.22-3.22-.034 1.112a.578.578 0 0 0 .56.593h.017a.577.577 0 0 0 .577-.56L8.956.633A.577.577 0 0 0 8.363.04h.004z'/%3e%3c/g%3e%3c/svg%3e" class="E2pznXhxJo3_7gb7pylff js-expand">
                                </a>
                            </li>
                        
                    </ul>
                    <div class="_3JvTBUyAO3xVBcnIxRLwFU">
                        <div class="_1Hu0pBibjnwQQwiAUkTYXe js-legit-int-options-cta" data-leg-int-type="purpose-leg-int">Opt out</div>
                        <div class="_3Sc7o7waynqWs_Ig71k2zC js-legit-int-options-message">Please note that opting out of legitimate interests may cause the site to stop functioning properly.</div>
                    </div>
                </div>
            </div>
        

    </div>
</li><li class="_1HwHO9vQCzhE42XrlVL7OK" data-item-type="purpose" data-item-id="7">
    
    <div class="_3ql0vzdiQOcFmIhzcQJS6k">
        <div class="_2HQ0FQtidNombjpBJJnJrP">
            <div class="_1uMkVepd1R8tkGak2msTxe js-expand">
                <img src="data:image/svg+xml,%3csvg height='100' width='100' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M74.363 56.363l-36 36C36.605 94.121 34.303 95 32 95s-4.605-.879-6.363-2.637a8.997 8.997 0 010-12.727L55.273 50 25.637 20.363a8.997 8.997 0 010-12.727 8.997 8.997 0 0112.727 0l36 36c3.515 3.513 3.515 9.215-.001 12.727z'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _2nfZZ_nLI6dGGUMMtp15EU">
                <span class="">Measure ad performance</span>
            </div>
        </div>
        

    <div class="_2EQa8QtLFBOtmGtirYWPeS" data-state="accepted">
        <label class=" _3uFrIZboRUQNjq-k8pdQHW js-consent-label" style="color: rgb(55, 0, 60);">Accepted</label>
        <label class="_1RrWsn0KKb2A7T8zC2WLHH js-custom-checkbox" style="border-color: rgb(55, 0, 60); background-color: rgb(55, 0, 60);">
            <input class=" js-checkbox" type="checkbox" name="purpose-consent">
            <div class="_1hWTK7MHex3cebeTpAx8KY">
                <img src="data:image/svg+xml,%3csvg id='tick' viewBox='0 0 18 14' xmlns='http://www.w3.org/2000/svg'%3e%3cpath fill='white' d='M5.727 11.075L1.432 6.687 0 8.149 5.727 14 18 1.463 16.568 0z' fill-rule='evenodd'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _15UBTqf8_Ex8a9DLfE8oRT">
                <img src="data:image/svg+xml,%3csvg id='dash' viewBox='0 0 16 2' xmlns='http://www.w3.org/2000/svg'%3e%3cpath fill='white' d='M0 0h16v2H0z' fill-rule='evenodd'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ ">
            </div>
        </label>
    </div>

    </div>
    
    <div class="fNMoi2O825ZaXpK417cfI">
        <div class="_2tU3ciVyEi2bv8_uqHIYeQ">The performance and effectiveness of ads that you see or interact with can be measured.</div>

        

        
            <div class="_24zAM6sJlywYUdBJLjPRXf js-list-item-group js-leg-int-group" data-leg-int-opted-out="false">
                <div class="_1PsDdX68HvALSFvJ7VE_HW">
                    <div class="_1uMkVepd1R8tkGak2msTxe js-expand">
                        <img src="data:image/svg+xml,%3csvg height='100' width='100' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M74.363 56.363l-36 36C36.605 94.121 34.303 95 32 95s-4.605-.879-6.363-2.637a8.997 8.997 0 010-12.727L55.273 50 25.637 20.363a8.997 8.997 0 010-12.727 8.997 8.997 0 0112.727 0l36 36c3.515 3.513 3.515 9.215-.001 12.727z'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _18pzpPAQ4yOJa9pZlfEOZC">
                        <span class="">Legitimate Interests</span>
                    </div>
                    <div class="_3UZVhYmmpYlXnegrh5fmkr">
                        <div class="_2KSGk-SAPK28jHbLWjrvV7">
                            <img src="data:image/svg+xml,%3csvg width='20' height='17' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M0 17h20L10 0 0 17zm10.91-2.684H9.09v-1.79h1.82v1.79zm0-3.58H9.09V7.159h1.82v3.579z' fill='%23ffb100' fill-rule='nonzero'/%3e%3c/svg%3e">
                        </div>
                        <div class="_2KknTv5cQqxr-fP0xT9o3K">
                            Opting out of legitimate interests may cause the site to stop functioning properly.
                        </div>
                    </div>
                </div>
                <div class="A8Mr8mc5PL75p42jJmYx0">
                    <ul class=" _3EHaM4EPZsod94joMjAGva">
                        
                            
                            <li class="_11R82T9EZBVuLfU7Hv9uF2">
                                <a href="https://policies.google.com/privacy" target="_blank" class="_2LU4-A27eZB2BJi17QS1OK" data-flexible="">
                                    Google Advertising Products 
                                    <img src="data:image/svg+xml,%3csvg xmlns='http://www.w3.org/2000/svg' viewBox='0 0 9 9'%3e%3cg fill='%23111' fill-rule='evenodd'%3e%3cpath d='M4.093 8.96a4.054 4.054 0 0 0 4.05-4.053.577.577 0 1 0-1.153 0A2.897 2.897 0 1 1 4.093 2.01a.577.577 0 0 0 0-1.154 4.051 4.051 0 0 0 0 8.103z'/%3e%3cpath d='M8.367.04L5.805.116a.577.577 0 1 0 .032 1.154l1.113-.03-3.22 3.216a.577.577 0 1 0 .815.816l3.22-3.22-.034 1.112a.578.578 0 0 0 .56.593h.017a.577.577 0 0 0 .577-.56L8.956.633A.577.577 0 0 0 8.363.04h.004z'/%3e%3c/g%3e%3c/svg%3e" class="E2pznXhxJo3_7gb7pylff js-expand">
                                </a>
                            </li>
                        
                    </ul>
                    <div class="_3JvTBUyAO3xVBcnIxRLwFU">
                        <div class="_1Hu0pBibjnwQQwiAUkTYXe js-legit-int-options-cta" data-leg-int-type="purpose-leg-int">Opt out</div>
                        <div class="_3Sc7o7waynqWs_Ig71k2zC js-legit-int-options-message">Please note that opting out of legitimate interests may cause the site to stop functioning properly.</div>
                    </div>
                </div>
            </div>
        

    </div>
</li><li class="_1HwHO9vQCzhE42XrlVL7OK" data-item-type="purpose" data-item-id="9">
    
    <div class="_3ql0vzdiQOcFmIhzcQJS6k">
        <div class="_2HQ0FQtidNombjpBJJnJrP">
            <div class="_1uMkVepd1R8tkGak2msTxe js-expand">
                <img src="data:image/svg+xml,%3csvg height='100' width='100' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M74.363 56.363l-36 36C36.605 94.121 34.303 95 32 95s-4.605-.879-6.363-2.637a8.997 8.997 0 010-12.727L55.273 50 25.637 20.363a8.997 8.997 0 010-12.727 8.997 8.997 0 0112.727 0l36 36c3.515 3.513 3.515 9.215-.001 12.727z'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _2nfZZ_nLI6dGGUMMtp15EU">
                <span class="">Apply market research to generate audience insights</span>
            </div>
        </div>
        

    <div class="_2EQa8QtLFBOtmGtirYWPeS" data-state="accepted">
        <label class=" _3uFrIZboRUQNjq-k8pdQHW js-consent-label" style="color: rgb(55, 0, 60);">Accepted</label>
        <label class="_1RrWsn0KKb2A7T8zC2WLHH js-custom-checkbox" style="border-color: rgb(55, 0, 60); background-color: rgb(55, 0, 60);">
            <input class=" js-checkbox" type="checkbox" name="purpose-consent">
            <div class="_1hWTK7MHex3cebeTpAx8KY">
                <img src="data:image/svg+xml,%3csvg id='tick' viewBox='0 0 18 14' xmlns='http://www.w3.org/2000/svg'%3e%3cpath fill='white' d='M5.727 11.075L1.432 6.687 0 8.149 5.727 14 18 1.463 16.568 0z' fill-rule='evenodd'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _15UBTqf8_Ex8a9DLfE8oRT">
                <img src="data:image/svg+xml,%3csvg id='dash' viewBox='0 0 16 2' xmlns='http://www.w3.org/2000/svg'%3e%3cpath fill='white' d='M0 0h16v2H0z' fill-rule='evenodd'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ ">
            </div>
        </label>
    </div>

    </div>
    
    <div class="fNMoi2O825ZaXpK417cfI">
        <div class="_2tU3ciVyEi2bv8_uqHIYeQ">Market research can be used to learn more about the audiences who visit sites/apps and view ads.</div>

        

        
            <div class="_24zAM6sJlywYUdBJLjPRXf js-list-item-group js-leg-int-group" data-leg-int-opted-out="false">
                <div class="_1PsDdX68HvALSFvJ7VE_HW">
                    <div class="_1uMkVepd1R8tkGak2msTxe js-expand">
                        <img src="data:image/svg+xml,%3csvg height='100' width='100' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M74.363 56.363l-36 36C36.605 94.121 34.303 95 32 95s-4.605-.879-6.363-2.637a8.997 8.997 0 010-12.727L55.273 50 25.637 20.363a8.997 8.997 0 010-12.727 8.997 8.997 0 0112.727 0l36 36c3.515 3.513 3.515 9.215-.001 12.727z'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _18pzpPAQ4yOJa9pZlfEOZC">
                        <span class="">Legitimate Interests</span>
                    </div>
                    <div class="_3UZVhYmmpYlXnegrh5fmkr">
                        <div class="_2KSGk-SAPK28jHbLWjrvV7">
                            <img src="data:image/svg+xml,%3csvg width='20' height='17' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M0 17h20L10 0 0 17zm10.91-2.684H9.09v-1.79h1.82v1.79zm0-3.58H9.09V7.159h1.82v3.579z' fill='%23ffb100' fill-rule='nonzero'/%3e%3c/svg%3e">
                        </div>
                        <div class="_2KknTv5cQqxr-fP0xT9o3K">
                            Opting out of legitimate interests may cause the site to stop functioning properly.
                        </div>
                    </div>
                </div>
                <div class="A8Mr8mc5PL75p42jJmYx0">
                    <ul class=" _3EHaM4EPZsod94joMjAGva">
                        
                            
                            <li class="_11R82T9EZBVuLfU7Hv9uF2">
                                <a href="https://policies.google.com/privacy" target="_blank" class="_2LU4-A27eZB2BJi17QS1OK" data-flexible="">
                                    Google Advertising Products 
                                    <img src="data:image/svg+xml,%3csvg xmlns='http://www.w3.org/2000/svg' viewBox='0 0 9 9'%3e%3cg fill='%23111' fill-rule='evenodd'%3e%3cpath d='M4.093 8.96a4.054 4.054 0 0 0 4.05-4.053.577.577 0 1 0-1.153 0A2.897 2.897 0 1 1 4.093 2.01a.577.577 0 0 0 0-1.154 4.051 4.051 0 0 0 0 8.103z'/%3e%3cpath d='M8.367.04L5.805.116a.577.577 0 1 0 .032 1.154l1.113-.03-3.22 3.216a.577.577 0 1 0 .815.816l3.22-3.22-.034 1.112a.578.578 0 0 0 .56.593h.017a.577.577 0 0 0 .577-.56L8.956.633A.577.577 0 0 0 8.363.04h.004z'/%3e%3c/g%3e%3c/svg%3e" class="E2pznXhxJo3_7gb7pylff js-expand">
                                </a>
                            </li>
                        
                    </ul>
                    <div class="_3JvTBUyAO3xVBcnIxRLwFU">
                        <div class="_1Hu0pBibjnwQQwiAUkTYXe js-legit-int-options-cta" data-leg-int-type="purpose-leg-int">Opt out</div>
                        <div class="_3Sc7o7waynqWs_Ig71k2zC js-legit-int-options-message">Please note that opting out of legitimate interests may cause the site to stop functioning properly.</div>
                    </div>
                </div>
            </div>
        

    </div>
</li><li class="_1HwHO9vQCzhE42XrlVL7OK" data-item-type="purpose" data-item-id="10">
    
    <div class="_3ql0vzdiQOcFmIhzcQJS6k">
        <div class="_2HQ0FQtidNombjpBJJnJrP">
            <div class="_1uMkVepd1R8tkGak2msTxe js-expand">
                <img src="data:image/svg+xml,%3csvg height='100' width='100' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M74.363 56.363l-36 36C36.605 94.121 34.303 95 32 95s-4.605-.879-6.363-2.637a8.997 8.997 0 010-12.727L55.273 50 25.637 20.363a8.997 8.997 0 010-12.727 8.997 8.997 0 0112.727 0l36 36c3.515 3.513 3.515 9.215-.001 12.727z'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _2nfZZ_nLI6dGGUMMtp15EU">
                <span class="">Develop and improve products</span>
            </div>
        </div>
        

    <div class="_2EQa8QtLFBOtmGtirYWPeS" data-state="accepted">
        <label class=" _3uFrIZboRUQNjq-k8pdQHW js-consent-label" style="color: rgb(55, 0, 60);">Accepted</label>
        <label class="_1RrWsn0KKb2A7T8zC2WLHH js-custom-checkbox" style="border-color: rgb(55, 0, 60); background-color: rgb(55, 0, 60);">
            <input class=" js-checkbox" type="checkbox" name="purpose-consent">
            <div class="_1hWTK7MHex3cebeTpAx8KY">
                <img src="data:image/svg+xml,%3csvg id='tick' viewBox='0 0 18 14' xmlns='http://www.w3.org/2000/svg'%3e%3cpath fill='white' d='M5.727 11.075L1.432 6.687 0 8.149 5.727 14 18 1.463 16.568 0z' fill-rule='evenodd'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _15UBTqf8_Ex8a9DLfE8oRT">
                <img src="data:image/svg+xml,%3csvg id='dash' viewBox='0 0 16 2' xmlns='http://www.w3.org/2000/svg'%3e%3cpath fill='white' d='M0 0h16v2H0z' fill-rule='evenodd'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ ">
            </div>
        </label>
    </div>

    </div>
    
    <div class="fNMoi2O825ZaXpK417cfI">
        <div class="_2tU3ciVyEi2bv8_uqHIYeQ">Your data can be used to improve existing systems and software, and to develop new products</div>

        

        
            <div class="_24zAM6sJlywYUdBJLjPRXf js-list-item-group js-leg-int-group" data-leg-int-opted-out="false">
                <div class="_1PsDdX68HvALSFvJ7VE_HW">
                    <div class="_1uMkVepd1R8tkGak2msTxe js-expand">
                        <img src="data:image/svg+xml,%3csvg height='100' width='100' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M74.363 56.363l-36 36C36.605 94.121 34.303 95 32 95s-4.605-.879-6.363-2.637a8.997 8.997 0 010-12.727L55.273 50 25.637 20.363a8.997 8.997 0 010-12.727 8.997 8.997 0 0112.727 0l36 36c3.515 3.513 3.515 9.215-.001 12.727z'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _18pzpPAQ4yOJa9pZlfEOZC">
                        <span class="">Legitimate Interests</span>
                    </div>
                    <div class="_3UZVhYmmpYlXnegrh5fmkr">
                        <div class="_2KSGk-SAPK28jHbLWjrvV7">
                            <img src="data:image/svg+xml,%3csvg width='20' height='17' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M0 17h20L10 0 0 17zm10.91-2.684H9.09v-1.79h1.82v1.79zm0-3.58H9.09V7.159h1.82v3.579z' fill='%23ffb100' fill-rule='nonzero'/%3e%3c/svg%3e">
                        </div>
                        <div class="_2KknTv5cQqxr-fP0xT9o3K">
                            Opting out of legitimate interests may cause the site to stop functioning properly.
                        </div>
                    </div>
                </div>
                <div class="A8Mr8mc5PL75p42jJmYx0">
                    <ul class=" _3EHaM4EPZsod94joMjAGva">
                        
                            
                            <li class="_11R82T9EZBVuLfU7Hv9uF2">
                                <a href="https://policies.google.com/privacy" target="_blank" class="_2LU4-A27eZB2BJi17QS1OK" data-flexible="">
                                    Google Advertising Products 
                                    <img src="data:image/svg+xml,%3csvg xmlns='http://www.w3.org/2000/svg' viewBox='0 0 9 9'%3e%3cg fill='%23111' fill-rule='evenodd'%3e%3cpath d='M4.093 8.96a4.054 4.054 0 0 0 4.05-4.053.577.577 0 1 0-1.153 0A2.897 2.897 0 1 1 4.093 2.01a.577.577 0 0 0 0-1.154 4.051 4.051 0 0 0 0 8.103z'/%3e%3cpath d='M8.367.04L5.805.116a.577.577 0 1 0 .032 1.154l1.113-.03-3.22 3.216a.577.577 0 1 0 .815.816l3.22-3.22-.034 1.112a.578.578 0 0 0 .56.593h.017a.577.577 0 0 0 .577-.56L8.956.633A.577.577 0 0 0 8.363.04h.004z'/%3e%3c/g%3e%3c/svg%3e" class="E2pznXhxJo3_7gb7pylff js-expand">
                                </a>
                            </li>
                        
                    </ul>
                    <div class="_3JvTBUyAO3xVBcnIxRLwFU">
                        <div class="_1Hu0pBibjnwQQwiAUkTYXe js-legit-int-options-cta" data-leg-int-type="purpose-leg-int">Opt out</div>
                        <div class="_3Sc7o7waynqWs_Ig71k2zC js-legit-int-options-message">Please note that opting out of legitimate interests may cause the site to stop functioning properly.</div>
                    </div>
                </div>
            </div>
        

    </div>
</li></div><div class="_3fsrz8NRpcs7-174mGBFTR"></div><div class="_3fsrz8NRpcs7-174mGBFTR"><li class="_1HwHO9vQCzhE42XrlVL7OK" data-item-type="special-purpose" data-item-id="1">
    
    <div class="_3ql0vzdiQOcFmIhzcQJS6k">
        <div class="_2HQ0FQtidNombjpBJJnJrP">
            <div class="_1uMkVepd1R8tkGak2msTxe js-expand">
                <img src="data:image/svg+xml,%3csvg height='100' width='100' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M74.363 56.363l-36 36C36.605 94.121 34.303 95 32 95s-4.605-.879-6.363-2.637a8.997 8.997 0 010-12.727L55.273 50 25.637 20.363a8.997 8.997 0 010-12.727 8.997 8.997 0 0112.727 0l36 36c3.515 3.513 3.515 9.215-.001 12.727z'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _2nfZZ_nLI6dGGUMMtp15EU">
                <span class="">Ensure security, prevent fraud, and debug</span>
            </div>
        </div>
        

    <div class="_2EQa8QtLFBOtmGtirYWPeS" data-state="accepted">
        <label class="" style="color:#37003c;">Always Accepted</label>
    </div>

    </div>
    
    <div class="fNMoi2O825ZaXpK417cfI">
        <div class="_2tU3ciVyEi2bv8_uqHIYeQ">Your data can be used to monitor for and prevent fraudulent activity, and ensure systems and processes work properly and securely.</div>

        
            <div class="_24zAM6sJlywYUdBJLjPRXf js-list-item-group">
                <div class="_1PsDdX68HvALSFvJ7VE_HW">
                    <div class="_1uMkVepd1R8tkGak2msTxe js-expand">
                        <img src="data:image/svg+xml,%3csvg height='100' width='100' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M74.363 56.363l-36 36C36.605 94.121 34.303 95 32 95s-4.605-.879-6.363-2.637a8.997 8.997 0 010-12.727L55.273 50 25.637 20.363a8.997 8.997 0 010-12.727 8.997 8.997 0 0112.727 0l36 36c3.515 3.513 3.515 9.215-.001 12.727z'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _18pzpPAQ4yOJa9pZlfEOZC">
                        <span class="">Vendors</span>
                    </div>
                    <div class="_2EQa8QtLFBOtmGtirYWPeS js-consent-text" data-state="">
                        <label class=" js-consent-label"></label>
                    </div>
                </div>
                <div class="A8Mr8mc5PL75p42jJmYx0">
                    <div class="_2tU3ciVyEi2bv8_uqHIYeQ _58cFzB3Lcmp6s2odcqBse">To ensure security, prevent fraud and debug vendors can:<br>* Ensure data are securely transmitted<br>* Detect and prevent malicious, fraudulent, invalid, or illegal activity.<br>* Ensure correct and efficient operation of systems and processes, including to monitor and enhance the performance of systems and processes engaged in permitted purposes<br>Vendors cannot:<br>* Conduct any other data processing operation allowed under a different purpose under this purpose.<br>Note: Data collected and used to ensure security, prevent fraud, and debug may include automatically-sent device characteristics for identification, precise geolocation data, and data obtained by actively scanning device characteristics for identification without separate disclosure and/or opt-in.</div>
                    <ul class=" _3EHaM4EPZsod94joMjAGva">
                        
                            
                            <li class="_11R82T9EZBVuLfU7Hv9uF2">
                                <a href="https://policies.google.com/privacy" target="_blank" class="_2LU4-A27eZB2BJi17QS1OK" data-flexible="">
                                    Google Advertising Products
                                    <img src="data:image/svg+xml,%3csvg xmlns='http://www.w3.org/2000/svg' viewBox='0 0 9 9'%3e%3cg fill='%23111' fill-rule='evenodd'%3e%3cpath d='M4.093 8.96a4.054 4.054 0 0 0 4.05-4.053.577.577 0 1 0-1.153 0A2.897 2.897 0 1 1 4.093 2.01a.577.577 0 0 0 0-1.154 4.051 4.051 0 0 0 0 8.103z'/%3e%3cpath d='M8.367.04L5.805.116a.577.577 0 1 0 .032 1.154l1.113-.03-3.22 3.216a.577.577 0 1 0 .815.816l3.22-3.22-.034 1.112a.578.578 0 0 0 .56.593h.017a.577.577 0 0 0 .577-.56L8.956.633A.577.577 0 0 0 8.363.04h.004z'/%3e%3c/g%3e%3c/svg%3e" class="E2pznXhxJo3_7gb7pylff js-expand">
                                </a>
                            </li>
                        
                    </ul>
                </div>
            </div>
        

        

    </div>
</li><li class="_1HwHO9vQCzhE42XrlVL7OK" data-item-type="special-purpose" data-item-id="2">
    
    <div class="_3ql0vzdiQOcFmIhzcQJS6k">
        <div class="_2HQ0FQtidNombjpBJJnJrP">
            <div class="_1uMkVepd1R8tkGak2msTxe js-expand">
                <img src="data:image/svg+xml,%3csvg height='100' width='100' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M74.363 56.363l-36 36C36.605 94.121 34.303 95 32 95s-4.605-.879-6.363-2.637a8.997 8.997 0 010-12.727L55.273 50 25.637 20.363a8.997 8.997 0 010-12.727 8.997 8.997 0 0112.727 0l36 36c3.515 3.513 3.515 9.215-.001 12.727z'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _2nfZZ_nLI6dGGUMMtp15EU">
                <span class="">Technically deliver ads or content</span>
            </div>
        </div>
        

    <div class="_2EQa8QtLFBOtmGtirYWPeS" data-state="accepted">
        <label class="" style="color:#37003c;">Always Accepted</label>
    </div>

    </div>
    
    <div class="fNMoi2O825ZaXpK417cfI">
        <div class="_2tU3ciVyEi2bv8_uqHIYeQ">Your device can receive and send information that allows you to see and interact with ads and content.</div>

        
            <div class="_24zAM6sJlywYUdBJLjPRXf js-list-item-group">
                <div class="_1PsDdX68HvALSFvJ7VE_HW">
                    <div class="_1uMkVepd1R8tkGak2msTxe js-expand">
                        <img src="data:image/svg+xml,%3csvg height='100' width='100' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M74.363 56.363l-36 36C36.605 94.121 34.303 95 32 95s-4.605-.879-6.363-2.637a8.997 8.997 0 010-12.727L55.273 50 25.637 20.363a8.997 8.997 0 010-12.727 8.997 8.997 0 0112.727 0l36 36c3.515 3.513 3.515 9.215-.001 12.727z'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _18pzpPAQ4yOJa9pZlfEOZC">
                        <span class="">Vendors</span>
                    </div>
                    <div class="_2EQa8QtLFBOtmGtirYWPeS js-consent-text" data-state="">
                        <label class=" js-consent-label"></label>
                    </div>
                </div>
                <div class="A8Mr8mc5PL75p42jJmYx0">
                    <div class="_2tU3ciVyEi2bv8_uqHIYeQ _58cFzB3Lcmp6s2odcqBse">To deliver information and respond to technical requests vendors can:<br>* Use a user’s IP address to deliver an ad over the internet<br>* Respond to a user’s interaction with an ad by sending the user to a landing page<br>* Use a user’s IP address to deliver content over the internet<br>* Respond to a user’s interaction with content by sending the user to a landing page<br>* Use information about the device type and capabilities for delivering ads or content, for example, to deliver the right size ad creative or video file in a format supported by the device<br>Vendors cannot:<br>* Conduct any other data processing operation allowed under a different purpose under this purpose</div>
                    <ul class=" _3EHaM4EPZsod94joMjAGva">
                        
                            
                            <li class="_11R82T9EZBVuLfU7Hv9uF2">
                                <a href="https://policies.google.com/privacy" target="_blank" class="_2LU4-A27eZB2BJi17QS1OK" data-flexible="">
                                    Google Advertising Products
                                    <img src="data:image/svg+xml,%3csvg xmlns='http://www.w3.org/2000/svg' viewBox='0 0 9 9'%3e%3cg fill='%23111' fill-rule='evenodd'%3e%3cpath d='M4.093 8.96a4.054 4.054 0 0 0 4.05-4.053.577.577 0 1 0-1.153 0A2.897 2.897 0 1 1 4.093 2.01a.577.577 0 0 0 0-1.154 4.051 4.051 0 0 0 0 8.103z'/%3e%3cpath d='M8.367.04L5.805.116a.577.577 0 1 0 .032 1.154l1.113-.03-3.22 3.216a.577.577 0 1 0 .815.816l3.22-3.22-.034 1.112a.578.578 0 0 0 .56.593h.017a.577.577 0 0 0 .577-.56L8.956.633A.577.577 0 0 0 8.363.04h.004z'/%3e%3c/g%3e%3c/svg%3e" class="E2pznXhxJo3_7gb7pylff js-expand">
                                </a>
                            </li>
                        
                    </ul>
                </div>
            </div>
        

        

    </div>
</li></div><div class="_3fsrz8NRpcs7-174mGBFTR"><li class="_1HwHO9vQCzhE42XrlVL7OK" data-item-type="feature" data-item-id="1">
    
    <div class="_3ql0vzdiQOcFmIhzcQJS6k">
        <div class="_2HQ0FQtidNombjpBJJnJrP">
            <div class="_1uMkVepd1R8tkGak2msTxe js-expand">
                <img src="data:image/svg+xml,%3csvg height='100' width='100' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M74.363 56.363l-36 36C36.605 94.121 34.303 95 32 95s-4.605-.879-6.363-2.637a8.997 8.997 0 010-12.727L55.273 50 25.637 20.363a8.997 8.997 0 010-12.727 8.997 8.997 0 0112.727 0l36 36c3.515 3.513 3.515 9.215-.001 12.727z'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _2nfZZ_nLI6dGGUMMtp15EU">
                <span class="">Match and combine offline data sources</span>
            </div>
        </div>
        

    <div class="_2EQa8QtLFBOtmGtirYWPeS" data-state="accepted">
        <label class="" style="color:#37003c;">Always Accepted</label>
    </div>

    </div>
    
    <div class="fNMoi2O825ZaXpK417cfI">
        <div class="_2tU3ciVyEi2bv8_uqHIYeQ">Data from offline data sources can be combined with your online activity in support of one or more purposes</div>

        
            <div class="_24zAM6sJlywYUdBJLjPRXf js-list-item-group">
                <div class="_1PsDdX68HvALSFvJ7VE_HW">
                    <div class="_1uMkVepd1R8tkGak2msTxe js-expand">
                        <img src="data:image/svg+xml,%3csvg height='100' width='100' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M74.363 56.363l-36 36C36.605 94.121 34.303 95 32 95s-4.605-.879-6.363-2.637a8.997 8.997 0 010-12.727L55.273 50 25.637 20.363a8.997 8.997 0 010-12.727 8.997 8.997 0 0112.727 0l36 36c3.515 3.513 3.515 9.215-.001 12.727z'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _18pzpPAQ4yOJa9pZlfEOZC">
                        <span class="">Vendors</span>
                    </div>
                    <div class="_2EQa8QtLFBOtmGtirYWPeS js-consent-text" data-state="">
                        <label class=" js-consent-label"></label>
                    </div>
                </div>
                <div class="A8Mr8mc5PL75p42jJmYx0">
                    <div class="_2tU3ciVyEi2bv8_uqHIYeQ _58cFzB3Lcmp6s2odcqBse">Vendors can:<br>* Combine data obtained offline with data collected online in support of one or more Purposes or Special Purposes.</div>
                    <ul class=" _3EHaM4EPZsod94joMjAGva">
                        
                            
                            <li class="_11R82T9EZBVuLfU7Hv9uF2">
                                <a href="https://policies.google.com/privacy" target="_blank" class="_2LU4-A27eZB2BJi17QS1OK" data-flexible="">
                                    Google Advertising Products
                                    <img src="data:image/svg+xml,%3csvg xmlns='http://www.w3.org/2000/svg' viewBox='0 0 9 9'%3e%3cg fill='%23111' fill-rule='evenodd'%3e%3cpath d='M4.093 8.96a4.054 4.054 0 0 0 4.05-4.053.577.577 0 1 0-1.153 0A2.897 2.897 0 1 1 4.093 2.01a.577.577 0 0 0 0-1.154 4.051 4.051 0 0 0 0 8.103z'/%3e%3cpath d='M8.367.04L5.805.116a.577.577 0 1 0 .032 1.154l1.113-.03-3.22 3.216a.577.577 0 1 0 .815.816l3.22-3.22-.034 1.112a.578.578 0 0 0 .56.593h.017a.577.577 0 0 0 .577-.56L8.956.633A.577.577 0 0 0 8.363.04h.004z'/%3e%3c/g%3e%3c/svg%3e" class="E2pznXhxJo3_7gb7pylff js-expand">
                                </a>
                            </li>
                        
                    </ul>
                </div>
            </div>
        

        

    </div>
</li><li class="_1HwHO9vQCzhE42XrlVL7OK" data-item-type="feature" data-item-id="2">
    
    <div class="_3ql0vzdiQOcFmIhzcQJS6k">
        <div class="_2HQ0FQtidNombjpBJJnJrP">
            <div class="_1uMkVepd1R8tkGak2msTxe js-expand">
                <img src="data:image/svg+xml,%3csvg height='100' width='100' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M74.363 56.363l-36 36C36.605 94.121 34.303 95 32 95s-4.605-.879-6.363-2.637a8.997 8.997 0 010-12.727L55.273 50 25.637 20.363a8.997 8.997 0 010-12.727 8.997 8.997 0 0112.727 0l36 36c3.515 3.513 3.515 9.215-.001 12.727z'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _2nfZZ_nLI6dGGUMMtp15EU">
                <span class="">Link different devices</span>
            </div>
        </div>
        

    <div class="_2EQa8QtLFBOtmGtirYWPeS" data-state="accepted">
        <label class="" style="color:#37003c;">Always Accepted</label>
    </div>

    </div>
    
    <div class="fNMoi2O825ZaXpK417cfI">
        <div class="_2tU3ciVyEi2bv8_uqHIYeQ">Different devices can be determined as belonging to you or your household in support of one or more of purposes.</div>

        
            <div class="_24zAM6sJlywYUdBJLjPRXf js-list-item-group">
                <div class="_1PsDdX68HvALSFvJ7VE_HW">
                    <div class="_1uMkVepd1R8tkGak2msTxe js-expand">
                        <img src="data:image/svg+xml,%3csvg height='100' width='100' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M74.363 56.363l-36 36C36.605 94.121 34.303 95 32 95s-4.605-.879-6.363-2.637a8.997 8.997 0 010-12.727L55.273 50 25.637 20.363a8.997 8.997 0 010-12.727 8.997 8.997 0 0112.727 0l36 36c3.515 3.513 3.515 9.215-.001 12.727z'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _18pzpPAQ4yOJa9pZlfEOZC">
                        <span class="">Vendors</span>
                    </div>
                    <div class="_2EQa8QtLFBOtmGtirYWPeS js-consent-text" data-state="">
                        <label class=" js-consent-label"></label>
                    </div>
                </div>
                <div class="A8Mr8mc5PL75p42jJmYx0">
                    <div class="_2tU3ciVyEi2bv8_uqHIYeQ _58cFzB3Lcmp6s2odcqBse">Vendors can:<br>* Deterministically determine that two or more devices belong to the same user or household<br>* Probabilistically determine that two or more devices belong to the same user or household<br>* Actively scan device characteristics for identification for probabilistic identification if users have allowed vendors to actively scan device characteristics for identification (Special Feature 2)</div>
                    <ul class=" _3EHaM4EPZsod94joMjAGva">
                        
                            
                            <li class="_11R82T9EZBVuLfU7Hv9uF2">
                                <a href="https://policies.google.com/privacy" target="_blank" class="_2LU4-A27eZB2BJi17QS1OK" data-flexible="">
                                    Google Advertising Products
                                    <img src="data:image/svg+xml,%3csvg xmlns='http://www.w3.org/2000/svg' viewBox='0 0 9 9'%3e%3cg fill='%23111' fill-rule='evenodd'%3e%3cpath d='M4.093 8.96a4.054 4.054 0 0 0 4.05-4.053.577.577 0 1 0-1.153 0A2.897 2.897 0 1 1 4.093 2.01a.577.577 0 0 0 0-1.154 4.051 4.051 0 0 0 0 8.103z'/%3e%3cpath d='M8.367.04L5.805.116a.577.577 0 1 0 .032 1.154l1.113-.03-3.22 3.216a.577.577 0 1 0 .815.816l3.22-3.22-.034 1.112a.578.578 0 0 0 .56.593h.017a.577.577 0 0 0 .577-.56L8.956.633A.577.577 0 0 0 8.363.04h.004z'/%3e%3c/g%3e%3c/svg%3e" class="E2pznXhxJo3_7gb7pylff js-expand">
                                </a>
                            </li>
                        
                    </ul>
                </div>
            </div>
        

        

    </div>
</li></div></ul>
                    </div>
                    <div class="_1AqM-R7JFkYFf4xt-i0y_w js-tab-content" data-tab-content="vendors">
                        <ul class="IHzEulReWVs1ygBjjxtAJ js-vendor-list">
                            <!-- Vendors List populated by JS -->
                        <div class="_3fsrz8NRpcs7-174mGBFTR"><li class="_1HwHO9vQCzhE42XrlVL7OK" data-item-type="vendor" data-item-id="755">
    
    <div class="_3ql0vzdiQOcFmIhzcQJS6k">
        <div class="_2HQ0FQtidNombjpBJJnJrP">
            <div class="_1uMkVepd1R8tkGak2msTxe js-expand">
                <img src="data:image/svg+xml,%3csvg height='100' width='100' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M74.363 56.363l-36 36C36.605 94.121 34.303 95 32 95s-4.605-.879-6.363-2.637a8.997 8.997 0 010-12.727L55.273 50 25.637 20.363a8.997 8.997 0 010-12.727 8.997 8.997 0 0112.727 0l36 36c3.515 3.513 3.515 9.215-.001 12.727z'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _2nfZZ_nLI6dGGUMMtp15EU">
                <span class="">Google Advertising Products</span>
            </div>
            <a href="https://policies.google.com/privacy" target="_blank" class="_3ViPMeE_CpzVkJRrRbmBbI">
                <img src="data:image/svg+xml,%3csvg xmlns='http://www.w3.org/2000/svg' viewBox='0 0 9 9'%3e%3cg fill='%23111' fill-rule='evenodd'%3e%3cpath d='M4.093 8.96a4.054 4.054 0 0 0 4.05-4.053.577.577 0 1 0-1.153 0A2.897 2.897 0 1 1 4.093 2.01a.577.577 0 0 0 0-1.154 4.051 4.051 0 0 0 0 8.103z'/%3e%3cpath d='M8.367.04L5.805.116a.577.577 0 1 0 .032 1.154l1.113-.03-3.22 3.216a.577.577 0 1 0 .815.816l3.22-3.22-.034 1.112a.578.578 0 0 0 .56.593h.017a.577.577 0 0 0 .577-.56L8.956.633A.577.577 0 0 0 8.363.04h.004z'/%3e%3c/g%3e%3c/svg%3e" class="E2pznXhxJo3_7gb7pylff">
            </a>
        </div>
        

    <div class="_2EQa8QtLFBOtmGtirYWPeS" data-state="accepted">
        <label class=" _3uFrIZboRUQNjq-k8pdQHW js-consent-label" style="color: rgb(55, 0, 60);">Accepted</label>
        <label class="_1RrWsn0KKb2A7T8zC2WLHH js-custom-checkbox" style="border-color: rgb(55, 0, 60); background-color: rgb(55, 0, 60);">
            <input class=" js-checkbox" type="checkbox" name="vendor-consent">
            <div class="_1hWTK7MHex3cebeTpAx8KY">
                <img src="data:image/svg+xml,%3csvg id='tick' viewBox='0 0 18 14' xmlns='http://www.w3.org/2000/svg'%3e%3cpath fill='white' d='M5.727 11.075L1.432 6.687 0 8.149 5.727 14 18 1.463 16.568 0z' fill-rule='evenodd'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _15UBTqf8_Ex8a9DLfE8oRT">
                <img src="data:image/svg+xml,%3csvg id='dash' viewBox='0 0 16 2' xmlns='http://www.w3.org/2000/svg'%3e%3cpath fill='white' d='M0 0h16v2H0z' fill-rule='evenodd'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ ">
            </div>
        </label>
    </div>

    </div>
    
    <div class="fNMoi2O825ZaXpK417cfI">

        

        

        
            <div class="_24zAM6sJlywYUdBJLjPRXf js-list-item-group">
                <div class="_1PsDdX68HvALSFvJ7VE_HW">
                    <div class="_1uMkVepd1R8tkGak2msTxe js-expand">
                        <img src="data:image/svg+xml,%3csvg height='100' width='100' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M74.363 56.363l-36 36C36.605 94.121 34.303 95 32 95s-4.605-.879-6.363-2.637a8.997 8.997 0 010-12.727L55.273 50 25.637 20.363a8.997 8.997 0 010-12.727 8.997 8.997 0 0112.727 0l36 36c3.515 3.513 3.515 9.215-.001 12.727z'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _18pzpPAQ4yOJa9pZlfEOZC">
                        <span class="">Special Purposes</span>
                    </div>
                    <div class="_2EQa8QtLFBOtmGtirYWPeS" data-state="accepted">
                        <label class="" style="color:#37003c;">Always Accepted</label>
                    </div>
                </div>
                <div class="A8Mr8mc5PL75p42jJmYx0">
                    <ul class="">
                        
                            <li class="_3O6bQ2DBQgo2ENtPDLNiPx">Ensure security, prevent fraud, and debug</li>
                        
                            <li class="_3O6bQ2DBQgo2ENtPDLNiPx">Technically deliver ads or content</li>
                        
                    </ul>
                </div>
            </div>
        

        
            <div class="_24zAM6sJlywYUdBJLjPRXf js-list-item-group">
                <div class="_1PsDdX68HvALSFvJ7VE_HW">
                    <div class="_1uMkVepd1R8tkGak2msTxe js-expand">
                        <img src="data:image/svg+xml,%3csvg height='100' width='100' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M74.363 56.363l-36 36C36.605 94.121 34.303 95 32 95s-4.605-.879-6.363-2.637a8.997 8.997 0 010-12.727L55.273 50 25.637 20.363a8.997 8.997 0 010-12.727 8.997 8.997 0 0112.727 0l36 36c3.515 3.513 3.515 9.215-.001 12.727z'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _18pzpPAQ4yOJa9pZlfEOZC">
                        <span class="">Features</span>
                    </div>
                    <div class="_2EQa8QtLFBOtmGtirYWPeS" data-state="accepted">
                        <label class="" style="color:#37003c;">Always Accepted</label>
                    </div>
                </div>
                <div class="A8Mr8mc5PL75p42jJmYx0">
                    <ul class="">
                        
                            <li class="_3O6bQ2DBQgo2ENtPDLNiPx">Match and combine offline data sources</li>
                        
                            <li class="_3O6bQ2DBQgo2ENtPDLNiPx">Link different devices</li>
                        
                    </ul>
                </div>
            </div>
        

        
            <div class="_24zAM6sJlywYUdBJLjPRXf js-list-item-group js-leg-int-group" data-leg-int-opted-out="false">
                <div class="_1PsDdX68HvALSFvJ7VE_HW">
                    <div class="_1uMkVepd1R8tkGak2msTxe js-expand">
                        <img src="data:image/svg+xml,%3csvg height='100' width='100' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M74.363 56.363l-36 36C36.605 94.121 34.303 95 32 95s-4.605-.879-6.363-2.637a8.997 8.997 0 010-12.727L55.273 50 25.637 20.363a8.997 8.997 0 010-12.727 8.997 8.997 0 0112.727 0l36 36c3.515 3.513 3.515 9.215-.001 12.727z'/%3e%3c/svg%3e" class="kH9tk86QHyEnXZylzQkXQ _18pzpPAQ4yOJa9pZlfEOZC">
                        <span class="">Legitimate Interests</span>
                    </div>
                    <div class="_3UZVhYmmpYlXnegrh5fmkr">
                        <div class="_2KSGk-SAPK28jHbLWjrvV7">
                            <img src="data:image/svg+xml,%3csvg width='20' height='17' xmlns='http://www.w3.org/2000/svg'%3e%3cpath d='M0 17h20L10 0 0 17zm10.91-2.684H9.09v-1.79h1.82v1.79zm0-3.58H9.09V7.159h1.82v3.579z' fill='%23ffb100' fill-rule='nonzero'/%3e%3c/svg%3e">
                        </div>
                        <div class="_2KknTv5cQqxr-fP0xT9o3K">
                            Opting out of legitimate interests may cause the site to stop functioning properly.
                        </div>
                    </div>
                </div>
                <div class="A8Mr8mc5PL75p42jJmYx0">
                    <ul class="">
                        
                            
                            <li class="_3O6bQ2DBQgo2ENtPDLNiPx" data-flexible="">
                                Select basic ads 
                            </li>
                        
                            
                            <li class="_3O6bQ2DBQgo2ENtPDLNiPx" data-flexible="">
                                Create a personalised content profile 
                            </li>
                        
                            
                            <li class="_3O6bQ2DBQgo2ENtPDLNiPx" data-flexible="">
                                Select personalised content 
                            </li>
                        
                            
                            <li class="_3O6bQ2DBQgo2ENtPDLNiPx" data-flexible="">
                                Measure ad performance 
                            </li>
                        
                            
                            <li class="_3O6bQ2DBQgo2ENtPDLNiPx" data-flexible="">
                                Apply market research to generate audience insights 
                            </li>
                        
                            
                            <li class="_3O6bQ2DBQgo2ENtPDLNiPx" data-flexible="">
                                Develop and improve products 
                            </li>
                        
                    </ul>
                    <div class="_3JvTBUyAO3xVBcnIxRLwFU">
                        <div class="_1Hu0pBibjnwQQwiAUkTYXe js-legit-int-options-cta" data-leg-int-type="vendor-leg-int">Opt out</div>
                        <div class="_3Sc7o7waynqWs_Ig71k2zC js-legit-int-options-message">Please note that opting out of legitimate interests may cause the site to stop functioning properly.</div>
                    </div>
                </div>
            </div>
        
    </div>
</li></div><div class="_3fsrz8NRpcs7-174mGBFTR"></div></ul>
                    </div>

                </div>
                <div class="_1hY3OQlNAY1YUf8L5CrXuG">
                    <div class="_2tFLh0xBwCF1IFIIyQXJSN js-footer-copy">You can manage and withdraw your consent at any time via the Cookie Policy.</div>
                    <div class="_24Il51SkQ29P1pCkJOUO-7">
                        <button class="_2hTJ5th4dIYlveipSEMYHH BfdVlAo_cgSVjDUegen0F js-save-and-close" style="background-color:#37003c;">Save and Close</button>
                    </div>
                </div>
            </div>
        </div>
    </div>
</div>
<script type="text/javascript">
    __tcfapi('addEventListener', 2, function(tcData, success) {
        if (success && tcData.gdprApplies && (tcData.eventStatus === 'tcloaded' || tcData.eventStatus === 'useractioncomplete') ) {
            if (tcData.purpose.consents[1]) {
                gtag('consent', 'update', {
                    'ad_storage': 'granted',
                    'analytics_storage': 'granted'
                })
            }
        }
    })
</script>

<div class="_21qjHktoYkBsbeNaD5qxm4"></div><script type="text/javascript" src="/resources/prod/v6.98.1-4068/widgets/pl_global-header.min.js"></script><script type="text/javascript" src="/resources/prod/v6.98.1-4068/widgets/pl_match-week.min.js"></script><script type="text/javascript" src="/resources/prod/v6.98.1-4068/widgets/pl_tabbed.min.js"></script><script type="text/javascript" src="/resources/prod/v6.98.1-4068/widgets/pl_match-centre.min.js"></script><script type="text/javascript" src="/resources/prod/v6.98.1-4068/widgets/pl_social-share.min.js"></script><script type="text/javascript" src="/resources/prod/v6.98.1-4068/widgets/pl_player-image.min.js"></script><script type="text/javascript" src="/resources/prod/v6.98.1-4068/widgets/pl_kotm.min.js"></script><script type="text/javascript" src="/resources/prod/v6.98.1-4068/widgets/pl_stats.min.js"></script><script type="text/javascript" src="/resources/prod/v6.98.1-4068/widgets/pl_editorial-lists.min.js"></script><script type="text/javascript" src="/resources/prod/v6.98.1-4068/widgets/pl_video-player.min.js"></script><script type="text/javascript" src="/resources/prod/v6.98.1-4068/widgets/pl_gallery.min.js"></script><script type="text/javascript" src="/resources/prod/v6.98.1-4068/widgets/pl_footer.min.js"></script><script data-player="plVideoModal" src="//players.brightcove.net/2508689025001/BvTUJZhBm_default/index.min.js?plVideoModal"></script><script data-player="plVideoModal_html5_api" src="//players.brightcove.net/2508689025001/BvTUJZhBm_default/index.min.js?plVideoModal_html5_api"></script><iframe src="https://7d9018e0137b1093db6a7588f778170a.safeframe.googlesyndication.com/safeframe/1-0-38/html/container.html" style="visibility: hidden; display: none;"></iframe><iframe scrolling="no" frameborder="0" allowtransparency="true" src="https://platform.twitter.com/widgets/widget_iframe.d7fc2fc075c61f6fa34d79a0cbbf1e34.html?origin=https%3A%2F%2Fwww.premierleague.com" title="Twitter settings iframe" style="display: none;"></iframe><iframe id="rufous-sandbox" scrolling="no" frameborder="0" allowtransparency="true" allowfullscreen="true" style="position: absolute; visibility: hidden; display: none; width: 0px; height: 0px; padding: 0px; border: none;" title="Twitter analytics iframe"></iframe><script id="onPoll" src="https://resources.premierleague.com/dynamic/data/livewire/pl_2016_17/poll.js"></script></body>

# %% [markdown]
# ## Write code to clean the html code stored in 'teamsContainer' to output the team names and scoreline of the given match.

# %%
# write code here

# %% [markdown]
# ## Now we want to retrieve the team names as well of the scoreline for all the matches in August (match ID: 46605 to 46643).
# Save the names of the home team, away team, the number of goals scored by the home team and the number of goals scored by the away team in a dataframe.
#
# Afterwards print out the dataframe.
#
# Note: If correctly implemented, it should take up to a 3 minutes to scrape these results.

# %%
home_teams = []
away_teams = []
scores = []

# %%
url = 'https://premierleague.com/match/{0}'

# use list coprehension to get all the urls
all_urls = [url.format(match) for match in range(46605, 46644)]

for url in all_urls:
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    home_team = soup.find("div", {"class": "team home"}).find('span',class_="long")
    away_team = soup.find("div", {"class": "team away"}).find('span',class_="long")
    soccer_scores = soup.find('div',class_="score fullTime")
    scores.append(soccer_scores.text)
    home_teams.append(home_team.text)
    away_teams.append(away_team.text)

# %%
# write code here

# %% [markdown]
# ## Print a list of all unique teams.

# %%
# write code here

# %% [markdown]
# ## Using the scores of each match, compute the current standings.
# Use the following rules to calculate the points for a given team:
#
# For a win, award a team 3, points.
#
# A draw earns both teams 1 point.
#
# No points are earned for a loss.
#
# ### Print the resulting dataframe ordered by total points.
# Your dataframe should have the following columns: Team Name, Total points.

# %%
# write code here
